# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import dateutil.parser

# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
df = pd.read_csv("IHME_GBD_2013_DEATHS_1990_2013_WAR_AND_DISASTER_Y2014M12D17.CSV")

# %%
df.head()
# Out:
#    location_id location_code location_name  year  age_group_id  \
# 0            1             G        Global  1990             2
# 1            1             G        Global  1990             2
# 2            1             G        Global  1990             3
# 3            1             G        Global  1990             3
# 4            1             G        Global  1990             4
#
#    age_group_name  sex_id sex_name  cause_id              cause_name  metric  \
# 0  Early Neonatal       1     Male       696  Unintentional injuries  deaths
# 1  Early Neonatal       2   Female       696  Unintentional injuries  deaths
# 2   Late Neonatal       1     Male       696  Unintentional injuries  deaths
# 3   Late Neonatal       2   Female       696  Unintentional injuries  deaths
# 4   Post Neonatal       1     Male       696  Unintentional injuries  deaths
#
#      unit     mean    lower     upper
# 0  number  19032.6  13955.4   26473.2
# 1  number  13138.1   8708.2   17590.1
# ...

# %%
df.columns
# Out:
# Index(['location_id', 'location_code', 'location_name', 'year', 'age_group_id',
#        'age_group_name', 'sex_id', 'sex_name', 'cause_id', 'cause_name',
#        'metric', 'unit', 'mean', 'lower', 'upper'],
#       dtype='object')

# %%
df = df[df['unit'] == 'rate per 100,000']

# %%
df = df[df['age_group_name'] == 'All Ages']

# %%
df = df[df['sex_name'] == 'Female']

# %%
df = df.set_index(['location_name'])

# %%
df
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# Global                   1             G  1990            22       All Ages
# Global                   1             G  1991            22       All Ages
# Global                   1             G  1992            22       All Ages
# Global                   1             G  1993            22       All Ages
# Global                   1             G  1994            22       All Ages
# Global                   1             G  1995            22       All Ages
# Global                   1             G  1996            22       All Ages
# Global                   1             G  1997            22       All Ages
# Global                   1             G  1998            22       All Ages
# Global                   1             G  1999            22       All Ages
# Global                   1             G  2000            22       All Ages
# ...

# %%
df_global = df.loc[df.index.isin(['Global'])]

# %%
df_global
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# Global                   1             G  1990            22       All Ages
# Global                   1             G  1991            22       All Ages
# Global                   1             G  1992            22       All Ages
# Global                   1             G  1993            22       All Ages
# Global                   1             G  1994            22       All Ages
# Global                   1             G  1995            22       All Ages
# Global                   1             G  1996            22       All Ages
# Global                   1             G  1997            22       All Ages
# Global                   1             G  1998            22       All Ages
# Global                   1             G  1999            22       All Ages
# Global                   1             G  2000            22       All Ages
# ...

# %%
df_africa = df.loc[df.index.isin(['Algeria','Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Cabo Verde', 'Central African Republic', 'Chad', 'Comoros', 'Congo', 'Democratic Republic of the Congo', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'South Africa', 'South Sudan', 'Swaziland', 'Togo', 'Uganda', 'Tanzania', 'Zambia', 'Zimbabwe'])]

# %%
df_africa
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# Algeria                139           DZA  1990            22       All Ages
# Algeria                139           DZA  1991            22       All Ages
# Algeria                139           DZA  1992            22       All Ages
# Algeria                139           DZA  1993            22       All Ages
# Algeria                139           DZA  1994            22       All Ages
# Algeria                139           DZA  1995            22       All Ages
# Algeria                139           DZA  1996            22       All Ages
# Algeria                139           DZA  1997            22       All Ages
# Algeria                139           DZA  1998            22       All Ages
# Algeria                139           DZA  1999            22       All Ages
# Algeria                139           DZA  2000            22       All Ages
# ...

# %%
df_africa.sort_values(by='mean', ascending=False)
# Out:
#                        location_id location_code  year  age_group_id  \
# location_name
# Angola                         168           AGO  1990            22
# Angola                         168           AGO  1991            22
# Angola                         168           AGO  1992            22
# Angola                         168           AGO  1993            22
# Angola                         168           AGO  1994            22
# Equatorial Guinea              172           GNQ  2005            22
# Equatorial Guinea              172           GNQ  2006            22
# Equatorial Guinea              172           GNQ  2007            22
# Equatorial Guinea              172           GNQ  2008            22
# Angola                         168           AGO  1995            22
# Equatorial Guinea              172           GNQ  2009            22
# Equatorial Guinea              172           GNQ  1998            22
# ...

# %%
df_africa_year = df_africa.set_index(['year'])

# %%
df_africa_year
# Out:
#       location_id location_code  age_group_id age_group_name  sex_id sex_name  \
# year
# 1990          139           DZA            22       All Ages       2   Female
# 1991          139           DZA            22       All Ages       2   Female
# 1992          139           DZA            22       All Ages       2   Female
# 1993          139           DZA            22       All Ages       2   Female
# 1994          139           DZA            22       All Ages       2   Female
# 1995          139           DZA            22       All Ages       2   Female
# 1996          139           DZA            22       All Ages       2   Female
# 1997          139           DZA            22       All Ages       2   Female
# 1998          139           DZA            22       All Ages       2   Female
# 1999          139           DZA            22       All Ages       2   Female
# 2000          139           DZA            22       All Ages       2   Female
# ...

# %%
df_africa_year = df_africa_year.groupby(df_africa_year.index).sum()

# %%
df_africa_year
# Out:
#       location_id  age_group_id  sex_id  cause_id    mean  lower   upper
# year
# 1990         9152          1034      94     32712  1108.2  732.0  1658.4
# 1991         9152          1034      94     32712  1105.5  731.8  1642.4
# 1992         9152          1034      94     32712  1100.4  729.4  1637.8
# 1993         9152          1034      94     32712  1096.8  726.7  1612.0
# 1994         9152          1034      94     32712  1099.0  724.2  1603.9
# 1995         9152          1034      94     32712  1104.8  732.4  1602.0
# 1996         9152          1034      94     32712  1103.8  730.5  1591.9
# 1997         9152          1034      94     32712  1097.7  726.3  1578.6
# 1998         9152          1034      94     32712  1091.7  721.6  1555.7
# 1999         9152          1034      94     32712  1084.3  717.5  1548.3
# 2000         9152          1034      94     32712  1075.9  717.1  1539.9
# 2001         9152          1034      94     32712  1064.7  712.9  1511.6
# ...

# %%
fig, ax = plt.subplots()

df_africa_year.plot(x=df_africa_year.index, y='mean', ax=ax, legend=False)
ax.set_title("")

# %%
#Latin America and Caribbean
df_latinamerica = df.loc[df.index.isin(['Antigua and Barbuda', 'Argentina', 'Bolivia', 'Bahamas', 'Barbados', 'Belize', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'Ecuador', 'El Salvador', 'Grenada', 'Guatemala', 'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Venezuela'])]

# %%
df_latinamerica.sort_values(by='mean', ascending=False)
# Out:
#                     location_id location_code  year  age_group_id  \
# location_name
# Bolivia                     121           BOL  1990            22
# Bolivia                     121           BOL  1991            22
# Bolivia                     121           BOL  1992            22
# Bolivia                     121           BOL  1993            22
# Bolivia                     121           BOL  1994            22
# Bolivia                     121           BOL  1995            22
# Bolivia                     121           BOL  1996            22
# Bolivia                     121           BOL  1997            22
# Bolivia                     121           BOL  1998            22
# Bolivia                     121           BOL  1999            22
# Bolivia                     121           BOL  2000            22
# Bolivia                     121           BOL  2001            22
# Bolivia                     121           BOL  2002            22
# ...

# %%
df_latinamerica_year = df_latinamerica.set_index(['year'])

# %%
df_latinamerica_year = df_latinamerica_year.groupby(df_latinamerica_year.index).sum()

# %%
df_latinamerica_year
# Out:
#       location_id  age_group_id  sex_id  cause_id   mean  lower  upper
# year
# 1990         3666           682      62     21576  472.9  380.1  597.3
# 1991         3666           682      62     21576  473.0  385.3  589.1
# 1992         3666           682      62     21576  471.8  386.1  581.8
# 1993         3666           682      62     21576  473.0  388.6  579.2
# 1994         3666           682      62     21576  472.7  388.5  575.7
# 1995         3666           682      62     21576  473.4  389.8  570.5
# 1996         3666           682      62     21576  475.9  390.6  567.2
# 1997         3666           682      62     21576  479.2  392.4  566.6
# 1998         3666           682      62     21576  481.4  390.9  565.5
# 1999         3666           682      62     21576  480.3  387.0  562.4
# 2000         3666           682      62     21576  480.1  384.8  561.7
# 2001         3666           682      62     21576  480.8  380.9  563.0
# ...

# %%
fig, ax = plt.subplots()

df_latinamerica_year.plot(x=df_latinamerica_year.index, y='mean', ax=ax, legend=False)
ax.set_title("")

# %%
df_asiapac = df.loc[df.index.isin(['Afghanistan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'North Korea', 'Fiji', 'India', 'Indonesia', 'Iran', 'Iraq', 'Japan', 'Jordan', 'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Marshall Islands', 'Federated States of Micronesia', 'Mongolia', 'Myanmar', 'Nepal', 'Oman', 'Pakistan', 'Papua New Guinea', 'Philippines', 'Qatar', 'South Korea', 'Samoa', 'Saudi Arabia', 'Singapore', 'Solomon Islands', 'Sri Lanka', 'Syria', 'Tajikstan', 'Thailand', 'Timor-Leste', 'Turkey', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vanuatu', 'Vietnam', 'Yemen'])]

# %%
df_asiapac
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# China                    6           CHN  1990            22       All Ages
# China                    6           CHN  1991            22       All Ages
# China                    6           CHN  1992            22       All Ages
# China                    6           CHN  1993            22       All Ages
# China                    6           CHN  1994            22       All Ages
# China                    6           CHN  1995            22       All Ages
# China                    6           CHN  1996            22       All Ages
# China                    6           CHN  1997            22       All Ages
# China                    6           CHN  1998            22       All Ages
# China                    6           CHN  1999            22       All Ages
# China                    6           CHN  2000            22       All Ages
# ...

# %%
df_asiapac.sort_values(by='mean', ascending=False)
# Out:
#                       location_id location_code  year  age_group_id  \
# location_name
# Bangladesh                    161           BGD  1990            22
# Bangladesh                    161           BGD  1991            22
# Bangladesh                    161           BGD  1992            22
# India                         163           IND  1990            22
# India                         163           IND  1991            22
# India                         163           IND  1992            22
# India                         163           IND  1993            22
# Bangladesh                    161           BGD  1993            22
# India                         163           IND  1994            22
# India                         163           IND  1995            22
# Bangladesh                    161           BGD  1994            22
# India                         163           IND  1996            22
# Bangladesh                    161           BGD  1995            22
# ...

# %%
df_asiapac_year = df_asiapac.set_index(['year'])

# %%
df_asiapac_year = df_asiapac_year.groupby(df_asiapac_year.index).sum()

# %%
df_asiapac_year
# Out:
#       location_id  age_group_id  sex_id  cause_id   mean  lower   upper
# year
# 1990         3817          1078      98     34104  962.3  682.3  1330.9
# 1991         3817          1078      98     34104  941.8  673.4  1290.7
# 1992         3817          1078      98     34104  923.9  664.8  1255.8
# 1993         3817          1078      98     34104  908.3  653.1  1228.7
# 1994         3817          1078      98     34104  897.3  644.2  1202.9
# 1995         3817          1078      98     34104  888.9  635.5  1192.8
# 1996         3817          1078      98     34104  877.1  627.0  1176.4
# 1997         3817          1078      98     34104  867.2  622.0  1159.1
# 1998         3817          1078      98     34104  857.2  616.6  1147.1
# 1999         3817          1078      98     34104  845.2  609.8  1124.7
# 2000         3817          1078      98     34104  831.8  601.9  1112.2
# 2001         3817          1078      98     34104  818.6  592.5  1087.4
# ...

# %%
fig, ax = plt.subplots()

df_asiapac_year.plot(x=df_asiapac_year.index, y='mean', ax=ax, legend=False)
ax.set_title("")

# %%
#Eastern European

df_easterneurope = df.loc[df.index.isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Latvia', 'Lithuania', 'Montenegro', 'Poland', 'Moldova', 'Romania', 'Russia', 'Serbia', 'Slovakia', 'Macedonia', 'Ukraine'])]

# %%
df_easterneurope
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# Armenia                 33           ARM  1990            22       All Ages
# Armenia                 33           ARM  1991            22       All Ages
# Armenia                 33           ARM  1992            22       All Ages
# Armenia                 33           ARM  1993            22       All Ages
# Armenia                 33           ARM  1994            22       All Ages
# Armenia                 33           ARM  1995            22       All Ages
# Armenia                 33           ARM  1996            22       All Ages
# Armenia                 33           ARM  1997            22       All Ages
# Armenia                 33           ARM  1998            22       All Ages
# Armenia                 33           ARM  1999            22       All Ages
# Armenia                 33           ARM  2000            22       All Ages
# ...

# %%
df_easterneurope.sort_values(by='mean', ascending=False)
# Out:
#                         location_id location_code  year  age_group_id  \
# location_name
# Hungary                          48           HUN  1990            22
# Hungary                          48           HUN  1991            22
# Hungary                          48           HUN  1992            22
# Hungary                          48           HUN  1993            22
# Hungary                          48           HUN  1994            22
# Hungary                          48           HUN  1995            22
# Czech Republic                   47           CZE  1990            22
# Hungary                          48           HUN  1996            22
# Czech Republic                   47           CZE  1991            22
# Hungary                          48           HUN  1997            22
# Czech Republic                   47           CZE  1992            22
# Hungary                          48           HUN  1998            22
# ...

# %%
df_easterneurope_year = df_easterneurope.set_index(['year'])
df_easterneurope_year = df_easterneurope_year.groupby(df_easterneurope_year.index).sum()

# %%
df_easterneurope_year
# Out:
#       location_id  age_group_id  sex_id  cause_id   mean  lower  upper
# year
# 1990         1104           484      44     15312  435.6  330.0  514.3
# 1991         1104           484      44     15312  437.0  335.0  512.1
# 1992         1104           484      44     15312  441.2  338.7  515.3
# 1993         1104           484      44     15312  446.1  341.5  518.8
# 1994         1104           484      44     15312  450.1  346.9  524.0
# 1995         1104           484      44     15312  443.1  343.0  512.4
# 1996         1104           484      44     15312  426.8  336.5  491.9
# 1997         1104           484      44     15312  409.0  327.9  472.1
# 1998         1104           484      44     15312  393.2  318.3  454.2
# 1999         1104           484      44     15312  384.5  314.7  448.9
# 2000         1104           484      44     15312  378.9  313.6  444.3
# 2001         1104           484      44     15312  372.3  312.0  442.5
# ...

# %%
fig, ax = plt.subplots()

df_easterneurope_year.plot(x=df_easterneurope_year.index, y='mean', ax=ax, legend=False)
ax.set_title("")

# %%
#Western European

df_westerneurope = df.loc[df.index.isin(['Andorra', 'Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Israel', 'Italy', 'Liechtenstein', 'Luxembourg', 'Malta', 'Monaco', 'Netherlands', 'New Zealand', 'Norway', 'Portugal', 'San Marino', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom', 'United States'])]

# %%
df_westerneurope.sort_values(by='mean', ascending=False)
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# France                  80           FRA  2013            22       All Ages
# France                  80           FRA  1995            22       All Ages
# France                  80           FRA  1994            22       All Ages
# France                  80           FRA  1993            22       All Ages
# France                  80           FRA  1996            22       All Ages
# France                  80           FRA  1998            22       All Ages
# France                  80           FRA  2012            22       All Ages
# France                  80           FRA  1992            22       All Ages
# France                  80           FRA  1990            22       All Ages
# France                  80           FRA  1997            22       All Ages
# France                  80           FRA  1999            22       All Ages
# ...

# %%
df_westerneurope_year = df_westerneurope.set_index(['year'])
df_westerneurope_year = df_westerneurope_year.groupby(df_westerneurope_year.index).sum()

# %%
df_westerneurope_year
# Out:
#       location_id  age_group_id  sex_id  cause_id   mean  lower  upper
# year
# 1990         2283           572      52     18096  530.6  417.2  664.9
# 1991         2283           572      52     18096  526.9  418.2  661.6
# 1992         2283           572      52     18096  524.4  420.5  662.4
# 1993         2283           572      52     18096  521.9  420.2  667.4
# 1994         2283           572      52     18096  520.1  420.3  667.6
# 1995         2283           572      52     18096  520.0  420.7  672.2
# 1996         2283           572      52     18096  520.2  420.8  671.8
# 1997         2283           572      52     18096  521.6  420.1  672.8
# 1998         2283           572      52     18096  525.8  423.1  675.5
# 1999         2283           572      52     18096  528.1  424.9  674.4
# 2000         2283           572      52     18096  532.1  428.6  680.1
# 2001         2283           572      52     18096  539.0  432.3  688.2
# ...

# %%
fig, ax = plt.subplots()

df_westerneurope_year.plot(x=df_westerneurope_year.index, y='mean', ax=ax, legend=False)
ax.set_title("")

# %%
fig, ax = plt.subplots(figsize=(10,5))

# Use ax for both
df_westerneurope_year.plot(x=df_westerneurope_year.index, y='mean', ax=ax, label='Western Europe')
df_asiapac_year.plot(x=df_asiapac_year.index, y='mean', ax=ax, label='Asia Pacific')
df_africa_year.plot(x=df_africa_year.index, y='mean', ax=ax, label='Africa')
df_latinamerica_year.plot(x=df_latinamerica_year.index, y='mean', ax=ax, label='Latin America')
df_easterneurope_year.plot(x=df_easterneurope_year.index, y='mean', ax=ax, label='Eastern Europe')
ax.set_title("")

ax.xaxis.grid(which="major", color='MidnightBlue', linestyle=':', linewidth=1)
# Turn on a minor grid, a smaller grid, a more frequent grid
ax.xaxis.grid(which="minor", color='darkred', linestyle=":", linewidth=0.5)
ax.minorticks_on()

ax.set_axisbelow(True)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

plt.tick_params(
    which='major', # both major and minor ticks are affected
    top='off',   # ticks along the top edge are off
    left='off', # ticks along the right edge are off
    right='off', # ticks along the right edge are off
    bottom='off', # ticks along the bottom edge are on
    labelright='off',
    labeltop='off', # top label is on
    labelbottom='on')  # bottom label is on

plt.savefig("women_world_deaths.pdf", transparent=True)

# %%
#Let's see who's got it worst
df.sort_values(by='mean', ascending=False).head(60)
# Out:
#                location_id location_code  year  age_group_id age_group_name  \
# location_name
# Bolivia                121           BOL  1990            22       All Ages
# Bolivia                121           BOL  1991            22       All Ages
# Bangladesh             161           BGD  1990            22       All Ages
# Bolivia                121           BOL  1992            22       All Ages
# Bolivia                121           BOL  1993            22       All Ages
# Bolivia                121           BOL  1994            22       All Ages
# Bolivia                121           BOL  1995            22       All Ages
# Bangladesh             161           BGD  1991            22       All Ages
# Bolivia                121           BOL  1996            22       All Ages
# Bangladesh             161           BGD  1992            22       All Ages
# Bolivia                121           BOL  1997            22       All Ages
# ...

# %%
df_bolivia = df.loc[df.index.isin(['Bolivia'])]
df_bolivia_year = df_bolivia.set_index(['year'])
df_bolivia_year = df_bolivia_year.groupby(df_bolivia_year.index).sum()

# %%
df_bangladesh = df.loc[df.index.isin(['Bangladesh'])]
df_bangladesh_year = df_bangladesh.set_index(['year'])
df_bangladesh_year = df_bangladesh_year.groupby(df_bangladesh_year.index).sum()

# %%
df_india = df.loc[df.index.isin(['India'])]
df_india_year = df_india.set_index(['year'])
df_india_year = df_india_year.groupby(df_india_year.index).sum()

# %%
df_maldives = df.loc[df.index.isin(['Maldives'])]
df_maldives_year = df_maldives.set_index(['year'])
df_maldives_year = df_maldives_year.groupby(df_maldives_year.index).sum()

# %%
df_bhutan = df.loc[df.index.isin(['Bhutan'])]
df_bhutan_year = df_bhutan.set_index(['year'])
df_bhutan_year = df_bhutan_year.groupby(df_bhutan_year.index).sum()

# %%
fig, ax = plt.subplots(figsize=(10,5))

# Use ax for both
df_bolivia_year.plot(x=df_bolivia_year.index, y='mean', ax=ax, label='Bolivia')
df_bangladesh_year.plot(x=df_bangladesh_year.index, y='mean', ax=ax, label='Bangladesh')
df_india_year.plot(x=df_india_year.index, y='mean', ax=ax, label='India')
df_maldives_year.plot(x=df_maldives_year.index, y='mean', ax=ax, label='Maldives')
df_bhutan_year.plot(x=df_bhutan_year.index, y='mean', ax=ax, label='Bhutan')
ax.set_title("")

ax.xaxis.grid(which="major", color='MidnightBlue', linestyle=':', linewidth=1)
# Turn on a minor grid, a smaller grid, a more frequent grid
ax.xaxis.grid(which="minor", color='darkred', linestyle=":", linewidth=0.5)
ax.minorticks_on()

ax.set_axisbelow(True)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

plt.tick_params(
    which='major', # both major and minor ticks are affected
    top='off',   # ticks along the top edge are off
    left='off', # ticks along the right edge are off
    right='off', # ticks along the right edge are off
    bottom='off', # ticks along the bottom edge are on
    labelright='off',
    labeltop='off', # top label is on
    labelbottom='on')  # bottom label is on

ax.set_ylim((0,89))

plt.savefig("women_topfive_deaths.pdf", transparent=True)
