# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
listings = pd.read_csv("Summary_information_listings.csv")

# %%
listings.head()
# Out:
#          id                                name   host_id host_name  \
# 0   3943387  Cozy City Island Room/Private Bath  20433973     Julia
# 1   6627449      Large 1 BDRM in Great location  13886510    Arlene
# 2  11675715        Cozy 1 BR Basement Apartment  56714504     Josue
# 3   1886820      Quaint City Island Community.    9815788     Steve
# 4   5557381             Quaint City Island Home  28811542    Phoebe
#
#   neighbourhood_group neighbourhood   latitude  longitude        room_type  \
# 0               Bronx   City Island  40.839396 -73.781437     Private room
# 1               Bronx   City Island  40.849775 -73.786609  Entire home/apt
# 2               Bronx   City Island  40.850376 -73.784681  Entire home/apt
# 3               Bronx   City Island  40.841144 -73.783052  Entire home/apt
# 4               Bronx   City Island  40.850024 -73.789328     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0     65               1                 15  2016-06-10               0.75
# 1    125               3                 10  2016-06-25               0.82
# 2     79               1                 16  2016-06-12               4.57
# 3    300               7                  0         NaN                NaN
# 4     59               1                 59  2016-06-29               4.36
#
#    calculated_host_listings_count  availability_365
# 0                               1               345
# 1                               1               336
# 2                               1               305
# 3                               1               206
# 4                               1               293

# %%
listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
area = pd.read_csv("neighbourhoods.csv")
#area

# %%
listings['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          3455
# Bedford-Stuyvesant    2546
# Harlem                2373
# East Village          1977
# Upper West Side       1904
# Bushwick              1754
# Hell's Kitchen        1495
# Upper East Side       1490
# Crown Heights         1258
# Chelsea               1079
# Name: neighbourhood, dtype: int64

# %%
listings['room_type'].value_counts()
# Out:
# Entire home/apt    19994
# Private room       17589
# Shared room         1227
# Name: room_type, dtype: int64

# %%
room = listings[listings['room_type']!='Entire home/apt']
apt = listings[listings['room_type']=='Entire home/apt']

# %%
room['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          1876
# Bedford-Stuyvesant    1489
# Harlem                1439
# Bushwick              1300
# East Village           769
# Crown Heights          712
# Upper West Side        702
# Hell's Kitchen         629
# Washington Heights     569
# East Harlem            555
# Name: neighbourhood, dtype: int64

# %%
apt['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          1579
# East Village          1208
# Upper West Side       1202
# Bedford-Stuyvesant    1057
# Upper East Side       1015
# Harlem                 934
# Hell's Kitchen         866
# Chelsea                816
# West Village           669
# Midtown                663
# Name: neighbourhood, dtype: int64

# %%
plt.style.use("fivethirtyeight")

# %%
fig, ax = plt.subplots()

ax.set_title("Top 10 Neighbourhoods With Entire Apartment")

ax.grid(linestyle="")
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tick_params(
which ='major',
top = 'off',
left = 'off',
right = 'off',
bottom = 'off',
labeltop='off',
labelbottom='on')

apt['neighbourhood'].value_counts().head(10).plot(kind='barh')

plt.savefig("neibourhood-apt.pdf",transparent=True)

# %%
fig, ax = plt.subplots()

ax.set_title("Top 10 Neighbourhoods With Private/Shared room")

ax.grid(linestyle="")
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tick_params(
which ='major',
top = 'off',
left = 'off',
right = 'off',
bottom = 'off',
labeltop='off',
labelbottom='on')

room['neighbourhood'].value_counts().head(10).plot(kind='barh')

plt.savefig("neibourhood-room.pdf",transparent=True)

# %%
fig, ax = plt.subplots()

ax.set_title("Top 10 Neighbourhoods Prefer To Rent In NYC")

ax.grid(linestyle="")
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tick_params(
which ='major',
top = 'off',
left = 'off',
right = 'off',
bottom = 'off',
labeltop='off',
labelbottom='on')

listings['neighbourhood'].value_counts().head(10).plot(kind='barh')

plt.savefig("neibourhood-top.pdf",transparent=True)

# %%
listings['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          3455
# Bedford-Stuyvesant    2546
# Harlem                2373
# East Village          1977
# Upper West Side       1904
# Bushwick              1754
# Hell's Kitchen        1495
# Upper East Side       1490
# Crown Heights         1258
# Chelsea               1079
# Name: neighbourhood, dtype: int64
