# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['pdf.fonttype'] = 42
import dateutil.parser
import numpy as NP
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/mercybenzaquen/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))

# %%
df = pd.read_csv("Venezuela_minimum_wage_vs_food_prices.csv")
df
# Out:
#      Fecha   Ano      Mes  Canasta Alimentaria (BsF)  Sueldo Minimo (BsF)  \
# 0   6/1/16  2016    Junio                  184072.39             15051.15
# 1   5/1/16  2016    Mayo                   152255.67             15051.15
# 2   4/1/16  2016   Abril                   115738.04             11578.00
# 3   3/1/16  2016   Marzo                    89156.31             11578.00
# 4   2/1/16  2016  Febrero                   75623.22              9648.18
# 5   1/1/16  2016    Enero                   68217.09              9648.18
# 6   6/1/15  2015    Junio                   21383.38              6746.98
# 7   5/1/15  2015    Mayo                    17833.03              6746.98
# 8   4/1/15  2015   Abril                    16500.74              5622.48
# 9   3/1/15  2015   Marzo                    20919.53              5622.48
# 10  2/1/15  2015  Febrero                   14450.08              5622.48
# 11  1/1/15  2015    Enero                   13645.06              4889.11
#
# ...

# %%
def parse_date (obj_date):
    return dateutil.parser.parse(obj_date)

df['Date']= df['Fecha'].apply(parse_date)
df
# Out:
#      Fecha   Ano      Mes  Canasta Alimentaria (BsF)  Sueldo Minimo (BsF)  \
# 0   6/1/16  2016    Junio                  184072.39             15051.15
# 1   5/1/16  2016    Mayo                   152255.67             15051.15
# 2   4/1/16  2016   Abril                   115738.04             11578.00
# 3   3/1/16  2016   Marzo                    89156.31             11578.00
# 4   2/1/16  2016  Febrero                   75623.22              9648.18
# 5   1/1/16  2016    Enero                   68217.09              9648.18
# 6   6/1/15  2015    Junio                   21383.38              6746.98
# 7   5/1/15  2015    Mayo                    17833.03              6746.98
# 8   4/1/15  2015   Abril                    16500.74              5622.48
# 9   3/1/15  2015   Marzo                    20919.53              5622.48
# 10  2/1/15  2015  Febrero                   14450.08              5622.48
# 11  1/1/15  2015    Enero                   13645.06              4889.11
#
# ...

# %%
df.index= df['Date']

# %%
df_2016= df[df['Ano']== 2016]

# %%
df_2015= df[df['Ano']== 2015]

# %%
df_2016.sort()
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':
#              Fecha   Ano      Mes  Canasta Alimentaria (BsF)  \
# Date
# 2016-01-01  1/1/16  2016    Enero                   68217.09
# 2016-02-01  2/1/16  2016  Febrero                   75623.22
# 2016-03-01  3/1/16  2016   Marzo                    89156.31
# 2016-04-01  4/1/16  2016   Abril                   115738.04
# 2016-05-01  5/1/16  2016    Mayo                   152255.67
# 2016-06-01  6/1/16  2016    Junio                  184072.39
#
#             Sueldo Minimo (BsF)  Cesta Ticket  Sueldo_Total       Date
# Date
# 2016-01-01              9648.18        6750.0      16398.18 2016-01-01
# 2016-02-01              9648.18        7975.0      17623.18 2016-02-01
# 2016-03-01             11578.00       13275.0      24853.00 2016-03-01
# 2016-04-01             11578.00       13275.0      24853.00 2016-04-01
# ...

# %%
df_2015.sort()
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':
#              Fecha   Ano      Mes  Canasta Alimentaria (BsF)  \
# Date
# 2015-01-01  1/1/15  2015    Enero                   13645.06
# 2015-02-01  2/1/15  2015  Febrero                   14450.08
# 2015-03-01  3/1/15  2015   Marzo                    20919.53
# 2015-04-01  4/1/15  2015   Abril                    16500.74
# 2015-05-01  5/1/15  2015    Mayo                    17833.03
# 2015-06-01  6/1/15  2015    Junio                   21383.38
#
#             Sueldo Minimo (BsF)  Cesta Ticket  Sueldo_Total       Date
# Date
# 2015-01-01              4889.11        2095.5       6984.61 2015-01-01
# 2015-02-01              5622.48        2475.0       8097.48 2015-02-01
# 2015-03-01              5622.48        2475.0       8097.48 2015-03-01
# 2015-04-01              5622.48        2475.0       8097.48 2015-04-01
# ...

# %%
fig, ax= plt.subplots(figsize=(12,5))
df_2016.sort().plot(kind= "barh", x= 'Date', y= 'Canasta Alimentaria (BsF)', ax=ax, stacked= True)
df_2016.sort().plot(kind= "barh", x= 'Date', y= 'Sueldo_Total', ax=ax, stacked= True, color='green')


# ax.set_xlim(('2016-01-01','2016-06-01'))
# ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
# ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)


# ax.yaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
# ax.yaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)



# ax.xaxis.grid(which= 'minor',color='darkred', linestyle='-.', linewidth=0.25)
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'on', bottom= 'on', labeltop= 'off', labelbottom= 'on')

ax.minorticks_on()
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   app.launch_new_instance()

# %%
# fig, ax= plt.subplots(figsize=(12,5))
# df.resample('M').plot(y= 'Canasta Alimentaria (BsF)')

# %%
fig, ax= plt.subplots(figsize=(12,5))
m= df.plot(x= 'Date', y= 'Canasta Alimentaria (BsF)', ax=ax)
n= df.plot(x= 'Date', y= 'Sueldo_Total', ax=ax)


ax.set_xlim(('2016-01-01','2016-06-01'))
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)


ax.yaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.yaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)



ax.xaxis.grid(which= 'minor',color='darkred', linestyle='-.', linewidth=0.25)
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'on', bottom= 'off', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
plt.savefig("Venezuela_minimum_wage_vs_food_prices_2.pdf", transparent=True)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# %%
df_alimentos = pd.read_excel("Food_prices.xlsx")

# %%
df_cereales = df_alimentos[df_alimentos['grupo']== 'CEREALES Y PRODUCTOS DERIVADOS']
df_carnes = df_alimentos[df_alimentos['grupo']== 'CARNES Y SUS PREPARADOS']
df_pescados = df_alimentos[df_alimentos['grupo']== 'PESCADOS Y MARISCOS']
df_leche_derivados = df_alimentos[df_alimentos['grupo']== 'LECHE, QUESOS Y HUEVOS']
df_aceites = df_alimentos[df_alimentos['grupo']== 'GRASAS Y ACEITES']
df_frutas = df_alimentos[df_alimentos['grupo']== 'FRUTAS Y HORTALIZAS']
df_raices =df_alimentos[df_alimentos['grupo']== 'RAÍCES, TUBÉRCULOS Y OTROS']
df_caraotas=df_alimentos[df_alimentos['grupo']== 'CARAOTAS, ARVEJAS Y LENTEJAS']
df_azucar_sal=df_alimentos[df_alimentos['grupo']== 'AZÚCAR Y SAL']
df_salsas=df_alimentos[df_alimentos['grupo']== 'SALSA Y MAYONESA']
df_cafe=df_alimentos[df_alimentos['grupo']== 'CAFÉ, TÉ Y SIMILARES']

# %%
df_cereales
# Out:
#                         producto   2015    2016  diferencia_en_bsf  \
# 0                      Arroz 1kg  27.00  567.41             540.41
# 1  Avena y sus derivados 400 gr   30.36  491.73             461.37
# 2   Harina de maíz precocida 1kg  31.60  375.20             343.60
# 3            Harina de Trigo 1kg  67.60  962.50             894.90
# 4      Pastas alimenticias 1/2kg  35.18  594.25             559.07
# 5  Pan de trigo Canilla X Unidad  25.00  251.29             226.29
#
#    diferencia_por                           grupo
# 0     2001.518519  CEREALES Y PRODUCTOS DERIVADOS
# 1     1519.664032  CEREALES Y PRODUCTOS DERIVADOS
# 2     1087.341772  CEREALES Y PRODUCTOS DERIVADOS
# 3     1323.816568  CEREALES Y PRODUCTOS DERIVADOS
# 4     1589.169983  CEREALES Y PRODUCTOS DERIVADOS
# 5      905.160000  CEREALES Y PRODUCTOS DERIVADOS

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_cereales.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_cereales.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_carnes.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_carnes.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_pescados.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_pescados.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_leche_derivados.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_leche_derivados.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_aceites.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_aceites.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(20,16))
df_frutas.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_frutas.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_raices.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_raices.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_caraotas.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_caraotas.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_azucar_sal.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_azucar_sal.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(10,6))
df_salsas.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_salsas.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(5,2))
df_cafe.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_cafe.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)

# %%
fig, ax= plt.subplots(figsize=(20,40))
df_alimentos.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_alimentos.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle=':', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle=':', linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-33434e332c2e> in <module>()
#       1 fig, ax= plt.subplots(figsize=(20,40))
# ----> 2 df_alimentos.plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
#       3 df_alimentos.plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
#       4 plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
#       5 plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
#
# NameError: name 'df_alimentos' is not defined

# %%
df_selected_food = pd.read_excel("Workbook7.xlsx")

# %%
df_selected_food
# Out:
#                                 producto   2015     2016  diferencia_en_bsf  \
# 0                                   Rice   27.0   567.41             540.41
# 1                            Corn flour    31.6   375.20             343.60
# 2   "Canilla" traditional bread (1 unit)   25.0   251.29             226.29
# 3                            Ground beef  920.0  4148.24            3228.24
# 4                           Chicken meat  288.0  2447.22            2159.22
# 5                       Coro-coro (fish)  376.0  2167.20            1791.20
# 6                        Eggs (1 carton)  496.0  3056.00            2560.00
# 7                          Powdered milk  244.0  1545.00            1301.00
# 8                           White cheese  614.0  3472.06            2858.06
# 9                          Vegetable oil   50.8   576.00             525.20
# 10                               Bannana   86.6   781.74             695.14
# ...

# %%
fig, ax= plt.subplots(figsize=(20,40))
df_selected_food.sort_values(2016).plot(kind='barh', x='producto', y=2016, ax=ax, stacked= True)
df_selected_food.sort_values(2016).plot(kind='barh', x='producto', y=2015, ax=ax, stacked= True, color= 'green')
plt.tick_params(which = 'major', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
plt.tick_params(which = 'minor', top= 'off',right='off', left= 'off', bottom= 'on', labeltop= 'off', labelbottom= 'on')
ax.minorticks_on()
ax.xaxis.grid(which= 'major', color='grey', linestyle='-', linewidth=1)
ax.xaxis.grid(which= 'minor', color='grey', linestyle='-', linewidth=1)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.savefig("Venezuela_food_prices_4.pdf", transparent= True)
