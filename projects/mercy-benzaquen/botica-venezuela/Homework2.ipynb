# %%
api_key = "UsOs1k6E0jc3BfEDj5V3WINoF"



api_secret= "yVgdfaJ2ikPoHRSJ84jBVvliqZAVe2Hpjgiawj6FeIJaciaFZj"



access_token= "752143572003061760-3joylZ5fIOwb4tE2GsgcEFcc6VxyqOT"



token_secret= "boCqol91w3Zkwj4M65raESS8Xl5xQRO5K47CTAarAiemy"

# %%
# !pip3 install twython

# %%
# !pip install matplotlib

# %%
import twython
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/mercybenzaquen/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))

# %%
import matplotlib
plt.rcParams['pdf.fonttype'] = 42

# %%
twitter = twython.Twython(api_key, api_secret, access_token, token_secret)

# %%
all_tweets= twitter.get_user_timeline(count= 500, include_rts=False, exclude_replies=True)

# %%
all_tweets[0].keys()
# Out:
# dict_keys(['is_quote_status', 'in_reply_to_user_id_str', 'lang', 'place', 'geo', 'contributors', 'created_at', 'in_reply_to_status_id_str', 'favorite_count', 'truncated', 'in_reply_to_status_id', 'id_str', 'retweeted', 'id', 'retweet_count', 'in_reply_to_user_id', 'coordinates', 'in_reply_to_screen_name', 'text', 'user', 'source', 'entities', 'favorited'])

# %%
all_tweets[0]['text']
# Out:
# 'Pedro Riego solicita #micardis de 80mg y #amlodipina de 5mg o 10mg en #CiudadGuayana 04148561175 #ServicioPublico via @LaTuristaKAM'

# %%
all_tweets[0]['coordinates']

# %%
tweet_text= []
for tweet in all_tweets:
    print(tweet['text'])
    tweet_text.append(tweet['text'])
# Out:
# Pedro Riego solicita #micardis de 80mg y #amlodipina de 5mg o 10mg en #CiudadGuayana 04148561175 #ServicioPublico via @LaTuristaKAM
# Solicito para mi arritmia e hipertensión #ManidonRetard 240mg en #CiudadGuayana escribirme si lo ubican. GRACIAS! via @LaTuristaKAM
# NECESITO CON URGENCIA PARA MI QUIMIO TAXOTERE, ONICIT, EMEND, RECORMON Y GRANOCITE. VIVO EN VALENCIA 4244198538 via @LCarolinaGA
# Tengo glucofage. Soy Alberto tel 4143355861 @liorelisTME @meblar222 @lasister73 @Danisalva1978 via @albertomann18
# #SeSolicita para mi abuelo ISMO de 20MG, #CiudadGuayana o #Caracas Contactarme aquí https://t.co/gH6UlcH4LR via @LaTuristaKAM
# Por favor me urge Espironolactona de 25 mgs y Quetiapina de 100 mgs.  Es para mi mamá.  Gracias via @Namasteluz
# Bt , solicito betaduo inyectable 2 cc, en caracas, gcs via @VR1Fan
# Los tienes? Envíame un MENSAJE PRIVADO y taggea (@) al usuario necesitado. O busca su pedido en mi profile y respnde https://t.co/cRCJh1gLQ8
# ...

# %%
len(all_tweets)
# Out:
# 128

# %%
# !pip install textblob

# %%
# !python3 -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/mercybenzaquen/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mercybenzaquen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mercybenzaquen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mercybenzaquen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/mercybenzaquen/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/mercybenzaquen/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
Hysaar de 100mg. Buscapina plus, Cataflan via @Mylin42
Mi correo aljome@gmail.com via @Mylin42
Necesito Losartan 50 mg,  04249545709 via @corneadorcbl
Hola. Necesito ativan de 2 mg para mi mamá. Mi número de tlf 04147566293. Urgente via @Yennifer1966
Necesitó aprovel  y olanzapina soy de maracay y mi tlf 04243650115 via @oswaldofiguera1
Necesito salbutanol via @emmy_benzaquen
Necesito Cedax pediiatrico via @pulkale
Necesito Cedax pediatrician via @pulkale
Necesito Tangorex 200 mg via @pulkale
Necessities Cedax pediatrico via @pulkale
Necesito livial o tibolona urgente ,correo macogu@cantv.net via @Macogu10
Por favor  Tangorex 200 mg  bastante URGENTE gracias via @pulkale
Sigan a @botvenezuela via @teresa_perez100
Hola necesito Glucofage de 500 y Femelle via @lasister73
Necesito carvedilol 6.25 mg joellevy3@gmail.com via @joellevy
Necesito nefrotal H 100 mg. joellevy3@gmail.com via @joellevy
Tengo una caja de Euthyrox de 75 mgs que no necesito. via @Paugamus
Necesito Ombrize  y spiriva. Mi nombre maira ñañez 04148120444 via @mairak1
Necesito Glucofage y Losartan para paciente con tratamiento de por Vida.. 04142360087 muchas gracias via @Danisalva1978
Tengo una caja de Euthyrox de 75 mgs que no necesito. Mi correo gamus.paulina@gmail.com via @Paugamus
Necesito livial o tibolona urgente ,correo macogu@cantv.net via @Macogu10
Nombre jorge necesito cefadroxilo 250 o 500 mg suspensión via @jsonnen
Necesito Hytrin 5mg. @monsi18 via @monsi18""")

# %%
for item in blob.words:
    print(item)
# Out:
# Buenos
# dias
# necesito
# livial
# o
# tibolona
# gracias
# via
# CLAIRET_PL
# buscando
# quietapina/quietidin
# y
# akineton
# para
# mi
# madre
# con
# demencia
# senil
# y
# parkinsonismo
# Eternamente
# agradecida
# ❤
# via
# BettyvixenLuz
# Buekos
# dias
# para
# tratamiento
# medico
# requiero
# femelle
# de
# 20
# mcg
# en
# san
# Cristóbal
# via
# claudialex1
# Buekos
# dias
# para
# tratamiento
# medico
# requiero
# femelle
# de
# 20
# mcg
# en
# tachira
# via
# claudialex1
# Urgente
# femara
# amiga
# cancer
# d
# mama
# necesito
# urgente
# via
# milayance
# Es
# para
# una
# amiga
# que
# sufre
# de
# un
# tumor
# en
# la
# hipófisis
# son
# solo
# 4
# ampo
# via
# mariale11276
# Hola
# necesito
# sandostatin
# lar
# de
# 20
# mg
# María
# Ramos
# 04146911141
# Caracas
# via
# mariale11276
# Necesito
# para
# mi
# esposo
# VALSARTAN
# 160mg
# Punto
# Fijo
# Falcón
# via
# rosibarroso
# Urgente
# necesito
# femala
# mila
# 04241077454
# ccas
# mi
# amiga
# tiene
# cancer
# ...

# %%
from collections import Counter
c= Counter(blob.words)
c.most_common()
# Out:
# [('via', 109),
#  ('de', 63),
#  ('Necesito', 47),
#  ('o', 25),
#  ('mg', 25),
#  ('para', 24),
#  ('en', 23),
#  ('necesito', 21),
#  ('y', 16),
#  ('urgente', 14),
#  ('LiorelisTME', 13),
#  ('tratamiento', 13),
#  ('Hola', 12),
#  ('mi', 11),
#  ('100mg', 10),
#  ('San', 10),
#  ('gmail.com', 10),
#  ('Gracias', 8),
#  ('50mg', 8),
#  ('con', 8),
#  ('por', 7),
#  ('claudialex1', 6),
#  ('ontimonsa', 6),
#  ('requiero', 6),
#  ('favor', 6),
#  ('URGENTE', 6),
#  ('caja', 6),
#  ('Losartan', 6),
#  ('Maracaibo', 6),
#  ('Mi', 6),
#  ('una', 6),
#  ('Glucofage', 6),
#  ('Venezuela', 6),
#  ('estado', 5),
#  ('pulkale', 5),
#  ('Falcón', 5),
#  ('mgs', 5),
#  ('continúo', 5),
#  ('Vivo', 5),
#  ('vivo', 5),
#  ('Caracas', 5),
#  ('Cristóbal', 5),
#  ('soy', 5),
#  ('ampollas', 5),
#  ('Cristóbal-Táchira', 5),
#  ('contacto', 5),
#  ('XR', 4),
#  ('es', 4),
#  ('Etaconil', 4),
#  ('simancas', 4),
#  ('Táchira', 4),
#  ('monicasantana11', 4),
#  ('ALACTIN', 4),
#  ('urgencia', 4),
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("Cuenta_medicamentos_23Julio_1.2.xlsx")
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
df
# Out:
#          Medicamentos  Pedidos  \
# 0           Losartan       7.0
# 1           Glucofage      4.0
# 2           Tibolona       3.0
# 3             Livial       2.0
# 4             Janumet      2.0
# 5             Femelle      2.0
# 6              Galvus      2.0
# 7          Carvedilol      2.0
# 8             Betaduo      1.0
# 9             Alactin      1.0
# 10          Quietidin      1.0
# 11            Sinemet      1.0
# 12           Geslutin      1.0
# 13            Provera      1.0
# 14           Dostinex      1.0
# 15           Etaconil      1.0
# 16   Cedax Pediátrico      1.0
# 17          Minigynon      1.0
# 18            Tygacil      1.0
# 19        Allopurinol      1.0
# 20           Euthyrox      1.0
# 21         Quietapina      1.0
# 22  Pañales de adulto      1.0
# 23          Aldactone      1.0
# 24           Glutapak      1.0
# 25             Xareto      1.0
# 26           Euthirox      1.0
# 27             Soriel      1.0
# 28      oxcarbazepina      1.0
# ...

# %%
ax= df.dropna().head(20).sort('Pedidos').plot(kind='barh', x='Medicamentos', y='Pedidos', figsize=(10,5), width= 0.70)
ax.set_title("BOTica análisis: 10 medicamentos más pedidos")
ax.set_xlabel("Número de usuarios necesitados")
ax.set_ylabel("Nombre del Medicamento")
#ax.legend(loc='upper left', prop={'size':14}, bbox_to_anchor=(1,1))
ax.legend(['Division 1', 'Division 2', 'Division 3', 'Division 4'])
plt.tick_params(which = 'major', top= 'off',right='off', bottom= 'on', left= 'off', labeltop= 'off', labelbottom= 'on', labelleft= 'on')


plt.savefig("medicamentos.pdf",transparent=True)
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
