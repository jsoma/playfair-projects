# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
plt.style.use('ggplot')
import dateutil.parser
import datetime
datetime
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/mercybenzaquen/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))

# %% [markdown]
# # The following is data that I will use while I wait for the data from FORO PENAL.. So it is just practice to get an idea of what I want

# %%
df = pd.read_excel("project_4_chart_1_political_prisoners_unnoficial_data.xlsx")
df.head()
# Out:
#     Fecha de detencion                                             Nombre  \
# 1.0         2003-04-21  Erasmo José Bolívar (Agente de la Policia Metr...
# 2.0         2003-04-21  Héctor José Rovaín (Inspector Jefe de la Polic...
# 3.0         2016-08-10  Luis Molina Cerrada (Distinguido de la Policía...
# 4.0         2003-04-21  Arube Pérez Salazar (Cabo 1ro de la Policía Me...
# 5.0         2003-04-21  Marco Hurtado (Sub-Comisario de la Policia Met...
#
#                     Sitio de reclusión Tiempo detenido  Unnamed: 4
# 1.0  CENAPROMIL “Ramo Verde” (Miranda)   12 años preso         NaN
# 2.0  CENAPROMIL “Ramo Verde” (Miranda)   12 años preso         NaN
# 3.0  CENAPROMIL “Ramo Verde” (Miranda)   12 años preso         NaN
# 4.0  CENAPROMIL “Ramo Verde” (Miranda)   12 años preso         NaN
# 5.0  CENAPROMIL “Ramo Verde” (Miranda)   12 años preso         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 88 entries, 1.0 to 11.0
# Data columns (total 5 columns):
# Fecha de detencion    87 non-null datetime64[ns]
# Nombre                87 non-null object
# Sitio de reclusión    87 non-null object
# Tiempo detenido       77 non-null object
# Unnamed: 4            0 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 4.1+ KB

# %%
dateutil.parser.parse("2003-04-21")
# Out:
# datetime.datetime(2003, 4, 21, 0, 0)

# %%
df.index = df['Fecha de detencion']

# %%
df['date']  = pd.to_datetime(df['Fecha de detencion'])

# %%
len(df['2014'])
# Out:
# 53

# %%
#df.resample('M').count()

# %%
fig, ax = plt.subplots()
df.resample('M').count().plot(y='Nombre', figsize= (10,7), ax=ax)
plt.savefig("project4_political_prisoners.pdf", transparent=True)

# %%
df.resample('A').count().plot(y='Nombre', figsize= (10,7), ax=ax)

# %% [markdown]
# # FORO PENAL DATA
# This is the biggest non-profit that has a record of political prisoners in Venezuela. I did not hear back from them so I am scrapping the data they have in their website, although I know they have additional info that would be interesting.

# %%
# !pip3 install bs4
# Out:
# Requirement already satisfied (use --upgrade to upgrade): bs4 in /usr/local/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): beautifulsoup4 in /usr/local/lib/python3.5/site-packages (from bs4)

# %%
from bs4 import BeautifulSoup

# %%
from urllib.request import urlopen

html_str = urlopen('https://foropenal.com/presos-politicos/lista-publica').read()

# %%
html_str
# Out:
# b'<!DOCTYPE html>\n<html lang="es" class="no-js" dir="ltr" prefix="fb: http://www.facebook.com/2008/fbml content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="profile" href="http://www.w3.org/1999/xhtml/vocab" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="shortcut icon" href="https://foropenal.com/sites/default/files/faviconforopenal_0.ico" type="image/vnd.microsoft.icon" />\n  <title>Listado de Presos Pol\xc3\xadticos | Foro Penal Venezolano</title>\n  <link type="text/css" rel="stylesheet" href="https://foropenal.com/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://foropenal.com/sites/default/files/css/css_cvSXG2klPlT6C6v6dkPfO74ka3ruk7bMxdRYIkMwit0.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://foropenal.com/sites/default/files/css/css_7_NjOFC8f8Ned9j5gebYUz6VaZTLVSWZfMZq9_augpI.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://foropenal.com/sites/default/files/css/css_Jda_PbIkqT53PlohP4Xo8pSiLrvlUxWY_ef2XInaDdg.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://foropenal.com/sites/default/files/css-locked.css?ob3d8g" media="all" />\n  <!-- HTML5 element support for IE6-8 -->\n  <!--[if lt IE 9]>\n    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>\n  <![endif]-->\n  <script src="https://foropenal.com/sites/default/files/js/js_JLxuxbhhrFRy-sBnijHkR0TGGHgiukMPv94zvDWgQ3g.js"></script>\n<script src="https://foropenal.com/sites/default/files/js/js_90Ag6l1CFsAyJAKiuRVgq-spTLL1A-4lrtFI9gbaqcw.js"></script>\n<script src="https://foropenal.com/sites/default/files/js/js_UbSGaxxVSiJHFnGvpR6xvtQlZ57n1wrUA46sIa0ppAk.js"></script>\n<script src="https://foropenal.com/sites/default/files/js/js_vzUiL4k7pRUp0TAgSFQCJ0F9asMl39gCqbtk8NRJcgY.js"></script>\n<script>jQuery.extend(Drupal.settings, {"basePath":"\\/","pathPrefix":"","ajaxPageState":{"theme":"zenon","theme_token":"2VYVDSUcZf7ZBZhHOezjPtMBM6Y9dwexwrRI0h74Utc","js":{"sites\\/all\\/modules\\/contrib\\/browserclass\\/browserclass.js":1,"sites\\/all\\/modules\\/addthis\\/addthis.js":1,"sites\\/all\\/themes\\/biotic\\/js\\/bootstrap.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/replace\\/jquery\\/1.8\\/jquery.min.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"sites\\/all\\/modules\\/contrib\\/admin_menu\\/admin_devel\\/admin_devel.js":1,"sites\\/all\\/modules\\/biotic\\/tb_menu\\/js\\/tb-menu.js":1,"public:\\/\\/languages\\/es_yRL_KNNjjMG0L1jaeyUnwVEDzL1lHZJWX2A24KZNgfc.js":1,"sites\\/all\\/modules\\/contrib\\/responsive_menus\\/styles\\/meanMenu\\/jquery.meanmenu.min.js":1,"sites\\/all\\/modules\\/contrib\\/responsive_menus\\/styles\\/meanMenu\\/responsive_menus_mean_menu.js":1,"sites\\/all\\/themes\\/biotic\\/assets\\/js\\/vendor\\/jquery.waitforimages.min.js":1,"sites\\/all\\/themes\\/biotic\\/js\\/biotic.js":1,"sites\\/all\\/themes\\/zenon\\/assets\\/js\\/vendor.min.js":1,"sites\\/all\\/themes\\/zenon\\/assets\\/js\\/zenon.min.js":1,"sites\\/all\\/themes\\/zenon\\/assets\\/js\\/Chart.min.js":1,"sites\\/all\\/themes\\/biotic\\/js\\/webfont.js":1},"css":{"modules\\/system\\/system.base.css":1,"sites\\/all\\/modules\\/counter\\/counter.css":1,"sites\\/all\\/modules\\/contrib\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/contrib\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"modules\\/field\\/theme\\/field.css":1,"sites\\/all\\/modules\\/biotic\\/tb_menu\\/css\\/tb-menu ...

# %%
document = BeautifulSoup(html_str, "html.parser")

# %%
document
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="es" prefix="fb: http://www.facebook.com/2008/fbml content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
# <head>
# <meta charset="utf-8">
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <link href="https://foropenal.com/sites/default/files/faviconforopenal_0.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <title>Listado de Presos Políticos | Foro Penal Venezolano</title>
# <link href="https://foropenal.com/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://foropenal.com/sites/default/files/css/css_cvSXG2klPlT6C6v6dkPfO74ka3ruk7bMxdRYIkMwit0.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://foropenal.com/sites/default/files/css/css_7_NjOFC8f8Ned9j5gebYUz6VaZTLVSWZfMZq9_augpI.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://foropenal.com/sites/default/files/css/css_Jda_PbIkqT53PlohP4Xo8pSiLrvlUxWY_ef2XInaDdg.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://foropenal.com/sites/default/files/css-locked.css?ob3d8g" media="all" rel="stylesheet" type="text/css"/>
# <!-- HTML5 element support for IE6-8 -->
# <!--[if lt IE 9]>
#     <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#   <![endif]-->
# <script src="https://foropenal.com/sites/default/files/js/js_JLxuxbhhrFRy-sBnijHkR0TGGHgiukMPv94zvDWgQ3g.js"></script>
# <script src="https://foropenal.com/sites/default/files/js/js_90Ag6l1CFsAyJAKiuRVgq-spTLL1A-4lrtFI9gbaqcw.js"></script>
# <script src="https://foropenal.com/sites/default/files/js/js_UbSGaxxVSiJHFnGvpR6xvtQlZ57n1wrUA46sIa0ppAk.js"></script>
# <script src="https://foropenal.com/sites/default/files/js/js_vzUiL4k7pRUp0TAgSFQCJ0F9asMl39gCqbtk8NRJcgY.js"></script>
# <script>jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"zenon","theme_token":"2VYVDSUcZf7ZBZhHOezjPtMBM6Y9dwexwrRI0h74Utc","js":{"sites\/all\/modules\/contrib\/browserclass\/browserclass.js":1,"sites\/all\/modules\/addthis\/addthis.js":1,"sites\/all\/themes\/biotic\/js\/bootstrap.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.8\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/admin_menu\/admin_devel\/admin_devel.js":1,"sites\/all\/modules\/biotic\/tb_menu\/js\/tb-menu.js":1,"public:\/\/languages\/es_yRL_KNNjjMG0L1jaeyUnwVEDzL1lHZJWX2A24KZNgfc.js":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/meanMenu\/jquery.meanmenu.min.js":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/meanMenu\/responsive_menus_mean_menu.js":1,"sites\/all\/themes\/biotic\/assets\/js\/vendor\/jquery.waitforimages.min.js":1,"sites\/all\/themes\/biotic\/js\/biotic.js":1,"sites\/all\/themes\/zenon\/assets\/js\/vendor.min.js":1,"sites\/all\/themes\/zenon\/assets\/js\/zenon.min.js":1,"sites\/all\/themes\/zenon\/assets\/js\/Chart.min.js":1,"sites\/all\/themes\/biotic\/js\/webfont.js":1},"css":{"modules\/system\/system.base.css":1,"sites\/all\/modules\/counter\/counter.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/biotic\/tb_menu\/css\/tb-menu.css":1,"sites\/all\/modules\/biotic\/tb_menu\/css\/style-default.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/meanMenu\/meanmenu.min.css":1,"sites\/all\/libraries\/fontawesome\/css\/font-awesome.css":1,"sites\/all\/themes\/biotic\/assets\/css\/vendor\/animate.min.css":1,"sites\/all\/themes\/biotic\/css\/overrides.css":1,"sites\/all\/themes\/biotic\/css\/biotic.css":1,"sites\/all\/themes\/zenon\/assets\/css\/vendor.min.css":1,"sites\/all\/themes\/zenon\/assets\/css\/zenon.min.css":1,"sites\/all\/themes\/zenon\/assets\/css\/style.custom.css":1,"public:\/\/css-locked.css":1}},"urlIsAjaxTrusted":{"\/presos-politicos\/lista-publica":true},"responsive_menus":[{"selectors":"#main-menu","trigger_txt":"\u003Cspan \/\u003E\u003Cspan \/\u003E\u003Cspan \/\u003E","close_txt":"X","close_size":"18px","position":"center","media_size":"980","show_children":"1","expand_children":"1","expand_txt":"\u2192","contract_txt":"\u2193","remove_attrs":"1","responsive_menus_style":"mean_menu"}],"webfontloader":{"fonts":["PT+Sans:400,700:latin","Droid+Serif:400,400italic:latin","Merienda:400:latin","Gochi+Hand:400:latin"]},"zenon":{"debug":0},"pathToTheme":"sites\/all\/themes\/zenon","bootstrap":{"anchorsFix":0,"anchorsSmoothScrolling":0,"popoverEnabled":0,"popoverOptions":{"animation":1,"html":0,"placement":"right","selector":"","trigger":"click","title":"","content":"","delay":0,"container":"body"},"tooltipEnabled":0,"tooltipOptions":{"animation":1,"html":0,"placement":"auto left","selector":"","trigger":"hover focus","delay":0,"container":"body"}}});</script>
# </meta></meta></head>
# <body class="html not-front not-logged-in no-sidebars page-presos-politicos page-presos-politicos-lista-publica">
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Pasar al contenido principal</a>
# </div>
# <div class="global-wrapper">
# <div class="wrapper clearfix sticky-header" id="globalheaderwrapper">
# <div class="container" id="globalheadercontainer">
# <div id="globalheader">
# <div class="row">
# <div class="region region-navigation col-lg-12 z-index-10">
# <div class="row-fluid">
# <div class="block block-delta-blocks col-xs-12 col-sm-12 col-md-3 col-lg-3 text-center-xs text-center-sm text-left-lg text-left-md clearfix" id="block-delta-blocks-logo">
# <div class="logo-img"><a href="/" id="logo" title="Return to the Foro Penal Venezolano home page"><img alt="Foro Penal Venezolano" class="img-responsive" src="https://foropenal.com/sites/default/files/foropenalLogo_0.png" typeof="foaf:Image"/></a></div>
# </div> <!-- /.block -->
# <div class="block block-search col-xs-12 col-sm-12 col-md-3 col-lg-4 margin-top-10px clearfix" id="block-search-form">
# <form accept-charset="UTF-8" action="/presos-politicos/lista-publica" class="form-search content-search" id="search-block-form" method="post"><div><div>
# <h2 class="element-invisible">Formulario de búsqueda</h2>
# <div class="input-group"><input class="form-control form-text" id="edit-search-block-form--2" maxlength="128" name="search_block_form" placeholder="Buscar" size="15" title="Escriba lo que quiere buscar." type="text" value=""/><span class="input-group-btn"><button class="btn btn-default" type="submit">Buscar</button></span></div><button class="element-invisible btn btn-primary form-submit" id="edit-submit" name="op" type="submit" value="Buscar">Buscar</button>
# <input name="form_build_id" type="hidden" value="form-_Cq3IVkQClmJ8at3yD1dVHGL0REA_6yMfEZwMpn-l_Y"/>
# <input name="form_id" type="hidden" value="search_block_form"/>
# </div>
# </div></form>
# </div> <!-- /.block -->
# <div class="block block-tb-menu col-xs-12 col-sm-6 col-md-9 col-lg-9 menu-pull-right main-header-menu clearfix" id="block-tb-menu-0">
# <nav id="main-menu"><ul class="tb-menu main-menu" id="tb-menu-0"><li class="menu-218 menuparent menu-path-front first odd "><a href="/"><span>Inicio</span></a><ul></ul></li>
# <li class="menu-997 menuparent menu-path-node-431 even "><a href="/nosotros"><span>Nosotros</span></a><ul><li class="menu-1970 menu-path-node-2088 first odd "><a href="/antecedentes" title="Antecedentes del Foro Penal Venezolano"><span>Antecedentes</span></a></li>
# <li class="menu-1973 menu-path-node-2098 even "><a href="/quienes-somos"><span>Quiénes somos</span></a></li>
# <li class="menu-1971 menu-path-node-2089 odd last"><a href="/relevancia"><span>Relevancia</span></a></li>
# </ul></li>
# <li class="menu-1706 menuparent menu-path-node-567 odd "><a href="/presos-politicos" title="Detenidos Políticos"><span>Presos Políticos</span></a><ul><li class="menu-1976 menu-path-centros-de-reclusion first odd "><a href="/centros-de-reclusion" title="Centros de Reclusión"><span>Centros de Reclusión</span></a></li>
# <li class="menu-2243 menu-path-presos-politicos-lista-publica even "><a class="active" href="/presos-politicos/lista-publica"><span>Listado</span></a></li>
# <li class="menu-2246 menu-path-historico-privados odd last"><a href="/historico-privados"><span>Sus historias en video</span></a></li>
# </ul></li>
# <li class="menu-1702 menuparent menu-path-news even "><a href="/noticias"><span>Noticias</span></a><ul><li class="menu-1975 menu-path-galeria first odd "><a href="/galeria"><span>Galería</span></a></li>
# <li class="menu-1969 menu-path-reconocimientos even last"><a href="/reconocimientos"><span>Reconocimientos</span></a></li>
# </ul></li>
# <li class="menu-2179 menuparent menu-path-publicaciones odd "><a href="/publicaciones"><span>Publicaciones</span></a><ul><li class="menu-2182 menu-path-publicaciones-decisiones-cidh first odd "><a href="/publicaciones/decisiones-cidh"><span>Decisiones CIDH</span></a></li>
# <li class="menu-2180 menu-path-publicaciones-informes even "><a href="/publicaciones/informes"><span>Informes</span></a></li>
# <li class="menu-2204 menu-path-publicaciones-informes-ong-int odd "><a href="/publicaciones/informes-ong-int"><span>Informes ONG Internacionales</span></a></li>
# <li class="menu-2236 menu-path-node-2318 even "><a href="/propuestas"><span>Propuestas Asamblea Nacional</span></a></li>
# <li class="menu-2202 menu-path-publicaciones-resoluciones-onu odd "><a href="/publicaciones/resoluciones-onu"><span>Resoluciones ONU</span></a></li>
# <li class="menu-2247 menu-path-temas-interes even last"><a href="/temas-interes"><span>Temas de Interés</span></a></li>
# </ul></li>
# <li class="menu-482 menu-path-contact even last"><a href="/contacto"><span>Contáctanos</span></a></li>
# </ul></nav>
# </div> <!-- /.block -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wrapper clearfix " id="globalpageheaderwrapper">
# <div class="container" id="globalpageheadercontainer">
# <div id="globalpageheader">
# <div class="row">
# <div class="region region-static-page-title col-xs-12 col-sm-12 col-md-12 col-lg-12 ">
# <div class="row-fluid">
# <div class="block block-delta-blocks col-xs-12 col-sm-12 col-md-8 col-lg-8 clearfix" id="block-delta-blocks-page-title">
# <h1 class="title" id="page-title">Listado de Presos Políticos</h1>
# </div> <!-- /.block -->
# <div class="block block-delta-blocks col-xs-12 col-sm-12 col-md-4 col-lg-4 breadcrumb-naked text-right hidden-xs hidden-sm clearfix" id="block-delta-blocks-breadcrumb">
# <div class="clearfix" id="breadcrumb"><ul class="breadcrumb"><li class="depth-1 odd first"><a href="/">Inicio</a></li><li class="depth-2 even last"><a class="active" href="/presos-politicos/lista-publica">Listado de Presos Políticos</a></li></ul></div>
# </div> <!-- /.block -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wrapper clearfix " id="mainwrapper">
# <div class="container" id="maincontainer">
# <div id="main">
# <div class="row-fluid">
# <div class="region region-content col-xs-12 col-sm-12 col-md-12 col-lg-12">
# <div class="row-fluid">
# <div class="block block-system col-xs-12 col-sm-12 col-md-12 col-lg-12 clearfix" id="block-system-main">
# <div class="view view-detenidos view-id-detenidos view-display-id-page_2 view-dom-id-8ff894ef19c87febf9e7ba70b5eca6a8">
# <div class="view-filters">
# <form accept-charset="UTF-8" action="/presos-politicos/lista-publica" id="views-exposed-form-detenidos-page-2" method="get"><div><div class="views-exposed-form">
# <div class="views-exposed-widgets clearfix">
# <div class="views-exposed-widget views-widget-filter-keys" id="edit-keys-wrapper">
# <label for="edit-keys">
#             Buscar          </label>
# <div class="views-widget">
# <div class="form-type-textfield form-item-keys form-item form-group">
# <input class="form-control form-text" id="edit-keys" maxlength="128" name="keys" size="15" title="Escriba lo que quiere buscar." type="text" value=""/>
# </div>
# </div>
# </div>
# <div class="views-exposed-widget views-submit-button">
# <button class="btn btn-info form-submit" id="edit-submit-detenidos" name="" type="submit" value="Aplicar">Aplicar</button>
# </div>
# </div>
# </div>
# </div></form> </div>
# <div class="view-content">
# <table class="views-table cols-6 table table-striped table-hover table-condensed table-0">
# <thead>
# <tr>
# <th class="views-field views-field-field-person-photo views-align-center">
# </th>
# <th class="views-field views-field-title views-align-center">
#           Detenido        </th>
# <th class="views-field views-field-field-ocupacion views-align-center">
#           Ocupación        </th>
# <th class="views-field views-field-field-lugar-detencion views-align-center">
#           Lugar detención        </th>
# <th class="views-field views-field-field-fecha-detencion active views-align-center">
#           Fecha detención        </th>
# <th class="views-field views-field-field-estatus">
#           Estatus        </th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd views-row-first">
# <td class="views-field views-field-field-person-photo views-align-center">
# <a href="/Francisco-Javier-Lara-Marquez"><img alt="Francisco Javier Lara Márquez" class="img-responsive" height="100" src="https://foropenal.com/sites/default/files/styles/media_thumbnail/public/detenidos/frank.jpg?itok=0Th8E4ga" typeof="foaf:Image" width="100"/></a> </td>
# <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
property="rdfs:label skos:prefLabel" typeof="skos:Concept">Otro</a> </td>
# <td class="views-field views-field-field-lugar-detencion views-align-center">
# <a datatype="" href="/lugar-detencion/sebin-puerto-ayacucho" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Sebin Puerto Ayacucho</a> </td>
# <td class="views-field views-field-field-fecha-detencion active views-align-center">
# <span class="date-display-single" content="2016-01-06T00:00:00+02:00" datatype="xsd:dateTime" property="dc:date">Ene 6 2016</span> </td>
# <td class="views-field views-field-field-estatus">
# <a datatype="" href="/estatus/procesado" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Procesado</a> </td>
# </tr>
# <tr class="even">
# <td class="views-field views-field-field-person-photo views-align-center">
# <a href="/content/humberto-yusuino"><img alt="" class="img-responsive" height="100" src="https://foropenal.com/sites/default/files/styles/media_thumbnail/public/detenidos/humberto.jpg?itok=vVxmhrft" typeof="foaf:Image" width="100"/></a> </td>
# <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
# <a href="/content/humberto-yusuino">Humberto Yusuino</a> </td>
# <td class="views-field views-field-field-ocupacion views-align-center">
# <a datatype="" href="/ocupaciones/profesional" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Profesional</a> </td>
# <td class="views-field views-field-field-lugar-detencion views-align-center">
# <a datatype="" href="/lugar-detencion/sebin-puerto-ayacucho" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Sebin Puerto Ayacucho</a> </td>
# <td class="views-field views-field-field-fecha-detencion active views-align-center">
# <span class="date-display-single" content="2016-01-04T00:00:00+02:00" datatype="xsd:dateTime" property="dc:date">Ene 4 2016</span> </td>
# <td class="views-field views-field-field-estatus">
# <a datatype="" href="/estatus/procesado" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Procesado</a> </td>
# </tr>
# <tr class="odd">
# <td class="views-field views-field-field-person-photo views-align-center">
# <a href="/node/2466"><img alt="" class="img-responsive" height="100" src="https://foropenal.com/sites/default/files/styles/media_thumbnail/public/detenidos/yelut.png?itok=DPNmQjDz" typeof="foaf:Image" width="100"/></a> </td>
# <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
# <a href="/node/2466">Yelut Naspe Iniestra</a> </td>
# <td class="views-field views-field-field-ocupacion views-align-center">
# <a datatype="" href="/ocupaciones/profesional" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Profesional</a> </td>
# <td class="views-field views-field-field-lugar-detencion views-align-center">
# <a datatype="" href="/lugar-detencion/sebin-helicoide" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Sebin Helicoide</a> </td>
# <td class="views-field views-field-field-fecha-detencion active views-align-center">
# <span class="date-display-single" content="2015-12-16T00:00:00+02:00" datatype="xsd:dateTime" property="dc:date">Dic 16 2015</span> </td>
# <td class="views-field views-field-field-estatus">
# <a datatype="" href="/estatus/procesado" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Procesado</a> </td>
# </tr>
# <tr class="even views-row-last">
# <td class="views-field views-field-field-person-photo views-align-center">
# <a href="/content/gustavo-junior-parra-azuaje"><img alt="" class="img-responsive" height="100" src="https://foropenal.com/sites/default/files/styles/media_thumbnail/public/detenidos/gustavo.jpg?itok=THe_lotD" typeof="foaf:Image" width="100"/></a> </td>
# <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
# <a href="/content/gustavo-junior-parra-azuaje">Gustavo Junior Parra Azuaje</a> </td>
# <td class="views-field views-field-field-ocupacion views-align-center">
# <a datatype="" href="/ocupaciones/estudiante" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Estudiante</a> </td>
# <td class="views-field views-field-field-lugar-detencion views-align-center">
# <a datatype="" href="/lugar-detencion/tocuyito" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Tocuyito</a> </td>
# <td class="views-field views-field-field-fecha-detencion active views-align-center">
# <span class="date-display-single" content="2015-11-26T00:00:00+02:00" datatype="xsd:dateTime" property="dc:date">Nov 26 2015</span> </td>
# <td class="views-field views-field-field-estatus">
# <a datatype="" href="/estatus/procesado" property="rdfs:label skos:prefLabel" typeof="skos:Concept">Procesado</a> </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="text-center"><ul class="pagination"><li class="active first"><a href="#">1</a></li>
# <li><a href="/presos-politicos/lista-publica?keys=&amp;page=1" title="Ir a la página 2">2</a></li>
# <li><a href="/presos-politicos/lista-publica?keys=&amp;page=2" title="Ir a la página 3">3</a></li>
# <li><a href="/presos-politicos/lista-publica?keys=&amp;page=3" title="Ir a la página 4">4</a></li>
# <li><a href="/presos-politicos/lista-publica?keys=&amp;page=4" title="Ir a la página 5">5</a></li>
# <li class="pager-ellipsis disabled"><span>…</span></li>
# <li class="next last"><a href="/presos-politicos/lista-publica?keys=&amp;page=1" title="Ir a la página siguiente">siguiente ›</a></li>
# </ul></div>
# </div>
# </div> <!-- /.block -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wrapper clearfix title-upper" id="globalfooterwrapper">
# <div class="container-fluid clearfix" id="globalfootercontainer">
# <div id="globalfooter">
# <div class="row-fluid">
# <div class="region region-footer col-xs-12 col-sm-12 col-md-12 col-lg-12 ">
# <div class="row-fluid">
# <div class="block block-nodeblock col-xs-12 col-sm-12 col-md-12 col-lg-12 clearfix" id="block-nodeblock-428">
# <div about="/content/footer-style-1" class="node node-node-block clearfix" id="node-428" typeof="sioc:Item foaf:Document">
# <span class="rdf-meta element-hidden" content="Footer Style 1" property="dc:title"></span><span class="rdf-meta element-hidden" content="0" datatype="xsd:integer" property="sioc:num_replies"></span>
# <div class="content">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded"><nav class="footer-wrapper"><section class="col-md-3"><h3 class="block-title h5">
# <strong><span style="color:#000000;">FORO PENAL</span></strong>
# </h3>
# <ul class="list-unstyled"><li>
# <a href="/" title=""><span style="color:#000000;">Inicio</span></a>
# </li>
# <li>
# <a href="/nosotros" title="Sobre nosotros"><span style="color:#000000;">Sobre nosotros</span></a>
# </li>
# <li>
# <a href="/nosotros/equipo"><span style="color:#000000;">Nuestro equipo</span></a>
# </li>
# </ul></section><section class="col-md-3"><h3 class="block-title h5">
# <strong><span style="color:#000000;">PIDE AYUDA</span></strong>
# </h3>
# <ul class="list-unstyled"><li>
# <a href="/contacto" title="Asistencia médica"><span style="color:#000000;">Asistencia médica</span></a>
# </li>
# <li>
# <a href="/contacto" title="Asistencia psicológica"><span style="color:#000000;">Asistencia psicológica</span></a>
# </li>
# <li>
# <a href="/contacto"><span style="color:#000000;">Reporta una detención arbitraria</span></a>
# </li>
# <li>
# <a href="/contacto"><span style="color:#000000;">Denuncia una violación a tus DD.HH.</span></a>
# </li>
# <li>
#
#       </li>
# <li>
#
#       </li>
# </ul></section><section class="col-md-3"><h3 class="block-title h5">
# <span style="color:#000000;"><strong>ACTÚA</strong></span>
# </h3>
# <ul class="list-unstyled"><li>
# <a href="/contacto" title="Ayúdanos"><span style="color:#000000;">R</span></a><a href="/contacto"><span style="color:#000000;">egístrate como defensor activo</span></a>
# </li>
# <li>
# <a href="https://twitter.com/porhumanidad" target="_blank" title="Twitter"><span style="color:#000000;"><span class="fa fa-twitter"></span>  Síguenos</span></a><a href="http://twitter.com/porhumanidad"><span style="color:#000000;"> en Twitter</span></a>
# </li>
# <li>
# <a href="https://www.facebook.com/foropenalvenezolano?fref=ts" target="_blank" title="Facebook"><span style="color:#000000;"><span class="fa fa-facebook"></span>  Participa</span></a><a href="https://www.facebook.com/foropenalvenezolano?fref=ts"><span style="color:#000000;"> en nuestra comunidad</span></a>
# </li>
# <li>
# <span style="color:#000000;"><span class="fa fa-youtube-play" style="color:rgb(0, 0, 0);"></span> </span><a href="https://www.youtube.com/channel/UCMX1FPAJsQBC0H1gtFezwUA"><span style="color:#000000;">Mira los últimos videos</span></a>
# </li>
# </ul></section><section class="col-md-3"><h3 class="block-title h5">
# <strong><span style="color:#000000;">INFÓRMATE</span></strong>
# </h3>
# <ul class="list-unstyled"><li>
# <a href="/presos-politicos" title="Balance de detenidos"><span style="color:#000000;">Balance de detenidos</span></a>
# </li>
# <li>
# <a href="/informes"><span style="color:#000000;">Informes</span></a>
# </li>
# <li>
# <a href="/noticias" title="Noticias"><span style="color:#000000;">Noticias</span></a>
# </li>
# </ul></section></nav></div></div></div> </div>
# </div>
# </div> <!-- /.block -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wrapper clearfix " id="globalfooterbottomwrapper">
# <div class="container-fluid clearfix" id="globalfooterbottomcontainer">
# <div id="globalfooterbottom">
# <div class="row-fluid">
# <div class="region region-footer-bottom col-xs-12 col-sm-12 col-md-12 col-lg-12 ">
# <div class="row-fluid">
# <div class="block block-nodeblock col-xs-12 col-sm-12 col-md-6 col-lg-6 text-center-xs text-center-sm text-left-md clearfix" id="block-nodeblock-557">
# <div about="/content/copyright" class="node node-node-block clearfix" id="node-557" typeof="sioc:Item foaf:Document">
# <span class="rdf-meta element-hidden" content="Copyright" property="dc:title"></span><span class="rdf-meta element-hidden" content="0" datatype="xsd:integer" property="sioc:num_replies"></span>
# <div class="content">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded"><p>© <strong>Foro Penal Venezolano</strong> - Todos los derechos reservados.</p>
# </div></div></div> </div>
# </div>
# </div> <!-- /.block -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script src="https://foropenal.com/sites/default/files/js/js_3nt1sRoiqKAHyrmQV-h0GZ2A1OtHmTfshP9UOZCDAOA.js"></script>
# <script src="https://foropenal.com/sites/default/files/js/js_0FLbRiUqtDpV72FfWXeHPnFm-mOEfk_I-e170Ur5Kws.js"></script>
# </body>
# </html>

# %%
td_class_names = document.find_all('td', {'class': 'views-field views-field-title views-align-center ultimos-detenidos-nombre'})

# %%
td_class_names
# Out:
# [<td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/Francisco-Javier-Lara-Marquez">Francisco Javier Márquez Lara</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/gabriel-salom%C3%B3n-san-miguel">Gabriel Salomón San Miguel</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/angel-coromoto-rodr%C3%ADguez">Angel Coromoto Rodríguez</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/node/2438">Jeremy Bastardo Lugo</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/jes%C3%BAs-david-chirinos-rodr%C3%ADguez">Jesús David Chirinos Rodríguez</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/vilca-fern%C3%A1ndez">Vilca Fernández</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/javier-infante-p%C3%A9rez">Javier Infante Pérez</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/humberto-yusuino">Humberto Yusuino</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/node/2466">Yelut Naspe Iniestra</a> </td>,
#  <td class="views-field views-field-title views-align-center ultimos-detenidos-nombre">
#  <a href="/content/gustavo-junior-parra-azuaje">Gustavo Junior Parra Azuaje</a> </td>]

# %%
for item in td_class_names:
    names = item.find('a')
    print(names.string)
# Out:
# Francisco Javier Márquez Lara
# Gabriel Salomón San Miguel
# Angel Coromoto Rodríguez
# Jeremy Bastardo Lugo
# Jesús David Chirinos Rodríguez
# Vilca Fernández
# Javier Infante Pérez
# Humberto Yusuino
# Yelut Naspe Iniestra
# Gustavo Junior Parra Azuaje

# %% [markdown]
# # Scraping all 9 pages

# %%
import requests 
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
from urllib.request import urlopen

# %%
names_list= []

for i in range(9):
    html_str = urlopen('https://foropenal.com/presos-politicos/lista-publica?keys=&page=' + str(i)).read()
    document = BeautifulSoup(html_str, "html.parser")
    
    td_class_names = document.find_all('td', {'class': 'views-field views-field-title views-align-center ultimos-detenidos-nombre'})
    for item in td_class_names:
        names = item.find('a')
        names.string
        #print(names.string)
        names_list.append(names.string)
names_list
# Out:
# ['Francisco Javier Márquez Lara',
#  'Gabriel Salomón San Miguel',
#  'Angel Coromoto Rodríguez',
#  'Jeremy Bastardo Lugo',
#  'Jesús David Chirinos Rodríguez',
#  'Vilca Fernández',
#  'Javier Infante Pérez',
#  'Humberto Yusuino',
#  'Yelut Naspe Iniestra',
#  'Gustavo Junior Parra Azuaje',
#  'Pablo José Molina Gíl',
#  'Carlos Luis Jiménez Alfonzo',
#  'Jesús María Alarcón Camacho',
#  'Manuel Rosales',
#  'Romer Joaquín Mena Nava',
#  'Hector Alejandro Zerpa',
#  'Betty Grossi',
#  'Danny Gabriel Abreu Abreu',
#  'Andrea Susana González de León ',
#  'Fray Antonio Roa Contreras',
#  'Eduardo Figueroa Marchena',
#  'Edgar Bolívar Ramírez',
#  'Antonio José Ledezma Díaz',
#  'Pedro Rafael Maury Bolívar',
#  'Ricardo José Antich',
#  'Petter Alexander Moreno Guevara',
#  'Henry Salazar Moncada',
#  'Carlos José Esqueda Martínez',
#  'Luis Rafael Colmenares Pacheco',
#  'Luis Lugo Calderón',
#  'Luis Rafael Colmenares Pacheco',
#  'Franklin Fermin  Hernández Hernández',
#  'Carmen Alicia Gutiérrez Acevedo',
#  'José Gámez Bustamante',
#  'Juan Miguel De Sousa',
#  'Gilberto Sojo Rengifo',
#  'Victor Andrés Ugas',
#  'Gregory Sanabria',
#  'Juan Pablo Giraldo Ochoa',
#  'Maria Elena Uzcátegui',
#  'Gabriel Valles Sguerzi',
#  'Lorent Enrique Gómez Saleh',
#  'Skarlyn Duarte',
#  'Leonel  Sánchez Camero',
#  'Efraín José Ortega Hurtado',
#  'Vasco  Manuel Da Costa',
#  'José Luís Santamaría',
#  'Araminta González',
#  'Ronny José Navarro Rodriguez',
#  'Jimmy Torres',
#  'Antonio José Garbi González',
#  'Renzo David Prieto Ramírez',
#  'Gerardo Ernesto Carrero Delgado',
#  'Nixon Alfonzo Leal Toro',
#  'Carlos Pérez ',
#  'Angel Armando Contreras Ravelo',
#  'Eduardo Enrique García Piña',
#  'Laided Salazar de Zerpa',
#  'Andrés Thompson Martínez',
#  'Neri Córdoba Moreno',
#  'Cesar Orta Santamaría',
#  'Victor José Ascanio',
#  'Vladimir Aráque Hainal',
#  'Ruperto Chiquinquirá Sánchez',
#  'José Gregorio Delgado Vázquez',
#  'Rosmit  Mantilla',
#  'José Acacio Moreno',
#  'Yeimi Varela',
#  'Ignacio Porras Fernández',
#  'Marcelo Eduardo Crovato Sarabia',
#  'Ángel Betancourt',
#  'Chamel Akl',
#  'Juan Carlos Nieto Quintero',
#  'Oswaldo Hernández',
#  'Raúl Emilio Baduel',
#  'Alexander Tirado',
#  'Daniel Omar Ceballos Morales',
#  'Leopoldo Eduardo López Mendoza',
#  'Víctor Manuel García Hidalgo',
#  'Rolando Guevara',
#  'Otoniel Guevara',
#  'Iván  Simonovis Aranguren',
#  'Juan Bautista Guevara',
#  'Erasmo José Bolívar',
#  'Marco Javier Hurtado',
#  'Arube José Pérez Salazar',
#  'Luis Henrique Molina Cerrada',
#  'Hector José Rovaín']

# %%
professions_list= []

for i in range(9):
    html_str = urlopen('https://foropenal.com/presos-politicos/lista-publica?keys=&page=' + str(i)).read()
    document = BeautifulSoup(html_str, "html.parser")
    
    td_class_profession = document.find_all('td', {'class': 'views-field views-field-field-ocupacion views-align-center'})
    for item in td_class_profession:
        profession = item.find('a')
        profession.string
        professions_list.append(profession.string)
        
professions_list
# Out:
# ['Profesional',
#  'Profesional',
#  'Profesional',
#  'Otro',
#  'Otro',
#  'Estudiante',
#  'Otro',
#  'Profesional',
#  'Profesional',
#  'Estudiante',
#  'Militar',
#  'Militar',
#  'Militar',
#  'Profesional',
#  'Militar',
#  'Estudiante',
#  'Profesional',
#  'Estudiante',
#  'Otro',
#  'Profesional',
#  'Militar',
#  'Militar',
#  'Profesional',
#  'Otro',
#  'Militar',
#  'Militar',
#  'Militar',
#  'Militar',
#  'Profesional',
#  'Militar',
#  'Profesional',
#  'Otro',
#  'Profesional',
#  'Militar',
#  'Profesional',
#  'Otro',
#  'Profesional',
#  'Estudiante',
#  'Profesional',
#  'Otro',
#  'Otro',
#  'Otro',
#  'Otro',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Estudiante',
#  'Estudiante',
#  'Otro',
#  'Otro',
#  'Otro',
#  'Otro',
#  'Otro',
#  'Militar',
#  'Militar',
#  'Militar',
#  'Militar',
#  'Militar',
#  'Otro',
#  'Militar',
#  'Militar',
#  'Estudiante',
#  'Militar',
#  'Otro',
#  'Profesional',
#  'Profesional',
#  'Otro',
#  'Profesional',
#  'Militar',
#  'Militar',
#  'Profesional',
#  'Estudiante',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional',
#  'Profesional']

# %%
locations_list= []

for i in range(9):
    html_str = urlopen('https://foropenal.com/presos-politicos/lista-publica?keys=&page=' + str(i)).read()
    document = BeautifulSoup(html_str, "html.parser")
    
    td_class_location = document.find_all('td', {'class': 'views-field views-field-field-lugar-detencion views-align-center'})
    for item in td_class_location:
        location = item.find('a')
        location.string
        locations_list.append(location.string)

locations_list
# Out:
# ['Penitenciaria 26 de julio',
#  'Penitenciaria 26 de julio',
#  'Penitenciaria 26 de julio',
#  'Penitenciaria 26 de julio',
#  'Sebin Maracaibo',
#  'Sebin Helicoide',
#  'Sebin Puerto Ayacucho',
#  'Sebin Puerto Ayacucho',
#  'Sebin Helicoide',
#  'Tocuyito',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'DGCIM Boleíta',
#  'Arresto Domiciliario',
#  'Arresto Domiciliario',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Ramo Verde',
#  'Sebin Plaza Venezuela',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Arresto Domiciliario',
#  'Sebin Plaza Venezuela',
#  'Sebin Plaza Venezuela',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Rodeo II',
#  'Penitenciaria 26 de julio',
#  'Rodeo II',
#  'INOF',
#  'Sebin Helicoide',
#  'Ramo Verde',
#  'Tocuyito',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Sebin Maracaibo',
#  'Arresto Domiciliario',
#  'La Pica',
#  'La Pica',
#  'Policía Militar Fuerte Tiuna',
#  'La Pica',
#  'Sebin Helicoide',
#  'La Pica',
#  'La Pica',
#  'Sebin Helicoide',
#  'Policía Militar Fuerte Tiuna',
#  'Sebin Helicoide',
#  'Arresto Domiciliario',
#  'Arresto Domiciliario',
#  'Arresto Domiciliario',
#  'Arresto Domiciliario',
#  'Policía Militar Fuerte Tiuna',
#  'Cárcel de Santa Ana',
#  'Tocuyito',
#  'Tocuyito',
#  'Arresto Domiciliario',
#  'Ramo Verde',
#  'Arresto Domiciliario',
#  'Sebin Helicoide',
#  'Sebin Helicoide',
#  'Arresto Domiciliario',
#  'Sebin Helicoide',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde',
#  'Ramo Verde']

# %% [markdown]
# # OH NO!! dates are in spanish....

# %%
dates_list= []
for i in range(9):
    html_str = urlopen('https://foropenal.com/presos-politicos/lista-publica?keys=&page=' + str(i)).read()
    document = BeautifulSoup(html_str, "html.parser")
    td_class_dates = document.find_all('td', {'class': 'views-field views-field-field-fecha-detencion active views-align-center'})
    for item in td_class_dates:
        dates = item.find('span')
        dates.string
        dates_list.append(dates.string)
dates_list
# Out:
# ['Jun 19 2016',
#  'Jun 19 2016',
#  'Mayo 19 2016',
#  'Mayo 18 2016',
#  'Mayo 4 2016',
#  'Ene 31 2016',
#  'Ene 6 2016',
#  'Ene 4 2016',
#  'Dic 16 2015',
#  'Nov 26 2015',
#  'Nov 23 2015',
#  'Nov 23 2015',
#  'Nov 20 2015',
#  'Oct 15 2015',
#  'Ago 19 2015',
#  'Ago 17 2015',
#  'Ago 17 2015',
#  'Ago 17 2015',
#  'Ago 17 2015',
#  'Jul 24 2015',
#  'Jun 25 2015',
#  'Jun 17 2015',
#  'Feb 19 2015',
#  'Feb 13 2015',
#  'Feb 12 2015',
#  'Feb 12 2015',
#  'Feb 11 2015',
#  'Feb 11 2015',
#  'Feb 11 2015',
#  'Feb 11 2015',
#  'Feb 11 2015',
#  'Ene 21 2015',
#  'Ene 21 2015',
#  'Ene 21 2015',
#  'Ene 20 2015',
#  'Nov 26 2014',
#  'Oct 15 2014',
#  'Oct 7 2014',
#  'Sep 19 2014',
#  'Sep 12 2014',
#  'Sep 5 2014',
#  'Sep 4 2014',
#  'Ago 26 2014',
#  'Ago 21 2014',
#  'Jul 24 2014',
#  'Jul 24 2014',
#  'Jul 24 2014',
#  'Jul 24 2014',
#  'Jun 28 2014',
#  'Jun 10 2014',
#  'Jun 4 2014',
#  'Mayo 10 2014',
#  'Mayo 8 2014',
#  'Mayo 8 2014',
#  'Mayo 8 2014',
#  'Mayo 8 2014',
#  'Mayo 7 2014',
#  'Mayo 5 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 2 2014',
#  'Mayo 1 2014',
#  'Abr 22 2014',
#  'Abr 22 2014',
#  'Abr 12 2014',
#  'Abr 4 2014',
#  'Abr 2 2014',
#  'Abr 2 2014',
#  'Mar 21 2014',
#  'Mar 21 2014',
#  'Mar 19 2014',
#  'Feb 18 2014',
#  'Mar 1 2013',
#  'Nov 23 2004',
#  'Nov 23 2004',
#  'Nov 20 2004',
#  'Nov 20 2004',
#  'Abr 19 2003',
#  'Abr 19 2003',
#  'Abr 19 2003',
#  'Abr 19 2003',
#  'Abr 19 2003']

# %%
status_list= []
for i in range(9):
    html_str = urlopen('https://foropenal.com/presos-politicos/lista-publica?keys=&page=' + str(i)).read()
    document = BeautifulSoup(html_str, "html.parser")
    td_class_status = document.find_all('td', {'class': 'views-field views-field-field-estatus'})
    for item in td_class_status:
        status = item.find('a')
        status.string
        status_list.append(status.string)

status_list
# Out:
# ['Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Condenado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Procesado',
#  'Condenado',
#  'Condenado',
#  'Procesado',
#  'Condenado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Procesado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Procesado',
#  'Condenado',
#  'Procesado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado',
#  'Condenado']

# %%
political_prisoners_df = pd.DataFrame({'name' : names_list,'professions' : professions_list, 'locations': locations_list, 'dates': dates_list, 'status': status_list})

political_prisoners_df
# Out:
#            dates                     locations  \
# 0    Jun 19 2016     Penitenciaria 26 de julio
# 1    Jun 19 2016     Penitenciaria 26 de julio
# 2   Mayo 19 2016     Penitenciaria 26 de julio
# 3   Mayo 18 2016     Penitenciaria 26 de julio
df_dates_fixed.tail()
# Out:
#        dates                  locations  professions     status
# 4 2016-05-04            Sebin Maracaibo         Otro  Procesado
# 3 2016-05-18            Sebin Helicoide         Otro  Procesado
# 2 2016-05-19            Sebin Helicoide  Profesional  Procesado
# 0 2016-06-19  Penitenciaria 26 de julio  Profesional  Procesado
# 1 2016-06-19  Penitenciaria 26 de julio  Profesional  Procesado

# %%
df_dates_fixed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 82 to 1
# Data columns (total 4 columns):
# dates          86 non-null datetime64[ns]
# locations      86 non-null object
# professions    86 non-null object
# status         86 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.4+ KB

# %%
df_dates_fixed.index = df_dates_fixed['dates']

# %%
len(df_dates_fixed['2014'])
# Out:
# 42

# %%
fig, ax = plt.subplots()
df_dates_fixed.resample('M').count().plot( y='status', figsize= (10,7), ax=ax)
#plt.savefig("project4_political_prisoners.pdf", transparent=True)

# %%
fig, ax = plt.subplots()
df_dates_fixed.resample('M').count().plot(kind='bar', y='dates', figsize= (30,7), ax=ax)
#plt.savefig("project4_political_prisoners_bar_chart.pdf", transparent=True)

# %%
fig, ax = plt.subplots()
df_dates_fixed.resample('A').count().plot(kind='bar', y='dates', figsize= (12,5), ax=ax)
ax.yaxis.grid(which= 'major', color='grey', linestyle='-', linewidth=1)
ax.yaxis.grid(which= 'minor', color='grey', linestyle='-', linewidth=1)
plt.tick_params(which = 'major', top= 'on',right='on', bottom= 'on', labeltop= 'on', labelbottom= 'on', labelleft= 'on')
plt.tick_params(which = 'minor', top= 'on',right='on', bottom= 'on', labeltop= 'on', labelbottom= 'on', labelleft= 'on')
ax.minorticks_on()
#plt.savefig("project4_political_prisoners_bar_chart_anual.pdf", transparent=True)

# %%
df_dates_fixed
# Out:
#                 dates                      locations  professions     status
# dates
# 2003-04-19 2003-04-19                     Ramo Verde  Profesional  Condenado
# 2003-04-19 2003-04-19                     Ramo Verde  Profesional  Condenado
# 2003-04-19 2003-04-19                     Ramo Verde  Profesional  Condenado
# 2003-04-19 2003-04-19                     Ramo Verde  Profesional  Condenado
# 2003-04-19 2003-04-19                     Ramo Verde  Profesional  Condenado
# 2013-03-01 2013-03-01           Arresto Domiciliario  Profesional  Procesado
# 2014-02-18 2014-02-18                     Ramo Verde  Profesional  Condenado
# 2014-03-19 2014-03-19           Arresto Domiciliario  Profesional  Procesado
# 2014-03-21 2014-03-21                       Tocuyito  Profesional  Condenado
# 2014-03-21 2014-03-21                       Tocuyito   Estudiante  Condenado
# 2014-04-02 2014-04-02  PolicÃ­a Militar Fuerte Tiuna      Militar  Condenado
# 2014-04-02 2014-04-02           CÃ¡rcel de Santa Ana      Militar  Condenado
# 2014-04-04 2014-04-04           Arresto Domiciliario  Profesional  Procesado
# 2014-04-12 2014-04-12           Arresto Domiciliario         Otro  Procesado
# 2014-04-22 2014-04-22           Arresto Domiciliario  Profesional  Procesado
# 2014-04-22 2014-04-22           Arresto Domiciliario  Profesional  Procesado
# 2014-05-01 2014-05-01                Sebin Helicoide         Otro  Procesado
# 2014-05-02 2014-05-02                        La Pica      Militar  Condenado
len(df_dates_fixed['2004'])
# Out:
# 4

# %%
len(df_dates_fixed['2005'])
# Out:
# 0

# %%
len(df_dates_fixed['2006'])
# Out:
# 0

# %%
len(df_dates_fixed['2007'])
# Out:
# 0

# %%
len(df_dates_fixed['2008'])
# Out:
# 0

# %%
len(df_dates_fixed['2009'])
# Out:
# 0

# %%
len(df_dates_fixed['2010'])
# Out:
# 0

# %%
len(df_dates_fixed['2011'])
# Out:
# 0

# %%
len(df_dates_fixed['2012'])
# Out:
# 0

# %%
len(df_dates_fixed['2013'])
# Out:
# 1

# %%
df_dates_fixed['2014']
# Out:
#                 dates                      locations  professions     status
# dates
# 2014-02-18 2014-02-18                     Ramo Verde  Profesional  Condenado
# 2014-03-19 2014-03-19           Arresto Domiciliario  Profesional  Procesado
# 2014-03-21 2014-03-21                       Tocuyito  Profesional  Condenado
# 2014-03-21 2014-03-21                       Tocuyito   Estudiante  Condenado
# 2014-04-02 2014-04-02  PolicÃ­a Militar Fuerte Tiuna      Militar  Condenado
# 2014-04-02 2014-04-02           CÃ¡rcel de Santa Ana      Militar  Condenado
# 2014-04-04 2014-04-04           Arresto Domiciliario  Profesional  Procesado
# 2014-04-12 2014-04-12           Arresto Domiciliario         Otro  Procesado
# 2014-04-22 2014-04-22           Arresto Domiciliario  Profesional  Procesado
# 2014-04-22 2014-04-22           Arresto Domiciliario  Profesional  Procesado
# 2014-05-01 2014-05-01                Sebin Helicoide         Otro  Procesado
# 2014-05-02 2014-05-02                        La Pica      Militar  Condenado
# 2014-05-02 2014-05-02                        La Pica      Militar  Condenado
# 2014-05-02 2014-05-02  PolicÃ­a Militar Fuerte Tiuna      Militar  Condenado
# 2014-05-02 2014-05-02                        La Pica      Militar  Condenado
# 2014-05-02 2014-05-02                Sebin Helicoide         Otro  Procesado
# 2014-05-02 2014-05-02                        La Pica      Militar  Condenado
# 2014-05-02 2014-05-02                        La Pica      Militar  Condenado
# 2014-05-02 2014-05-02  PolicÃ­a Militar Fuerte Tiuna      Militar  Condenado
# 2014-05-02 2014-05-02                Sebin Helicoide   Estudiante  Procesado
# 2014-05-05 2014-05-05           Arresto Domiciliario      Militar  Condenado
# 2014-05-07 2014-05-07                Sebin Maracaibo         Otro  Procesado
# 2014-05-08 2014-05-08                Sebin Helicoide         Otro  Procesado
# 2014-05-08 2014-05-08                Sebin Helicoide         Otro  Procesado
# 2014-05-08 2014-05-08                Sebin Helicoide         Otro  Procesado
# 2014-05-08 2014-05-08                Sebin Helicoide         Otro  Procesado
# 2014-05-10 2014-05-10                Sebin Helicoide   Estudiante  Procesado
# 2014-06-10 2014-06-10                     Ramo Verde  Profesional  Condenado
# 2014-06-28 2014-06-28                Sebin Helicoide  Profesional  Procesado
# 2014-07-24 2014-07-24                       Rodeo II  Profesional  Procesado
# 2014-07-24 2014-07-24      Penitenciaria 26 de julio  Profesional  Procesado
# 2014-07-24 2014-07-24                       Rodeo II  Profesional  Procesado
# 2014-07-24 2014-07-24                           INOF  Profesional  Procesado
# 2014-08-07 2014-08-07                Sebin Helicoide   Estudiante  Procesado
# 2014-08-15 2014-08-15                Sebin Helicoide  Profesional  Procesado
# 2014-08-21 2014-08-21                Sebin Helicoide  Profesional  Procesado
# 2014-08-26 2014-08-26                Sebin Helicoide         Otro  Procesado
# 2014-09-04 2014-09-04          Sebin Plaza Venezuela         Otro  Procesado
# 2014-09-05 2014-09-05          Sebin Plaza Venezuela         Otro  Procesado
# 2014-09-12 2014-09-12           Arresto Domiciliario         Otro  Procesado
# 2014-09-19 2014-09-19                Sebin Helicoide  Profesional  Procesado
# 2014-11-26 2014-11-26                Sebin Helicoide         Otro  Procesado

# %%
len(df_dates_fixed['2015'])
# Out:
# 26

# %%
len(df_dates_fixed['2016'])
# Out:
# 8

# %%
len(df_dates_fixed)
# Out:
# 86

# %%
df_dates_fixed['2016']
# Out:
#                 dates                  locations  professions     status
# dates
# 2016-01-04 2016-01-04      Sebin Puerto Ayacucho  Profesional  Procesado
# 2016-01-06 2016-01-06      Sebin Puerto Ayacucho         Otro  Procesado
# 2016-01-31 2016-01-31            Sebin Helicoide   Estudiante  Procesado
# 2016-05-04 2016-05-04            Sebin Maracaibo         Otro  Procesado
# 2016-05-18 2016-05-18            Sebin Helicoide         Otro  Procesado
# 2016-05-19 2016-05-19            Sebin Helicoide  Profesional  Procesado
# 2016-06-19 2016-06-19  Penitenciaria 26 de julio  Profesional  Procesado
# 2016-06-19 2016-06-19  Penitenciaria 26 de julio  Profesional  Procesado

# %% [markdown]
# # Rule of law index 2015 data
# I used the complete data to recreate a map, now I will use data of the countries that ranked the lowest in the index to compare Venezuela to the other 4. Comparison of each category

# %%
df_WJP = pd.read_excel("project_4_chart_2_last_5.xlsx")
df_WJP.head()
# Out:
#        Country global rank  government powers absence of corruption  \
# 0  Afghanistan     101/102               0.44                  0.23
# 1     Cameroon      97/102               0.44                  0.25
# 2     Pakistan      98/102               0.49                 0.35
# 3    Venezuela     102/102               0.19                  0.27
# 4     Zimbabwe     100/102               0.26                  0.28
#
#    open government  fundamental rights order and security  \
# 0             0.43                0.38               0.42
# 1             0.39                0.50              0.54
# 2             0.45                0.39                0.3
# 3             0.38                0.39               0.54
# 4             0.32                0.29               0.63
#
#    regulatory enforcement  civil justice  criminal justice  overal score
# 0                    0.36           0.32              0.24          0.35
# 1                    0.39           0.37              0.32          0.40
# 2                    0.36           0.40              0.31          0.38
# 3                    0.26           0.35              0.16          0.32
# 4                    0.35           0.45              0.36          0.37

# %%
fig, ax = plt.subplots(figsize= (8,5))
df_WJP.plot(kind='bar', x='Country', y='criminal justice', ax=ax)
plt.savefig("project4_WJP_bottom_5.pdf", transparent=True)
ax.yaxis.grid(which= 'major', color='grey', linestyle='-', linewidth=1)
ax.yaxis.grid(which= 'minor', color='grey', linestyle='-', linewidth=1)
plt.tick_params(which = 'major', top= 'on',right='on', bottom= 'off', labeltop= 'off', labelbottom= 'off', labelleft= 'on')
plt.tick_params(which = 'minor', top= 'on',right='on', bottom= 'off', labeltop= 'off', labelbottom= 'off', labelleft= 'on')
ax.minorticks_on()
plt.savefig("project4_criminal_justice_scores.pdf", transparent=True)
