# %% [markdown]
# # Does gun control make us safer?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# plt.style.use('ggplot')
plt.style.use('default')
import dateutil.parser
from datetime import datetime
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
# %matplotlib inline

# %%
ms = pd.read_csv("massshooting.csv")
ms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 6 columns):
# Incident Date     1067 non-null object
# state             1067 non-null object
# city or county    1067 non-null object
# address           1048 non-null object
# killed            1067 non-null int64
# injured           1067 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 50.1+ KB

# %%
def get_date(str_date):
    return datetime.strptime(str_date,'%d-%b-%y')

# %%
ms['date'] = ms['Incident Date'].apply(get_date)

# %%
ms.head(5)
# Out:
#   Incident Date     state city or county                             address  \
# 0     24-Jul-16      Ohio       Hamilton                        1555 Main St
# 1     24-Jul-16   Florida     Fort Myers                      3580 Evans Ave
# 2     23-Jul-16      Ohio     Cincinnati        3400 block of Beekman Street
# 3     23-Jul-16     Texas        Bastrop                  202 Childers Drive
# 4     22-Jul-16  Illinois       Kankakee  300 block of North Wildwood Avenue
#
#    killed  injured       date
# 0       1        7 2016-07-24
# 1       2       16 2016-07-24
# 2       2        2 2016-07-23
# 3       4        1 2016-07-23
# 4       0        5 2016-07-22

# %%
dateutil.parser.parse("2016-07-17")
# Out:
# datetime.datetime(2016, 7, 17, 0, 0)

# %%
ms.index=ms['date']
ms.head(2)
# Out:
#            Incident Date    state city or county         address  killed  \
# date
# 2016-07-24     24-Jul-16     Ohio       Hamilton    1555 Main St       1
# 2016-07-24     24-Jul-16  Florida     Fort Myers  3580 Evans Ave       2
#
#             injured       date
# date
# 2016-07-24        7 2016-07-24
# 2016-07-24       16 2016-07-24

# %%
ax = ms.plot(figsize=[20,10])
ax

# plt.savefig('massshooting.pdf',transparent=True)

# %%
ms.groupby(by=ms.index.month).sum()
# Out:
#     killed  injured  Operations
# 1       90      211         NaN
# 2      111      272         NaN
# 3       77      299         NaN
# 4       99      329         NaN
# 5      107      451         NaN
# 6      174      605         NaN
# 7      129      549         NaN
# 8      110      397         NaN
# 9       83      341         NaN
# 10      65      220         NaN
# 11      83      271         NaN
# 12      69      225         NaN

# %%
ms.groupby(by=ms.index.month).sum().plot()

# %%
state = ms.groupby(by=ms['state']).sum()
state.sort_values(by="killed",ascending=False)
# state.to_csv("state.csv")
# Out:
#                       killed  injured  Operations
# state
# California               143      524         NaN
# Florida                  130      306         NaN
# Texas                    116      245         NaN
# Georgia                   66      202         NaN
# Illinois                  53      366         NaN
# Ohio                      48      117         NaN
# South Carolina            45       77         NaN
# New York                  43      221         NaN
# Tennessee                 38      158         NaN
# Michigan                  35      189         NaN
# Missouri                  34      117         NaN
# Louisiana                 33      211         NaN
# Arizona                   31       49         NaN
# Virginia                  27       99         NaN
# Washington                27       31         NaN
# Pennsylvania              27      165         NaN
# Indiana                   25      105         NaN
# Maryland                  22       93         NaN
# Kansas                    19       48         NaN
# New Jersey                17      109         NaN
# Oklahoma                  17       38         NaN
# North Carolina            17      119         NaN
# Alabama                   17       61         NaN
# Mississippi               17       34         NaN
# Oregon                    15       31         NaN
# New Mexico                15       18         NaN
# Kentucky                  14       39         NaN
# District of Columbia      13       75         NaN
# Minnesota                 11       46         NaN
# South Dakota              10        1         NaN
# Utah                       9        7         NaN
# Colorado                   9       45         NaN
# Nevada                     8       30         NaN
# Wisconsin                  8       28         NaN
# Arkansas                   7       25         NaN
# Maine                      5        0         NaN
# Montana                    5        0         NaN
# West Virginia              5        9         NaN
# Massachusetts              5       50         NaN
# Nebraska                   5       16         NaN
# Delaware                   4       24         NaN
# Vermont                    4        0         NaN
# Connecticut                3       36         NaN
# Iowa                       1        8         NaN
# Rhode Island               1       16         NaN
# Alaska                     0        6         NaN

# %%
state.sort_values(by="killed",ascending=False).head(10).sort_values(by='killed').plot(kind='barh',y='killed')

# %%
state.sort_values(by="killed",ascending=False).tail(10).sort_values(by='killed').plot(kind='barh',y='killed')

# %%
state_count = ms.groupby(by=ms['state']).count()
state_count.sort_values(by='date',ascending=False).head(10).sort_values(by='date').plot(kind='barh',y='date')

# %%
ms.groupby(by=ms.index.year).count()
# Out:
#       Incident Date  state  city or county  address  killed  injured  \
# 2013            254    254             254      246     254      254
# 2014            277    277             277      269     277      277
# 2015            332    332             332      329     332      332
# 2016            195    195             195      195     195      195
#
#       Operations  date
# 2013           0   254
# 2014           0   277
# 2015           0   332
# 2016           0   195

# %%
ms.groupby(by=ms.index.year).sum()
# Out:
#       killed  injured  Operations
# 2013     288      956         NaN
# 2014     268     1110         NaN
# 2015     369     1324         NaN
# 2016     272      780         NaN

# %%
ms.groupby(by=ms.index.year).plot()
# Out:
# 2013    Axes(0.125,0.2;0.775x0.7)
# 2014    Axes(0.125,0.2;0.775x0.7)
# 2015    Axes(0.125,0.2;0.775x0.7)
# 2016    Axes(0.125,0.2;0.775x0.7)
# dtype: object

# %%
ms.groupby(by=ms.index.day).sum().plot(legend=False)
