# %% [markdown]
# # Scraping Lundberg

# %%
import requests
from bs4 import BeautifulSoup
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Prepping beautifulsoup

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(open("/Users/barneyjs/Desktop/Transparenz.htm"), 'html.parser')

# %%
#odd numbers for names and adresses
odd = soup.find_all('div', {'class': 'row odd first clearfix'})
len(odd)
# Out:
# 96

# %%
#odd numbers for names and adresses
even = soup.find_all('div', {'class': 'row even first clearfix'})
len(even)
# Out:
# 95

# %%
#Fees
details = soup.find_all('div', {'class': 'row-details clearfix'})
len(details)
# Out:
# 191

# %%
#Together they add up to 191, from 96 and 95. So that makes 191. 
#My plan is to iterate through both the odd and the even list.
#Then zip join them together. And finally join them to the list of 
#fees.

# %%
def names(x):
    if x.find('div', {'class': 'hcptitle'}) is not None:
        return 'Doctor, ' + x.find('div', {'class': 'hcptitle'}).nextSibling.strip()
    else:
        return 'Hospital, ' + x.find('div', {'class': 'col hcohcpname'}).string.strip()

# %%
def address_(x):
    try:
        return x.find('div', {'class': 'col address'}).string  
    except:
        return None

# %% [markdown]
# ## First the names

# %%
#Getting odd names
oddnamelist = []
for item in odd:
    name = names(item)
    oddnamelist.append(name)

# %%
#Getting the even names
evennamelist = []
for item in even:
    name = names(item)
    evennamelist.append(name)

# %%
#Making sure the lists are the same length, and getting the last one, 
#if they're not.
if len(oddnamelist) > len(evennamelist):
    last_odd = oddnamelist.pop()
else:
    last_odd = ''
print(last_odd)
# Out:
# Hospital, Zentrum für Abhängigkeitserkrankungen

# %%
#Creating whole list of names
wholenamelist = []
for x in zip(oddnamelist,evennamelist):
    wholenamelist.append(x[0])
    wholenamelist.append(x[1])

#Adding on last element of the list, if odd was longer
wholenamelist.append(last_odd)
len(wholenamelist)
# Out:
# 191

# %% [markdown]
# ## Now the Addresses

# %%
#Getting the odd addresslist
oddaddresslist = []
for item in odd:
    address = address_(item)
    oddaddresslist.append(address)
len(oddaddresslist)
# Out:
# 96

# %%
#Getting the even addresslist
evenaddresslist = []
for item in even:
    address = address_(item)
    evenaddresslist.append(address)
len(evenaddresslist)
# Out:
# 95

# %%
if len(oddaddresslist) > len(evenaddresslist):
    last_odd = oddaddresslist.pop()
else:
    last_odd = ''

# %%
#Creating whole list of addresses:
addresslist = []
for x in zip(oddaddresslist,evenaddresslist):
    addresslist.append(x[0])
    addresslist.append(x[1])

#Adding on last element of the list, if odd was longer
addresslist.append(last_odd)
len(addresslist)
# Out:
# 191

# %% [markdown]
# # Now the fees

# %%
#Data prep and unctions 
#Prepping the data to get a list of all the Fees. This step may not be necessary.
Fees = []
Registration = []
for x in details:
    x = x.find('div', {'class': 'col meta'})
    Fees.append(x)

def donations(y):
    try: 
        return int(y.find('span', text = re.compile('Donations')).next_sibling.string.strip().replace(" CHF", ""))
    except:
        None
        return 0
    
def sponsorships(y):
    try:
        return int(y.find('span', text = re.compile('Sponsorship agreement with HCPs')).next_sibling.string.strip().replace(" CHF", ""))
    except:
        None
        return 0

def reg_fees(y):
    try:
        return int(y.find('span', text = re.compile('Registration Fees')).next_sibling.string.strip().replace(" CHF", ""))
    except:
        None
        return 0

def accomodations(y):
    try:
        return int(y.find('span', text = re.compile('Accommodations')).next_sibling.string.strip().replace(" CHF", ""))
    except:
        None
        return 0
    
def fees(y):
    try:
        return int(y.find('span', text = re.compile('Fees')).next_sibling.string.strip().replace(" CHF", ""))
    except:
        None 
        return 0
    
def consultancy(y):
    try: 
        return int(y.find('span', text = re.compile('Related')).next_sibling.string.strip().replace(" CHF", ""))
    except:
        None 
        return 0

# %%
Fees
# Out:
# [<div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              3800 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              17 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              3500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              450 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1050 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Registration Fees</span>
#                                                  560 CHF
#                                              </p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Travel &amp; Accommodations</span>
#                                                  717 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  700 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2527 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2808 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              4250 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              750 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              3900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  4240 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  750 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  30768 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  864 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  10895 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Donations and Grants</span>
#                                                  15689 CHF
#                                              </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2260 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              450 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1080 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1728 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              10042 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              803 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              3163 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              686 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  4320 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  4500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              750 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2108 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              811 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  15816 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              4900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              6800 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2808 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3300 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3780 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3056 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  4268 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  6780 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              97 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              176 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3800 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3400 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              800 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1350 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              110 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1620 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2450 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              88 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3056 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Registration Fees</span>
#                                                  250 CHF
#                                              </p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Travel &amp; Accommodations</span>
#                                                  310 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3184 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              750 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  464 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              50 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1350 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1350 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Registration Fees</span>
#                                                  250 CHF
#                                              </p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Travel &amp; Accommodations</span>
#                                                  310 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              3400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              80 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              8528 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              1390 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              7000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              373 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  10000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              10000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1600 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1581 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              4900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Registration Fees</span>
#                                                  250 CHF
#                                              </p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Travel &amp; Accommodations</span>
#                                                  310 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              4000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  15000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
# ...
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  4992 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  300 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1350 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Registration Fees</span>
#                                                  250 CHF
#                                              </p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Travel &amp; Accommodations</span>
#                                                  310 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  5000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  44550 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Donations and Grants</span>
#                                                  24570 CHF
#                                              </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2450 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              18 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  5543 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              900 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1400 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              51 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  7500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2700 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1200 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              87 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              300 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2080 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              600 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              2000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  14440 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3185 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  1620 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  3500 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  6000 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              450 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Registration Fees</span>
#                                                  560 CHF
#                                              </p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Travel &amp; Accommodations</span>
#                                                  717 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1500 CHF
#                                          </p>
#  <p></p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  12528 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>, <div class="col meta">
#  <p><span class="label title1">Fee for service and consultancy</span></p>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Fees</span>
#                                              1000 CHF
#                                          </p>
#  <p></p>
#  </div>
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Related expenses agreed in the fee for service or consultancy contract including travel &amp; accommodations relevant to the contract</span>
#                                              31 CHF
#                                          </p>
#  </div>
#  </div>, <div class="col meta">
#  <p>
#  <span class="label title1">Contribution to costs of Events</span>
#  </p>
#  <div class="col meta">
#  <div class="col meta fee">
#  <p>
#  <span class="label title2">Sponsorship agreement with HCPs/third parties appointed by HCOs to manage an Event</span>
#                                                  2160 CHF
#                                              </p>
#  </div>
#  </div>
#  <p></p>
#  </div>]

# %%
#Now making the 6 lists

DONATIONS_AND_GRANTS = []
SPONSORSHIPS = []
REG_FEES = []
ACCOMODATION = []
FEES = []
CONSULTANCY = []

for item in Fees:
    donation = donations(item)
    sponsorship = sponsorships(item)
    reg_fee = reg_fees(item)
    accomodation = accomodations(item)
    fee = fees(item)
    consultant = consultancy(item)
    DONATIONS_AND_GRANTS.append(donation)
    SPONSORSHIPS.append(sponsorship)
    REG_FEES.append(reg_fee)
    ACCOMODATION.append(accomodation)
    FEES.append(fee)
    CONSULTANCY.append(consultant)
    
len(DONATIONS_AND_GRANTS)
len(SPONSORSHIPS)
len(REG_FEES)
len(ACCOMODATION)
len(FEES)
len(CONSULTANCY)
# Out:
# 191

# %% [markdown]
# # Creating a dictionary with all of my lists
#
# ## What are my lists again:
# - wholenamelist
# - addresslist
# - DONATIONS_AND_GRANTS
# - SPONSORSHIPS
# - REG_FEES
# - ACCOMODATION
# - FEES
# - CONSULTANCY

# %%
Lundberg = []

for name, address, donation, sponsorship, reg_fee, accomodation, fee, consultant \
in zip(wholenamelist, addresslist, DONATIONS_AND_GRANTS, \
       SPONSORSHIPS, REG_FEES, ACCOMODATION, FEES, CONSULTANCY):
    
    Lundberg_dict = {'NAME': name, 
                    'ADDRESS': address,
                    'DONATIONS AND GRANTS': donation,
                    'SPONSORSHIPS': sponsorship,
                    'REGISTRATION FEES': reg_fee,
                    'TRAVEL AND ACCOMMODATION': accomodation,
                    'FEES': fee,
                    'OTHER EXPENSES AND CONSULTANCY': consultant}
    Lundberg.append(Lundberg_dict)

# %% [markdown]
# # Creating the DF

# %%
df = pd.DataFrame(Lundberg)

# %%
df.head(1)
# Out:
#                    ADDRESS  DONATIONS AND GRANTS  FEES  \
# 0  Forchstrasse 92, Zürich                     0  3800
#
#                      NAME  OTHER EXPENSES AND CONSULTANCY  REGISTRATION FEES  \
# 0  Doctor, Adrian Kormann                              17                  0
#
#    SPONSORSHIPS  TRAVEL AND ACCOMMODATION
# 0             0                         0

# %%
df['DOC, HOS'], df['FULLNAME'] = zip(*df['NAME'].apply(lambda x: x.split(',', 1)))

# %%
del df['NAME']

# %%
df_doctors = df[df['DOC, HOS'] == 'Doctor']
df_doctors.head(1)
# Out:
#                    ADDRESS  DONATIONS AND GRANTS  FEES  \
# 0  Forchstrasse 92, Zürich                     0  3800
#
#    OTHER EXPENSES AND CONSULTANCY  REGISTRATION FEES  SPONSORSHIPS  \
# 0                              17                  0             0
#
#    TRAVEL AND ACCOMMODATION DOC, HOS         FULLNAME
# 0                         0   Doctor   Adrian Kormann

# %%
df_hospitals = df[df['DOC, HOS'] == 'Hospital']
df_hospitals.head(1)
# Out:
#                       ADDRESS  DONATIONS AND GRANTS  FEES  \
# 7  Rue de la Dixence 21, Sion                     0     0
#
#    OTHER EXPENSES AND CONSULTANCY  REGISTRATION FEES  SPONSORSHIPS  \
# 7                               0                  0           700
#
#    TRAVEL AND ACCOMMODATION  DOC, HOS             FULLNAME
# 7                         0  Hospital   Amicale TCC Valais

# %%
del df_doctors['DOC, HOS']
del df_hospitals['DOC, HOS']

# %%
df_hospitals.to_csv('Lundberg_hospitals.csv', index=False)
df_doctors.to_csv('Lundberg_docs.csv', index=False)
