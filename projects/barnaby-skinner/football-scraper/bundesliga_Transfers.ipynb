# %% [markdown]
# # 10 Grafiken zur Vorschau auf die Bundesliga

# %% [markdown]
# **1 Graph of total market value of the Bundesliga**
#
# **5 Graphs on players **
#
# - Graphs of new vs. old players. (1) Games, (2) Age, (3) Goals, (4) Assists, (5) Height.
#
# ** 2 Graphs on Shoes **
#
# - Graph by number of games of transfers
# - Graph of number of goals scored
#
# **2 Graphs on Most Active Agents **
#
# - Graph by amount of players
# - Graph by amount of player value
#
# Source: www.transfermarkt.com

# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.style.use('ggplot')
import dateutil.parser
import re
import time

# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
datestring = time.strftime("%m-%h-%d")
datestring
# Out:
# '07-Jul-26'

# %% [markdown]
# # Functions for Scraper

# %%
#Function to pick every other player, as the scraper receives duplicates
def removing_every_other_player(x):
    return x[::2]

# %%
#Functions for visiting players profil page. Problem was, that the test pages I used, 
#didn't correspond to the ones I was then scraping. The used the language compile selection,
#with English phrases. But the Phrases I should have been using, should have been in German.
#And the there were things like 'Grösse'with a German double S.
def alter(player):
    try:
        return int(player.find('th', text = re.compile('Alter:')).findNext('td').string)
    except:
        return None

# %%
def im_team_seit(player):
    try:
        return player.find('th', text = re.compile('Im Team seit:')).findNext('td').string.strip()
    except:
        return None

# %%
def groesse(player):
    try:
        return int(player.find('th', text = re.compile('Größe:')).findNext('td').string.replace(',', '').replace(' m', ''))
    except:
        return None

# %%
def position(player):
    if player == None:
        return None
    else:
        return player.find('th', text = re.compile('Position:'))\
    .findNext('td').string.strip()

# %%
def club(player):
    if player.find('th', text = re.compile('Aktueller Verein:')).string.strip() == 'Aktueller Verein:':
        return player.find('th', text = re.compile('Aktueller')).findNext('td').findNext('a').find('img').get('alt')
    elif player.find('th', text = re.compile('Current club:')).string.strip() == 'Current club:':
        return player.find('th', text = re.compile('Current club:')).findNext('td').findNext('a').find('img').get('alt')
    else:
        return

# %%
#Function to extract the player's earlier club
def ex_club(player):
    try:
        return player.find('td', {'class': 'hauptlink no-border-links hide-for-small vereinsname'}).findNext('a').string
    except:
        return None

# %%
def agent(player):
    try:
        return player.find('th', text = re.compile("Spielerberater:"))\
    .findNext('td').findNext('a').get('title')
    except:
        return None

# %%
def shoes(player):
    try:
        return player.find('th', text = re.compile("Ausrüster:")).findNext('td')\
    .findNext('a').findNext('img').get('title')
    except:
        return None

# %%
def marktwert(player):
    try:
        return player.find('div', {'class': 'right-td'}).findNext('a').text.replace(',', '').replace(' Mio. €', '0000').replace(' Tsd. €', '0000')
    except:
        return None

# %%
def ausgeliehen_von(player):
    try:
        return player.find('th', text = re.compile("Ausgeliehen von:")).findNext('td').find('a').text
    except:
        return None

# %%
def Minuten(x):
    try:
        return int(x.find('td', {'class': 'zentriert'}).find_next('td', {'class': 'rechts'}).string.replace("'", ''))
    except:
        return None

# %%
#Changing Pandas Age to int
def Age_to_int(x):
    try:
        return int(x)
    except:
        return None

# %% [markdown]
# # Happy Scraping

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
#url = "http://www.transfermarkt.com/raiffeisen-super-league/transfers/wettbewerb/C1/saison_id/2016"
url = "http://www.transfermarkt.de/1-bundesliga/transfers/wettbewerb/L1"
response = requests.get(url, headers=headers)
transfermarkt_soup = BeautifulSoup(response.text, 'html.parser')

# %%
transfermarkt = transfermarkt_soup.find_all('a', {'class': 'spielprofil_tooltip'})

# %%
#not sure why this playing starts the scraped list. Keep an eye on this
transfermarkt.pop(0)
#Only picking every other player
transfermarkt = removing_every_other_player(transfermarkt)

# %%
transfer_dict = []

for spieler in transfermarkt:
    
    #Name
    Name = spieler.string
    print(Name)
    
    #Link
    spieler_link = spieler['href']
    spieler_link = 'http://www.transfermarkt.ch' + spieler_link
    #print(spieler_link)
    
    #Visiting players profil pages
    spieler_profil = requests.get(spieler_link, headers=headers)
    spieler_profil = BeautifulSoup(spieler_profil.text, 'html.parser')
    #print(spieler_profil)
    
    Alter = alter(spieler_profil)
    #print(Alter)
    Grösse = groesse(spieler_profil)
    #print(Grösse)
    Position = position(spieler_profil)
    #print(Position)
    Verein = club(spieler_profil)
    #print(Verein)
    Ex_Verein = ex_club(spieler_profil)
    #print(Ex_Verein)
    Agent = agent(spieler_profil)
    #print(Agent)
    Ausrüster = shoes(spieler_profil)
    #print(Ausrüster)
    Im_team_seit = im_team_seit(spieler_profil)
    #print(Im_team_seit)
    Marktwert = marktwert(spieler_profil)
    Ausgeliehen_von = ausgeliehen_von(spieler_profil)
    #print(Marktwert)
    #print(Marktwert)
    
    #Visiting Leistungsdaten pages
    spieler_leistungsdaten_link = spieler_link.replace('profil', 'leistungsdaten')
    spieler_leistungsdaten_link = spieler_leistungsdaten_link + '/plus/0?saison=ges'
    spieler_leistungsdaten = requests.get(spieler_leistungsdaten_link, headers=headers)
    spieler_leistungsdaten = BeautifulSoup(spieler_leistungsdaten.text, 'html.parser')
    print(spieler_leistungsdaten_link)
    
    #This is okay to do in a list, as every footballer has these parameters. for the Bundesliga
    #I had to accomodate that some players have no data on their performance.
    try: 
        Spiele = spieler_leistungsdaten.find('tfoot')
        leistungsdaten = Spiele.find_all('td', {'class': 'zentriert'})
        leistungsdaten_list = []
        for Daten in leistungsdaten:
            Daten = Daten.string
            leistungsdaten_list.append(Daten)
    
        if len(leistungsdaten_list) > 6:
            Totalspiele = int(leistungsdaten_list[0].replace('-', '0'))
            Tore = int(leistungsdaten_list[1].replace('-', '0'))
            Vorlagen = 0
            Gelbe_Karten = int(leistungsdaten_list[2].replace('-', '0'))
            Gelb_Rote_Karten = int(leistungsdaten_list[3].replace('-', '0'))
            Rote_Karten = int(leistungsdaten_list[4].replace('-', '0'))
    
        else:
            Totalspiele = int(leistungsdaten_list[0].replace('-', '0'))
            Tore = int(leistungsdaten_list[1].replace('-', '0'))
            Vorlagen = int(leistungsdaten_list[2].replace('-', '0'))
            Gelbe_Karten = int(leistungsdaten_list[3].replace('-', '0'))
            Gelb_Rote_Karten = int(leistungsdaten_list[4].replace('-', '0'))
            Rote_Karten = int(leistungsdaten_list[5].replace('-', '0'))
    except:
        None
        #print(leistungsdaten_list)
    
    #Minuten = Minuten(Spiele)
    
    Spieler_Dict = {"Name": Name,
                    "Alter": Alter,
                    "URL": spieler_link,
                    "Grösse": Grösse,
                    "Position": Position,
                    "Verein": Verein,
                    "Wechsel von": Ex_Verein,
                    "Ausgeliehen von": Ausgeliehen_von,
                    "Agent": Agent,
                    "Ausrüster": Ausrüster,
                    "Im Team seit": Im_team_seit,
                    "Total Spiele": Totalspiele,
                    "Tore": Tore,
                    "Vorlagen": Vorlagen,
                    "Gelbe Karten": Gelbe_Karten,
                    "Gelb-Rote Karten": Gelb_Rote_Karten,
                    "Rote Karten": Rote_Karten,
                    'Marktwert': Marktwert,
                    'Minuten': Minuten
                    }
    
    transfer_dict.append(Spieler_Dict)
# Out:
# Mats Hummels
# http://www.transfermarkt.ch/mats-hummels/leistungsdaten/spieler/39728/plus/0?saison=ges
# Renato Sanches
# http://www.transfermarkt.ch/renato-sanches/leistungsdaten/spieler/258027/plus/0?saison=ges
# Niklas Dorsch
# http://www.transfermarkt.ch/niklas-dorsch/leistungsdaten/spieler/251302/plus/0?saison=ges
# Fabian Benko
# http://www.transfermarkt.ch/fabian-benko/leistungsdaten/spieler/337027/plus/0?saison=ges
# Pierre-Emile Höjbjerg
# http://www.transfermarkt.ch/pierre-emile-hojbjerg/leistungsdaten/spieler/167799/plus/0?saison=ges
# Mario Götze
# http://www.transfermarkt.ch/mario-gotze/leistungsdaten/spieler/74842/plus/0?saison=ges
# Pierre-Emile Höjbjerg
# http://www.transfermarkt.ch/pierre-emile-hojbjerg/leistungsdaten/spieler/167799/plus/0?saison=ges
# Sebastian Rode
# http://www.transfermarkt.ch/sebastian-rode/leistungsdaten/spieler/44466/plus/0?saison=ges
# Medhi Benatia
# http://www.transfermarkt.ch/medhi-benatia/leistungsdaten/spieler/45124/plus/0?saison=ges
# Ivan Lucic
# http://www.transfermarkt.ch/ivan-lucic/leistungsdaten/spieler/164145/plus/0?saison=ges
# Serdar Tasci
# http://www.transfermarkt.ch/serdar-tasci/leistungsdaten/spieler/34593/plus/0?saison=ges
# André Schürrle
# http://www.transfermarkt.ch/andre-schurrle/leistungsdaten/spieler/58205/plus/0?saison=ges
# Mario Götze
# http://www.transfermarkt.ch/mario-gotze/leistungsdaten/spieler/74842/plus/0?saison=ges
# Ousmane Dembélé
# http://www.transfermarkt.ch/ousmane-dembele/leistungsdaten/spieler/288230/plus/0?saison=ges
# Sebastian Rode
# http://www.transfermarkt.ch/sebastian-rode/leistungsdaten/spieler/44466/plus/0?saison=ges
# Raphaël Guerreiro
# http://www.transfermarkt.ch/raphael-guerreiro/leistungsdaten/spieler/170986/plus/0?saison=ges
# Marc Bartra
# http://www.transfermarkt.ch/marc-bartra/leistungsdaten/spieler/99922/plus/0?saison=ges
# Emre Mor
# http://www.transfermarkt.ch/emre-mor/leistungsdaten/spieler/283223/plus/0?saison=ges
# Mikel Merino
# http://www.transfermarkt.ch/mikel-merino/leistungsdaten/spieler/338424/plus/0?saison=ges
# Jannik Bandowski
# http://www.transfermarkt.ch/florian-kath/leistungsdaten/spieler/218011/plus/0?saison=ges
# Zack Steffen
# http://www.transfermarkt.ch/zack-steffen/leistungsdaten/spieler/221624/plus/0?saison=ges
# Fabian Schleusener
# http://www.transfermarkt.ch/fabian-schleusener/leistungsdaten/spieler/229176/plus/0?saison=ges
# Caleb Stanko
# http://www.transfermarkt.ch/caleb-stanko/leistungsdaten/spieler/190269/plus/0?saison=ges
# Joshua Mees
# http://www.transfermarkt.ch/joshua-mees/leistungsdaten/spieler/196815/plus/0?saison=ges
# Naby Keïta
# http://www.transfermarkt.ch/naby-keita/leistungsdaten/spieler/302215/plus/0?saison=ges
# Timo Werner
# http://www.transfermarkt.ch/timo-werner/leistungsdaten/spieler/170527/plus/0?saison=ges
# Marius Müller
# http://www.transfermarkt.ch/marius-muller/leistungsdaten/spieler/118161/plus/0?saison=ges
# Benno Schmitz
# http://www.transfermarkt.ch/benno-schmitz/leistungsdaten/spieler/160968/plus/0?saison=ges
# Vitaly Janelt
# http://www.transfermarkt.ch/vitaly-janelt/leistungsdaten/spieler/270171/plus/0?saison=ges
# Idrissa Touré
# http://www.transfermarkt.ch/idrissa-toure/leistungsdaten/spieler/335516/plus/0?saison=ges
# Omer Damari
# http://www.transfermarkt.ch/omer-damari/leistungsdaten/spieler/112703/plus/0?saison=ges
# Zsolt Kalmár
# http://www.transfermarkt.ch/zsolt-kalmar/leistungsdaten/spieler/199268/plus/0?saison=ges
# Georg Teigl
# http://www.transfermarkt.ch/georg-teigl/leistungsdaten/spieler/81698/plus/0?saison=ges
# Stefan Hierländer
# http://www.transfermarkt.ch/stefan-hierlander/leistungsdaten/spieler/59053/plus/0?saison=ges
# Nils Quaschner
# http://www.transfermarkt.ch/nils-quaschner/leistungsdaten/spieler/94559/plus/0?saison=ges
# Ken Gipson
# http://www.transfermarkt.ch/ken-gipson/leistungsdaten/spieler/196822/plus/0?saison=ges
# John-Patrick Strauß
# http://www.transfermarkt.ch/john-patrick-strauss/leistungsdaten/spieler/237113/plus/0?saison=ges

# %% [markdown]
# # Creating and prepping the Dataframe

# %%
#Making the DataFrame
df_transfers = pd.DataFrame(transfer_dict)

# %%
df_transfers.head(1)
# Out:
#                  Agent  Alter Ausgeliehen von                     Ausrüster  \
# 0  HMH Sportmanagement     27            None  adidas ACE 16.1 Primeknit FG
#
#    Gelb-Rote Karten  Gelbe Karten  Grösse Im Team seit Marktwert  \
# 0                 0            41   192.0   01.07.2016
#
#                              Minuten          Name                   Position  \
# 0  <function Minuten at 0x10d8660d0>  Mats Hummels  Abwehr - Innenverteidiger
#
#    Rote Karten  Tore  Total Spiele  \
# 0            1    38           386
#
#                                                  URL             Verein  \
# 0  http://www.transfermarkt.ch/mats-hummels/profi...  FC Bayern München
#
#    Vorlagen    Wechsel von
# 0        16  Bor. Dortmund

# %%
#Dealing with the loan problem. Sorting out only the loaned players. Moving column to the back. 
#Deleting last club column. Renaming the loaned column. Then concating it with the original file.
#So now the last club column is correct. 
df_ausgeliehen = df_transfers[df_transfers['Ausgeliehen von'].notnull()]

def change_column_order(df, col_name, index):
    cols = df.columns.tolist()
    cols.remove(col_name)
    cols.insert(index, col_name)
    return df[cols]

#moving column to the back
df = change_column_order(df_ausgeliehen, 'Ausgeliehen von', 17)

del df['Wechsel von']

#Renaming last column
df.columns = df.columns.str.replace('Ausgeliehen von','Wechsel von')

#Prepping original dataframe
df_transfers = df_transfers[df_transfers['Ausgeliehen von'].isnull()]

del df_transfers['Ausgeliehen von']

#concating the two
df_SL_transfers = pd.concat([df, df_transfers], ignore_index=True)

#Dropping any duplicate values
df_SL_transfers = df_SL_transfers.drop_duplicates()

# %%
#df_SL_transfers[df_SL_transfers['Verein'] == 'VfL Wolfsburg']

# %%
###### Making sure all the clubs are spelt correctly:

#Bayern München
#Bor. Dortmund
#VfL Wolfsburg
#Bay. Leverkusen
#1.FSV Mainz 05*
#TSG Hoffenheim*
#SC Freiburg*
#FC Ingolstadt 04*
#RB Leipzig
#Hertha BSC
#Bor. M'gladbach
#Hamburger SV
#FC Schalke 04*
#E. Frankfurt
#FC Augsburg
#SV Werder Bremen*
#TSG 1899 Hoffenheim*
#1.FC Köln

#FC Bayern München
#Borussia Dortmund
#VfL Wolfsburg
#Bayer 04 Leverkusen
#1.FSV Mainz 05
#TSG Hoffenheim
#SC Freiburg
#FC Ingolstadt 04
#RasenBallsport Leipzig
#Hertha BSC
#Borussia Mönchengladbach
#Hamburger SV
#FC Schalke 04
#Eintracht Frankfurt
#FC Augsburg
#SV Werder Bremen
#TSG 1899 Hoffenheim
#1.FC Köln

def correct_names(x):
    return x.replace('Bayern München', 'FC Bayern München').replace('Bor. Dortmund',\
                    'Borussia Dortmund').replace('Bay. Leverkusen', 'Bayer 04 Leverkusen')\
                    .replace('RB Leipzig', 'RasenBallsport Leipzig').replace("Bor. M'gladbach",\
                    'Borussia Mönchengladbach').replace('E. Frankfurt', 'Eintracht Frankfurt')


df_SL_transfers['*Wechsel von*'] = df_SL_transfers['Wechsel von'].apply(correct_names)
#df_SL_transfers['*Verein*'] = df_SL_transfers['Verein'].apply(fcb)

# %%
df_SL_transfers.describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             Alter  Gelb-Rote Karten  Gelbe Karten      Grösse  Rote Karten  \
# count  264.000000        264.000000    264.000000  260.000000   264.000000
# mean    23.598485          0.621212     19.965909  183.580769     0.681818
# std      4.526827          1.053910     16.909364    6.530387     1.080897
# min     17.000000          0.000000      0.000000  168.000000     0.000000
# 25%     20.000000          0.000000      6.000000         NaN     0.000000
# 50%     23.000000          0.000000     16.000000         NaN     0.000000
# 75%     26.000000          1.000000     28.000000         NaN     1.000000
# max     39.000000          7.000000     80.000000  199.000000     8.000000
#
#              Tore  Total Spiele    Vorlagen
# count  264.000000    264.000000  264.000000
# mean    25.761364    163.291667   13.511364
# std     33.138491     98.798765   15.579548
# min      0.000000      6.000000    0.000000
# 25%      3.000000     90.000000    1.000000
# 50%     15.000000    152.500000    8.500000
# 75%     33.250000    226.500000   20.250000
# max    212.000000    550.000000   91.000000

# %% [markdown]
# # Interesting facts and figures

# %%
#Top, most active agents:
df_SL_transfers['Agent'].value_counts().head()
# Out:
# arena11 sports group                   16
# ROGON Sportmanagement GmbH & Co. KG    14
# Familienangehöriger                    14
# SportsTotal                            14
# PRO Profil GmbH                        10
# Name: Agent, dtype: int64

# %%
#Which shoes are they playing with?
df_SL_transfers['Ausrüster'].value_counts().head(10)
# Out:
# Nike Magista Obra FG - Spark Brilliance             20
# Nike Tiempo Legend VI FG - Spark Brilliance         20
# Nike Mercurial Vapor XI FG - Spark Brilliance       20
# adidas X 16.1 FG                                    19
# adidas ACE 16.1 Primeknit FG                        18
# Nike Mercurial Superfly V FG - Spark Brilliance     17
# Nike Magista Opus FG - Spark Brilliance             10
# Nike Hypervenom Phantom II FG - Spark Brilliance     6
# Nike Hypervenom Phinish II FG - Spark Brilliance     5
# Nike Mercurial Superfly FG - Radiant Reveal          2
# Name: Ausrüster, dtype: int64

# %%
df_SL_transfers['Rote Karten'].sort_values(ascending=False).head(3)
# Out:
# 143    8
# 230    5
# 137    5
# Name: Rote Karten, dtype: int64

# %%
df_SL_transfers[df_SL_transfers['Rote Karten'] == 8]
# Out:
#                     Agent  Alter Ausrüster  Gelb-Rote Karten  Gelbe Karten  \
# 143  arena11 sports group     31      None                 0            60
#
#      Grösse Im Team seit Marktwert                            Minuten  \
# 143   188.0   01.07.2016            <function Minuten at 0x10d8660d0>
#
#                Name               Position  Rote Karten  Tore  Total Spiele  \
# 143  Vedad Ibisevic  Sturm - Mittelstürmer            8   139           366
#
#                                                    URL      Verein  Vorlagen  \
# 143  http://www.transfermarkt.ch/vedad-ibisevic/pro...  Hertha BSC        48
#
#        Wechsel von  *Wechsel von*
# 143  VfB Stuttgart  VfB Stuttgart

# %%
df_SL_transfers['Alle Karten'] = df_SL_transfers['Gelbe Karten'] + df_SL_transfers['Rote Karten'] + df_SL_transfers['Gelb-Rote Karten']
df_SL_transfers['Alle Karten'].sort_values(ascending=False).head(3)
# Out:
# 102    89
# 290    83
# 0      72
# Name: Alle Karten, dtype: int64

# %%
df_SL_transfers[df_SL_transfers['Alle Karten'] == 89]
# Out:
#                                                  Agent  Alter  \
# 102  GRASS IS GREEN THOMAS BÖHM SPORTS MANAGEMENT GmbH     36
#
#                         Ausrüster  Gelb-Rote Karten  Gelbe Karten  Grösse  \
# 102  adidas ACE 16.1 Primeknit FG                 4            80   190.0
#
#     Im Team seit Marktwert                            Minuten            Name  \
# 102   01.07.2016            <function Minuten at 0x10d8660d0>  Martin Stranzl
#
#                       Position  Rote Karten  Tore  Total Spiele  \
# 102  Abwehr - Innenverteidiger            5    23           468
#
#                                                    URL        Verein  \
# 102  http://www.transfermarkt.ch/martin-stranzl/pro...  Karriereende
#
#      Vorlagen      Wechsel von             *Wechsel von*  Alle Karten
# 102        16  Bor. M'gladbach  Borussia Mönchengladbach           89

# %%
df_SL_transfers.describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             Alter  Gelb-Rote Karten  Gelbe Karten      Grösse  Rote Karten  \
# count  264.000000        264.000000    264.000000  260.000000   264.000000
# mean    23.598485          0.621212     19.965909  183.580769     0.681818
# std      4.526827          1.053910     16.909364    6.530387     1.080897
# min     17.000000          0.000000      0.000000  168.000000     0.000000
# 25%     20.000000          0.000000      6.000000         NaN     0.000000
# 50%     23.000000          0.000000     16.000000         NaN     0.000000
# 75%     26.000000          1.000000     28.000000         NaN     1.000000
# max     39.000000          7.000000     80.000000  199.000000     8.000000
#
#              Tore  Total Spiele    Vorlagen  Alle Karten
# count  264.000000    264.000000  264.000000   264.000000
# mean    25.761364    163.291667   13.511364    21.268939
# std     33.138491     98.798765   15.579548    18.090594
# min      0.000000      6.000000    0.000000     0.000000
# 25%      3.000000     90.000000    1.000000     6.000000
# 50%     15.000000    152.500000    8.500000    17.000000
# 75%     33.250000    226.500000   20.250000    30.000000
# max    212.000000    550.000000   91.000000    89.000000

# %% [markdown]
# # Creating Dataframes to establish gain, losses of each club

# %%
df_SL_Vereine = pd.read_csv("BL_Vereine_16_17.csv")

# %%
#FOR THE GAMES
#Merging the Files
df_SL_Zuzuege = df_SL_transfers.merge(df_SL_Vereine, left_on = 'Verein', right_on ='BL-Verein') 
df_SL_Abgänge = df_SL_transfers.merge(df_SL_Vereine, left_on = '*Wechsel von*', right_on ='BL-Verein')
#Working out totals of bought players
Total_Minuten_Zuzüge = pd.DataFrame(df_SL_Zuzuege.groupby('Verein')['Total Spiele'].sum())
#Working out totals of sold players
Total_Minuten_Abgänge = pd.DataFrame(df_SL_Abgänge.groupby('*Wechsel von*')['Total Spiele'].sum())
#Resetting the Index of both the new frames
Total_Minuten_Abgänge.reset_index(inplace=True)
Total_Minuten_Zuzüge.reset_index(inplace=True)
#Merging the data sets
Zuzüge_Abgänge = Total_Minuten_Zuzüge.merge(Total_Minuten_Abgänge, left_on = 'Verein', right_on ='*Wechsel von*') 
#Working out the difference
Zuzüge_Abgänge['Transfer_Differenz_Spiele'] = Zuzüge_Abgänge['Total Spiele_x'] - Zuzüge_Abgänge['Total Spiele_y']

# %%
#Deleting the columns we don't need:
del Zuzüge_Abgänge['*Wechsel von*']

# %%
#Renaming columns
Zuzüge_Abgänge.columns = ['Verein', 'Total Spiele Zuzüge', 'Total Spiele Abgänge', 'Total-Spiel-Differenz']

# %%
#FOR THE GOALS
Total_goals_Zuzüge = pd.DataFrame(df_SL_Zuzuege.groupby('Verein')['Tore'].sum())
Total_goals_Abgänge = pd.DataFrame(df_SL_Abgänge.groupby('*Wechsel von*')['Tore'].sum())
Total_goals_Abgänge.reset_index(inplace=True)
Total_goals_Zuzüge.reset_index(inplace=True)
Tore = Total_goals_Zuzüge.merge(Total_goals_Abgänge, left_on = 'Verein', right_on ='*Wechsel von*')
Tore['Transfer_Differenz_Tore'] = Tore['Tore_x'] - Tore['Tore_y']
del Tore['*Wechsel von*']

# %%
#FOR THE Assists
Total_assists_Zuzüge = pd.DataFrame(df_SL_Zuzuege.groupby('Verein')['Vorlagen'].sum())
Total_assists_Abgänge = pd.DataFrame(df_SL_Abgänge.groupby('*Wechsel von*')['Vorlagen'].sum())
Total_assists_Abgänge.reset_index(inplace=True)
Total_assists_Zuzüge.reset_index(inplace=True)
Vorlagen = Total_assists_Zuzüge.merge(Total_assists_Abgänge, left_on = 'Verein', right_on ='*Wechsel von*')
Vorlagen['Transfer_Differenz_Vorlagen'] = Vorlagen['Vorlagen_x'] - Vorlagen['Vorlagen_y']
del Vorlagen['*Wechsel von*']

# %%
#FOR THE HEIGHT
Total_height_Zuzüge = pd.DataFrame(df_SL_Zuzuege.groupby('Verein')['Grösse'].mean())
Total_height_Abgänge = pd.DataFrame(df_SL_Abgänge.groupby('*Wechsel von*')['Grösse'].mean())
Total_height_Abgänge.reset_index(inplace=True)
Total_height_Zuzüge.reset_index(inplace=True)
Grösse = Total_height_Zuzüge.merge(Total_height_Abgänge, left_on = 'Verein', right_on ='*Wechsel von*')
Grösse['Transfer_Differenz_Grösse'] = Grösse['Grösse_x'] - Grösse['Grösse_y']
del Grösse['*Wechsel von*']

# %%
#FOR THE AGE
Total_age_Zuzüge = pd.DataFrame(df_SL_Zuzuege.groupby('Verein')['Alter'].mean())
Total_age_Abgänge = pd.DataFrame(df_SL_Abgänge.groupby('*Wechsel von*')['Alter'].mean())
Total_age_Abgänge.reset_index(inplace=True)
Total_age_Zuzüge.reset_index(inplace=True)
Alter = Total_age_Zuzüge.merge(Total_age_Abgänge, left_on = 'Verein', right_on ='*Wechsel von*')
Alter['Transfer_Differenz_Alter'] = Alter['Alter_x'] - Alter['Alter_y']
del Alter['*Wechsel von*']
Alter
# Out:
#                       Verein    Alter_x    Alter_y  Transfer_Differenz_Alter
# 0                  1.FC Köln  22.250000  24.400000                 -2.150000
# 1             1.FSV Mainz 05  23.666667  28.333333                 -4.666667
# 2        Bayer 04 Leverkusen  23.000000  23.454545                 -0.454545
# 3          Borussia Dortmund  23.100000  26.333333                 -3.233333
# 4   Borussia Mönchengladbach  21.777778  25.875000                 -4.097222
# 5        Eintracht Frankfurt  22.000000  23.888889                 -1.888889
# 6                FC Augsburg  25.857143  27.777778                 -1.920635
# 7          FC Bayern München  20.250000  23.800000                 -3.550000
# 8           FC Ingolstadt 04  21.833333  22.500000                 -0.666667
# 9              FC Schalke 04  20.555556  25.750000                 -5.194444
# 10              Hamburger SV  21.625000  25.583333                 -3.958333
# 11                Hertha BSC  26.000000  26.800000                 -0.800000
# 12    RasenBallsport Leipzig  21.125000  22.400000                 -1.275000
# 13               SC Freiburg  22.888889  22.545455                  0.343434
# 14           SV Darmstadt 98  20.875000  26.071429                 -5.196429
# 15          SV Werder Bremen  25.363636  21.000000                  4.363636
# 16       TSG 1899 Hoffenheim  23.666667  20.500000                  3.166667
# 17             VfL Wolfsburg  20.727273  26.000000                 -5.272727

# %%
#Merging Zuzüge_Abgänge, Tore, Vorlagen, Grösse. Deleting the columns 
#we don't need. And renaming the ones we do.
Transferbilanz = Zuzüge_Abgänge.merge(Tore, left_on = 'Verein', right_on ='Verein')
Transferbilanz = Transferbilanz.merge(Vorlagen, left_on = 'Verein', right_on ='Verein')
Transferbilanz = Transferbilanz.merge(Grösse, left_on = 'Verein', right_on ='Verein')
Transferbilanz = Transferbilanz.merge(Alter, left_on = 'Verein', right_on ='Verein')


#Renaming columns
Transferbilanz.columns = ['Verein', 'Total Spiele Zuzüge', 'Total Spiele Abgänge', 'Total-Spiel-Differenz', 'Tore-Total-Zuzüge', 'Tore-Total-Abgänge', 'Tore-Differenz', 'Vorlagen Zuzüge', 'Vorlagen Abgänge', 'Vorlagen-Differenz', 'Grösse-Schnitt Zuzüge', 'Grösse-Schnitt Abgänger', 'Grösse-Differenz', 'Alters-Schnitt Zuzüge', 'Alters-Schnitt Abgänger', 'Alters-Differenz']
##Making Club name also the Index, handy when making the graphs
Transferbilanz.index = Transferbilanz['Verein']
Transferbilanz
# Out:
#                                             Verein  Total Spiele Zuzüge  \
# Verein
# 1.FC Köln                                1.FC Köln                 1203
# 1.FSV Mainz 05                      1.FSV Mainz 05                 1454
# Bayer 04 Leverkusen            Bayer 04 Leverkusen                 1745
# Borussia Dortmund                Borussia Dortmund                 1633
# Borussia Mönchengladbach  Borussia Mönchengladbach                 1260
# Eintracht Frankfurt            Eintracht Frankfurt                  960
# FC Augsburg                            FC Augsburg                 1584
# FC Bayern München                FC Bayern München                  560
# FC Ingolstadt 04                  FC Ingolstadt 04                  706
# FC Schalke 04                        FC Schalke 04                 1219
# Hamburger SV                          Hamburger SV                 1179
# Hertha BSC                              Hertha BSC                  505
# RasenBallsport Leipzig      RasenBallsport Leipzig                 1001
# SC Freiburg                            SC Freiburg                 1356
# SV Darmstadt 98                    SV Darmstadt 98                  644
# SV Werder Bremen                  SV Werder Bremen                 2436
# TSG 1899 Hoffenheim            TSG 1899 Hoffenheim                 2095
# VfL Wolfsburg                        VfL Wolfsburg                 1275
#
#                           Total Spiele Abgänge  Total-Spiel-Differenz  \
# Verein
# 1.FC Köln                                  937                    266
# 1.FSV Mainz 05                            1202                    252
# Bayer 04 Leverkusen                       1679                     66
# Borussia Dortmund                          936                    697
# Borussia Mönchengladbach                  1971                   -711
# Eintracht Frankfurt                       1188                   -228
# FC Augsburg                               2033                   -449
# FC Bayern München                         1014                   -454
# FC Ingolstadt 04                           307                    399
# FC Schalke 04                             1981                   -762
# Hamburger SV                              2367                  -1188
# Hertha BSC                                1101                   -596
# RasenBallsport Leipzig                     710                    291
# SC Freiburg                               1272                     84
# SV Darmstadt 98                           2543                  -1899
# SV Werder Bremen                           141                   2295
# TSG 1899 Hoffenheim                        605                   1490
# VfL Wolfsburg                             1173                    102
#
#                           Tore-Total-Zuzüge  Tore-Total-Abgänge  \
# Verein
# 1.FC Köln                               244                  68
# 1.FSV Mainz 05                          217                 100
# Bayer 04 Leverkusen                     167                 211
# Borussia Dortmund                       283                 192
# Borussia Mönchengladbach                137                 250
# Eintracht Frankfurt                     124                 191
# FC Augsburg                             400                 351
# FC Bayern München                        55                 135
# FC Ingolstadt 04                        122                 103
# FC Schalke 04                           282                 255
# Hamburger SV                            191                 517
# Hertha BSC                              161                  64
# RasenBallsport Leipzig                  224                 130
# SC Freiburg                             177                 173
# SV Darmstadt 98                          78                 220
# SV Werder Bremen                        448                   3
# TSG 1899 Hoffenheim                     391                  98
# VfL Wolfsburg                           219                 160
#
#                           Tore-Differenz  Vorlagen Zuzüge  Vorlagen Abgänge  \
# Verein
# 1.FC Köln                            176              114                87
# 1.FSV Mainz 05                       117              126                64
# Bayer 04 Leverkusen                  -44              124                93
# Borussia Dortmund                     91              247               127
# Borussia Mönchengladbach            -113               79               109
# Eintracht Frankfurt                  -67               73                91
# FC Augsburg                           49              165               138
# FC Bayern München                    -80               24               119
# FC Ingolstadt 04                      19               53                46
# FC Schalke 04                         27              137               174
# Hamburger SV                        -326              125               228
# Hertha BSC                            97               70                93
# RasenBallsport Leipzig                94               95                84
# SC Freiburg                            4               93                76
# SV Darmstadt 98                     -142               23               173
# SV Werder Bremen                     445              173                15
# TSG 1899 Hoffenheim                  293              192                41
# VfL Wolfsburg                         59               99                57
#
#                           Vorlagen-Differenz  Grösse-Schnitt Zuzüge  \
# Verein
# 1.FC Köln                                 27             183.714286
# 1.FSV Mainz 05                            62             182.111111
# Bayer 04 Leverkusen                       31             183.400000
# Borussia Dortmund                        120             179.100000
# Borussia Mönchengladbach                 -30             187.666667
# Eintracht Frankfurt                      -18             181.333333
# FC Augsburg                               27             186.142857
# FC Bayern München                        -95             181.500000
# FC Ingolstadt 04                           7             185.833333
# FC Schalke 04                            -37             183.111111
# Hamburger SV                            -103             178.875000
# Hertha BSC                               -23             184.500000
# RasenBallsport Leipzig                    11             183.125000
# SC Freiburg                               17             182.666667
# SV Darmstadt 98                         -150             183.375000
# SV Werder Bremen                         158             183.909091
# TSG 1899 Hoffenheim                      151             185.666667
# VfL Wolfsburg                             42             185.222222
#
#                           Grösse-Schnitt Abgänger  Grösse-Differenz  \
# Verein
# 1.FC Köln                              186.200000         -2.485714
# 1.FSV Mainz 05                         185.000000         -2.888889
# Bayer 04 Leverkusen                    186.100000         -2.700000
# Borussia Dortmund                      183.000000         -3.900000
# Borussia Mönchengladbach               185.125000          2.541667
# Eintracht Frankfurt                    181.888889         -0.555556
# FC Augsburg                            182.777778          3.365079
# FC Bayern München                      183.800000         -2.300000
# FC Ingolstadt 04                       183.500000          2.333333
# FC Schalke 04                          186.500000         -3.388889
# Hamburger SV                           181.750000         -2.875000
# Hertha BSC                             181.400000          3.100000
# RasenBallsport Leipzig                 180.000000          3.125000
# SC Freiburg                            186.181818         -3.515152
# SV Darmstadt 98                        184.428571         -1.053571
# SV Werder Bremen                       182.000000          1.909091
# TSG 1899 Hoffenheim                    184.000000          1.666667
# VfL Wolfsburg                          190.800000         -5.577778
#
#                           Alters-Schnitt Zuzüge  Alters-Schnitt Abgänger  \
# Verein
# 1.FC Köln                             22.250000                24.400000
# 1.FSV Mainz 05                        23.666667                28.333333
# Bayer 04 Leverkusen                   23.000000                23.454545
# Borussia Dortmund                     23.100000                26.333333
# Borussia Mönchengladbach              21.777778                25.875000
# Eintracht Frankfurt                   22.000000                23.888889
# FC Augsburg                           25.857143                27.777778
# FC Bayern München                     20.250000                23.800000
# FC Ingolstadt 04                      21.833333                22.500000
# FC Schalke 04                         20.555556                25.750000
# Hamburger SV                          21.625000                25.583333
# Hertha BSC                            26.000000                26.800000
# RasenBallsport Leipzig                21.125000                22.400000
# SC Freiburg                           22.888889                22.545455
# SV Darmstadt 98                       20.875000                26.071429
# SV Werder Bremen                      25.363636                21.000000
# TSG 1899 Hoffenheim                   23.666667                20.500000
# VfL Wolfsburg                         20.727273                26.000000
#
#                           Alters-Differenz
# Verein
# 1.FC Köln                        -2.150000
# 1.FSV Mainz 05                   -4.666667
# Bayer 04 Leverkusen              -0.454545
# Borussia Dortmund                -3.233333
# Borussia Mönchengladbach         -4.097222
# Eintracht Frankfurt              -1.888889
# FC Augsburg                      -1.920635
# FC Bayern München                -3.550000
# FC Ingolstadt 04                 -0.666667
# FC Schalke 04                    -5.194444
# Hamburger SV                     -3.958333
# Hertha BSC                       -0.800000
# RasenBallsport Leipzig           -1.275000
# SC Freiburg                       0.343434
# SV Darmstadt 98                  -5.196429
# SV Werder Bremen                  4.363636
# TSG 1899 Hoffenheim               3.166667
# VfL Wolfsburg                    -5.272727

# %%
Transferbilanz.head(1)
# Out:
#               Verein  Total Spiele Zuzüge  Total Spiele Abgänge  \
# Verein
# 1.FC Köln  1.FC Köln                 1203                   937
#
#            Total-Spiel-Differenz  Tore-Total-Zuzüge  Tore-Total-Abgänge  \
# Verein
# 1.FC Köln                    266                244                  68
#
#            Tore-Differenz  Vorlagen Zuzüge  Vorlagen Abgänge  \
# Verein
# 1.FC Köln             176              114                87
#
#            Vorlagen-Differenz  Grösse-Schnitt Zuzüge  Grösse-Schnitt Abgänger  \
# Verein
# 1.FC Köln                  27             183.714286                    186.2
#
#            Grösse-Differenz  Alters-Schnitt Zuzüge  Alters-Schnitt Abgänger  \
# Verein
# 1.FC Köln         -2.485714                  22.25                     24.4
#
#            Alters-Differenz
# Verein
# 1.FC Köln             -2.15

# %% [markdown]
# # Finally, graphing

# %%
#Experience

fig, ax = plt.subplots(figsize =(5,9))

#Font
csfont = {'fontname':'DIN Condensed'}

Transferbilanz['Total-Spiel-Differenz'].sort_values(ascending=True).plot(kind='barh', ax = ax, legend=False, color=['Tomato'])
plt.axes

ax.set_axis_bgcolor("WhiteSmoke")

ax.set_ylabel('')

ax.xaxis.grid(color='darkgrey', linestyle=':', linewidth=0.5)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.tick_params(
    #axis='x',
    top='off',
    which='off',
    left='off',
    right='off',
    bottom='off',
    labeltop='off',
    labelbottom='off')

#labelling, getting rid of boarders
ax.set_xlabel('Spielminuten der Neuzugänge versus Abgänge', **csfont, fontsize=12)
ax.set_title("Werder Bremen hat an Spielerfahrung zugelegt", **csfont, fontsize=24)

#Showing Median
#median = Transferbilanz['Total-Spiel-Differenz'].median()
#ax.plot([median, median], [0, 10], c='black', linestyle=':')
#ax.annotate(s='Durchschnitt aller Vereine', xy=(-1300,4), color='black')

ax.set_axisbelow(True)
plt.savefig('Erfahrung.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Erfahrung.png', transparent=False, bbox_inches='tight')

# %%
#Age

fig, ax = plt.subplots(figsize =(5,9))

#Font
csfont = {'fontname':'DIN Condensed'}

Transferbilanz['Alters-Differenz'].sort_values(ascending=True).plot(kind='barh', ax = ax, legend=False, color=['Tomato'])
plt.axes

ax.set_axis_bgcolor("WhiteSmoke")

ax.set_ylabel('')

ax.xaxis.grid(color='darkgrey', linestyle=':', linewidth=0.5)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.tick_params(
    #axis='x',
    top='off',
    which='off',
    left='off',
    right='off',
    bottom='off',
    labeltop='off',
    labelbottom='off')

#labelling, getting rid of boarders
ax.set_xlabel('Spielminuten der Neuzugänge versus Abgänge', **csfont, fontsize=12)
ax.set_title("Neuzugänge sind im Schnitt zwei Jahre jünger", **csfont, fontsize=24)

#Showing Median
median = Transferbilanz['Alters-Differenz'].median()
ax.plot([median, median], [0, 18], c='black', linestyle=':')
ax.annotate(s='Durchschnitt aller Vereine', xy=(-1.8,15), color='black')

ax.set_axisbelow(True)
plt.savefig('Alter.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Alter.png', transparent=False, bbox_inches='tight')

# %%
#Tore

fig, ax = plt.subplots(figsize =(5,9))

#Font
csfont = {'fontname':'DIN Condensed'}

Transferbilanz['Tore-Differenz'].sort_values(ascending=False).plot(kind='barh', ax = ax, legend=False, color=['Tomato'])
plt.axes

ax.set_axis_bgcolor("WhiteSmoke")

ax.set_ylabel('')

ax.xaxis.grid(color='darkgrey', linestyle=':', linewidth=0.5)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.tick_params(
    #axis='x',
    top='off',
    which='off',
    left='off',
    right='off',
    bottom='off',
    labeltop='off',
    labelbottom='off')

#labelling, getting rid of boarders
ax.set_xlabel('Karriere-Tore der Neuzugänge versus Abgänge', **csfont, fontsize=12)
ax.set_title("Der HSV hat an Torgefährlichkeit verloren", **csfont, fontsize=24)

#Showing Median
#median = Transferbilanz['Tore-Differenz'].median()
#ax.plot([median, median], [-4, 10], c='black', linestyle=':')
#ax.annotate(s='Durchschnitt aller Vereine', xy=(-190, 5), color='black')

ax.set_axisbelow(True)
plt.savefig('Tore.pdf', transparent=False, bbox_inches='tight')
plt.savefig('Tore.png', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize =(5,9))

#Font
csfont = {'fontname':'DIN Condensed'}

Transferbilanz['Vorlagen-Differenz'].sort_values(ascending=False).plot(kind='barh', ax = ax, legend=False, color=['Tomato'])
plt.axes

ax.set_axis_bgcolor("WhiteSmoke")

ax.set_ylabel('')

ax.xaxis.grid(color='darkgrey', linestyle=':', linewidth=0.5)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.tick_params(
    #axis='x',
    top='off',
    which='off',
    left='off',
    right='off',
    bottom='off',
    labeltop='off',
    labelbottom='off')

#labelling, getting rid of boarders
ax.set_xlabel('Karriere-Vorlagen der Neuzugänge versus Abgänge', **csfont, fontsize=12)
ax.set_title("Wer bereitet in Darmstadt künftig die Tore vor?", **csfont, fontsize=24)

ax.set_axisbelow(True)

plt.savefig('Vorlagen.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Vorlagen.png', transparent=True, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize =(7,5))

#Font
csfont = {'fontname':'DIN Condensed'}

Transferbilanz['Grösse-Differenz'].sort_values(ascending=True).plot(kind='bar', ax = ax, legend=False, color=['Tomato'])
plt.axes

ax.set_axis_bgcolor("WhiteSmoke")

ax.set_ylabel('')

ax.xaxis.grid(color='darkgrey', linestyle=':', linewidth=0.5)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.tick_params(
    #axis='x',
    top='off',
    which='off',
    left='off',
    right='off',
    bottom='off',
    labeltop='off',
    labelbottom='off')

#labelling, getting rid of boarders
ax.set_xlabel('Grösse Neuzugänge versus Abgänge, in cm', **csfont, fontsize=12)
ax.set_title("Augsburg-Zugänge sind knapp 4 cm grösser", **csfont, fontsize=24)

#Showing Median
#median = Transferbilanz['Grösse-Differenz'].median()
#ax.plot([median, median], [-4, 5], c='black', linestyle=':')
#ax.annotate(s='Durchschnitt aller Vereine', xy=(0.4,1.1), color='black')

ax.set_axisbelow(True)

plt.savefig('Groesse.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Groesse.png', transparent=True, bbox_inches='tight')

# %%
pd.DataFrame(df_SL_transfers).to_csv(datestring + '16_17_BL_Transfers.csv', index=False)

# %%
csfont = {'fontname':'DIN Condensed'}

fig, ax = plt.subplots(figsize =(7,5))
df_SL_transfers.groupby('Ausrüster')['Tore'].sum().sort_values(ascending=True).tail(3).plot(kind='barh', ax=ax, color=['Tomato'])
ax.set_ylabel('')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.set_title("Die besten Schuhe der Bundesliga", **csfont, fontsize=24)

plt.savefig('Schuhe.pdf', transparent=False, bbox_inches='tight')
plt.savefig('Schuhe.png', transparent=False, bbox_inches='tight')

# %%
df_SL_transfers[df_SL_transfers['Ausrüster'] == 'adidas X 16.1 FG']
# Out:
#                                           Agent  Alter         Ausrüster  \
# 53                      GOODWIN SPORTMANAGEMENT     21  adidas X 16.1 FG
# 55                       Haspel Sportconsulting     25  adidas X 16.1 FG
# 82                 Soccerdreamz Sportconsulting     32  adidas X 16.1 FG
# 87    ISMG International Sports Management GmbH     23  adidas X 16.1 FG
# 93                                  SportsTotal     23  adidas X 16.1 FG
# 97                                 Drazan Gilja     23  adidas X 16.1 FG
# 103                             World in Motion     23  adidas X 16.1 FG
# 117     Siebert & Backs Fussballmanagement GmbH     26  adidas X 16.1 FG
# 131                     Rechtsanwalt Rubinstein     25  adidas X 16.1 FG
# 167                             Soccertalk GmbH     28  adidas X 16.1 FG
# 177  Stars & Friends International Holding GmbH     30  adidas X 16.1 FG
# 189                             PRO Profil GmbH     21  adidas X 16.1 FG
# 191                                 Milan Kacar     29  adidas X 16.1 FG
# 193   ISMG International Sports Management GmbH     36  adidas X 16.1 FG
# 196                              extratime GmbH     21  adidas X 16.1 FG
# 237                                 SportsTotal     25  adidas X 16.1 FG
# 264                   Sven Jäger & Guido Walter     30  adidas X 16.1 FG
# 272                                   Ungeklärt     25  adidas X 16.1 FG
# 301                             Soccertalk GmbH     20  adidas X 16.1 FG
#
#      Gelb-Rote Karten  Gelbe Karten  Grösse Im Team seit Marktwert  \
# 53                  0             2   193.0   26.07.2016
# 55                  0            26   184.0   22.07.2016
# 82                  0            24   196.0   01.07.2016
# 87                  0            22   199.0   01.07.2016
# 93                  0            16   181.0   01.07.2015
# 97                  0             9   185.0   01.07.2016
# 103                 1            47   184.0   01.09.2010
# 117                 1            52   182.0   01.07.2016
# 131                 1            36   180.0   01.07.2015
# 167                 0            24   183.0   01.07.2016
# 177                 0            17   178.0   01.07.2016
# 189                 1            16   188.0   01.07.2016
# 191                 1            42   185.0   19.07.2016
# 193                 0            28   182.0   01.07.2016
# 196                 1             5   175.0   01.07.2016
# 237                 1            51   184.0   01.07.2016
# 264                 0            46   171.0   19.07.2016
# 272                 1            11   177.0   01.07.2016
# 301                 0             4   176.0   01.07.2014
#
#                                Minuten                Name  \
# 53   <function Minuten at 0x10d8660d0>          Ivan Lucic
# 55   <function Minuten at 0x10d8660d0>      André Schürrle
# 82   <function Minuten at 0x10d8660d0>        Dario Kresic
# 87   <function Minuten at 0x10d8660d0>  Jannik Vestergaard
# 93   <function Minuten at 0x10d8660d0>         Josip Drmic
# 97   <function Minuten at 0x10d8660d0>     Branimir Hrgota
# 103  <function Minuten at 0x10d8660d0>  Martin Hinteregger
# 117  <function Minuten at 0x10d8660d0>         Marco Höger
# 131  <function Minuten at 0x10d8660d0>  Maximilian Beister
# 167  <function Minuten at 0x10d8660d0>     Artjoms Rudnevs
# 177  <function Minuten at 0x10d8660d0>        Dusan Svento
# 189  <function Minuten at 0x10d8660d0>     Matti Steinmann
# 191  <function Minuten at 0x10d8660d0>         Gojko Kacar
# 193  <function Minuten at 0x10d8660d0>          Ivica Olic
# 196  <function Minuten at 0x10d8660d0>      Philipp Müller
# 237  <function Minuten at 0x10d8660d0>         Felix Kroos
# 264  <function Minuten at 0x10d8660d0>        Marco Sailer
# 272  <function Minuten at 0x10d8660d0>     Andrej Kramaric
# 301  <function Minuten at 0x10d8660d0>     Joel Gerezgiher
#
#                                Position  Rote Karten  Tore  Total Spiele  \
# 53                              Torwart            0     2            78
# 55                   Sturm - Linksaußen            1    94           326
# 82                              Torwart            0     0           181
# 87            Abwehr - Innenverteidiger            0    15           163
# 93                Sturm - Mittelstürmer            1    70           203
# 97                Sturm - Mittelstürmer            0    49           136
# 103           Abwehr - Innenverteidiger            2    26           259
# 117   Mittelfeld - Zentrales Mittelfeld            1    27           257
# 131                 Sturm - Rechtsaußen            1    58           198
# 167               Sturm - Mittelstürmer            0   110           268
# 177         Abwehr - Linker Verteidiger            0    26           317
# 189   Mittelfeld - Zentrales Mittelfeld            0    13           141
# 191  Mittelfeld - Defensives Mittelfeld            2    34           211
# 193               Sturm - Mittelstürmer            0   133           403
# 196  Mittelfeld - Offensives Mittelfeld            0    32           119
# 237  Mittelfeld - Defensives Mittelfeld            1    37           235
# 0  GM FOOT     29  Nike Magista Opus FG - Spark Brilliance                 0
#
#    Gelbe Karten  Grösse Im Team seit Marktwert  \
# 0            71   190.0   15.07.2016
#
#                              Minuten           Name  \
# 0  <function Minuten at 0x10d8660d0>  Medhi Benatia
#
#                     Position  Rote Karten  Tore  Total Spiele  \
# 0  Abwehr - Innenverteidiger            1    17           271
#
#                                                  URL          Verein  \
# 0  http://www.transfermarkt.ch/medhi-benatia/prof...  Juventus Turin
#
#    Vorlagen        Wechsel von         *Wechsel von*  Alle Karten
# 0         6  FC Bayern München  FC FC Bayern München           72

# %%
fig, ax = plt.subplots(figsize =(7,5))
df_SL_transfers['Agent'].value_counts().sort_values(ascending=True).tail(5).plot(kind='barh', ax=ax, color=['Tomato'])
ax.set_title("Die aktivsten Agenten der Bundesliga", **csfont, fontsize=24)
plt.savefig('Agenten.pdf', transparent=False, bbox_inches='tight')
plt.savefig('Agenten.png', transparent=False, bbox_inches='tight')

# %%
df_SL_transfers
# Out:
#                                                  Agent  Alter  \
# 0                                              GM FOOT     29
# 1                                    Soccer-Concept AG     19
# 2    Schwarzer & Rummenigge Sports Management GmbH ...     19
# 3                      Rummenigge Sport Marketing GmbH     19
# 5                                       Sports 11 GmbH     20
# 6                               Haspel Sportconsulting     19
# 9                           Sports Entertainment Group     21
# 11                                    Together For You     19
# 12                                 Familienangehöriger     23
# 13                          Sports Entertainment Group     21
# 15                                         SportsTotal     18
# 16                                  EW Management GmbH     23
# 19                                      Friends Sports     20
# 20                                          TDS SPORTS     21
# 21                                         SportsTotal     24
# 23                                 DLT Sportmanagement     21
# 24                            H.S.P. Sports-Management     21
# 25                 ROGON Sportmanagement GmbH & Co. KG     22
# 26                                     AKA Global GmbH     21
# 27                               neblung sportsnetwork     21
# 28                 ROGON Sportmanagement GmbH & Co. KG     21
# 30                 ROGON Sportmanagement GmbH & Co. KG     19
# 33                                 Familienangehöriger     19
# 36                 ROGON Sportmanagement GmbH & Co. KG     21
# 37                                         LIAN SPORTS     22
# 38                                    GT Talents World     23
# 39                                                None     19
# 40                                    Robert Schneider     20
# 41                              Haspel Sportconsulting     21
# 42           ISMG International Sports Management GmbH     24
# ..                                                 ...    ...
# 301                                    Soccertalk GmbH     20
# 302                                Familienangehöriger     27
# 304                                    PRO Profil GmbH     25
# 306                            Headtrick GmbH & Co. KG     20
# 307                         Sports Entertainment Group     29
# 308                ROGON Sportmanagement GmbH & Co. KG     28
# 309                                               None     22
# 311                                MET Management GmbH     20
# 313                                 Sports United GmbH     22
# 314                             Haspel Sportconsulting     25
# 317                              Wasserman Media Group     21
# 318                                   act SPORTS GROUP     23
# 319         Mondial Sport Management & Consulting Sarl     23
# 320  GRASS IS GREEN THOMAS BÖHM SPORTS MANAGEMENT GmbH     26
# 321                               arena11 sports group     22
# 322                                            Sbsfoot     26
# 326                          Sven Jäger & Guido Walter     21
# 327                                HMH Sportmanagement     20
# 328                                               None     25
# 331                               arena11 sports group     21
# 332                                  Karlheinz Förster     20
# 24   <function Minuten at 0x10d8660d0>             Marnon Busch
# 25   <function Minuten at 0x10d8660d0>            Antonio Colak
# 26   <function Minuten at 0x10d8660d0>          Russell Canouse
# 27   <function Minuten at 0x10d8660d0>           Marvin Schwäbe
# 28   <function Minuten at 0x10d8660d0>             Felipe Pires
# 30   <function Minuten at 0x10d8660d0>                Joelinton
# 33   <function Minuten at 0x10d8660d0>          Benedikt Gimber
# 36   <function Minuten at 0x10d8660d0>           Matheus Biteco
# 37   <function Minuten at 0x10d8660d0>               Ante Rebic
# 38   <function Minuten at 0x10d8660d0>         Guillermo Varela
# 39   <function Minuten at 0x10d8660d0>            Jesús Vallejo
# 40   <function Minuten at 0x10d8660d0>          Tim Kleindienst
# 41   <function Minuten at 0x10d8660d0>             Florian Kath
# 42   <function Minuten at 0x10d8660d0>       Fabian Schleusener
# ..                                 ...                      ...
# 301  <function Minuten at 0x10d8660d0>          Joel Gerezgiher
# 302  <function Minuten at 0x10d8660d0>          Carlos Zambrano
# 304  <function Minuten at 0x10d8660d0>     Aleksandar Ignjovski
# 306  <function Minuten at 0x10d8660d0>          Yannick Zummack
# 307  <function Minuten at 0x10d8660d0>          Constant Djakpa
# 308  <function Minuten at 0x10d8660d0>          Änis Ben-Hatira
# 309  <function Minuten at 0x10d8660d0>             Emil Balayev
# 311  <function Minuten at 0x10d8660d0>           Caglar Söyüncü
# 313  <function Minuten at 0x10d8660d0>               Onur Bulut
# 314  <function Minuten at 0x10d8660d0>             Manuel Gulde
# 317  <function Minuten at 0x10d8660d0>             Zack Steffen
# 318  <function Minuten at 0x10d8660d0>  Charles Elie Laprevotte
# 319  <function Minuten at 0x10d8660d0>      Christopher Jullien
# 320  <function Minuten at 0x10d8660d0>        Philipp Zulechner
# 321  <function Minuten at 0x10d8660d0>           Sebastian Kerk
# 322  <function Minuten at 0x10d8660d0>          Stefan Mitrovic
# 326  <function Minuten at 0x10d8660d0>         Konstantin Fuhry
# 327  <function Minuten at 0x10d8660d0>            Marco Hingerl
# 328  <function Minuten at 0x10d8660d0>    Vegar Eggen Hedenstad
# 331  <function Minuten at 0x10d8660d0>               Naby Keïta
# 332  <function Minuten at 0x10d8660d0>              Timo Werner
# 333  <function Minuten at 0x10d8660d0>            Marius Müller
# 334  <function Minuten at 0x10d8660d0>            Benno Schmitz
# 335  <function Minuten at 0x10d8660d0>            Vitaly Janelt
# 336  <function Minuten at 0x10d8660d0>            Idrissa Touré
# 337  <function Minuten at 0x10d8660d0>              Omer Damari
# 338  <function Minuten at 0x10d8660d0>             Zsolt Kalmár
# 340  <function Minuten at 0x10d8660d0>        Stefan Hierländer
# 341  <function Minuten at 0x10d8660d0>               Ken Gipson
# 342  <function Minuten at 0x10d8660d0>      John-Patrick Strauß
#
#                                Position  Rote Karten  Tore  Total Spiele  \
# 0             Abwehr - Innenverteidiger            1    17           271
# 1               Mittelfeld - Linksaußen            0    19            66
# 2                 Sturm - Mittelstürmer            0    43            93
# 3                 Sturm - Mittelstürmer            0    64            97
# 5    Mittelfeld - Defensives Mittelfeld            1    18           113
# 6          Abwehr - Rechter Verteidiger            0     3            77
# 9                               Torwart            1     0            65
# 11                Sturm - Mittelstürmer            0    32            58
# 12                              Torwart            0     0           150
# 13            Abwehr - Innenverteidiger            0     3           121
# 15   Mittelfeld - Offensives Mittelfeld            0    16            90
# 16       Mittelfeld - Linkes Mittelfeld            0    18           122
# 19                Sturm - Mittelstürmer            0     0            14
# 20   Mittelfeld - Offensives Mittelfeld            0    23            73
# 21                Sturm - Mittelstürmer            0    80           234
# 23              Mittelfeld - Linksaußen            0    33           100
# 24         Abwehr - Rechter Verteidiger            0     3           141
# 25                Sturm - Mittelstürmer            0    66           162
# 26    Mittelfeld - Zentrales Mittelfeld            0     3           133
# 27                              Torwart            0     0           149
# 28                   Sturm - Linksaußen            0    16            67
# 30                Sturm - Mittelstürmer            0     5            15
# 33            Abwehr - Innenverteidiger            0     8            79
# 36    Mittelfeld - Zentrales Mittelfeld            1     0            29
# 37              Sturm - Hängende Spitze            3    19            90
# 38         Abwehr - Rechter Verteidiger            0     3            77
# 39            Abwehr - Innenverteidiger            0     1            54
# 40                Sturm - Mittelstürmer            0    33           107
# 41              Mittelfeld - Linksaußen            0    15           111
# 42                   Sturm - Linksaußen            0    61           124
# ..                                  ...          ...   ...           ...
# 301  Mittelfeld - Offensives Mittelfeld            0    10            69
# 302           Abwehr - Innenverteidiger            1     6           206
# 304        Abwehr - Rechter Verteidiger            0     4           182
# 306                             Torwart            1     0            44
# 307         Abwehr - Linker Verteidiger            3     5           163
# 308             Mittelfeld - Linksaußen            1    53           225
# 309                             Torwart            1     0            11
# 311           Abwehr - Innenverteidiger            0     2            40
# 313            Mittelfeld - Rechtsaußen            2    15           167
# 314           Abwehr - Innenverteidiger            1     8           134
# 317                             Torwart            0     0            14
# 318  Mittelfeld - Defensives Mittelfeld            2     6           108
# 319           Abwehr - Innenverteidiger            0    18           114
# 320               Sturm - Mittelstürmer            2    63           219
# 321             Mittelfeld - Linksaußen            0    36           167
# 322           Abwehr - Innenverteidiger            2     4           145
# 326                             Torwart            1     0           108
# 327   Mittelfeld - Zentrales Mittelfeld            0    21           104
# 328        Abwehr - Rechter Verteidiger            0     7           175
# 331   Mittelfeld - Zentrales Mittelfeld            0    24           104
# 332               Sturm - Mittelstürmer            0    72           165
# 333                             Torwart            1     0           147
# 334        Abwehr - Rechter Verteidiger            1     6           182
# 335  Mittelfeld - Defensives Mittelfeld            1     8            54
# 336   Mittelfeld - Zentrales Mittelfeld            0     8            52
# 337               Sturm - Mittelstürmer            1    99           222
# 338  Mittelfeld - Offensives Mittelfeld            0     7            75
# 340   Mittelfeld - Zentrales Mittelfeld            1    16           196
# 341        Abwehr - Rechter Verteidiger            0     1            61
# 342  Mittelfeld - Defensives Mittelfeld            0    15            69
#
#                                                    URL  \
# 0    http://www.transfermarkt.ch/medhi-benatia/prof...
# 1    http://www.transfermarkt.ch/andrejs-ciganiks/p...
# 2    http://www.transfermarkt.ch/patrik-dzalto/prof...
# 328                       FC St. Pauli        11               SC Freiburg
# 331             RasenBallsport Leipzig        18               RB Salzburg
# 332             RasenBallsport Leipzig        23             VfB Stuttgart
# 333             RasenBallsport Leipzig         0            1.FC K'lautern
# 334             RasenBallsport Leipzig        15               RB Salzburg
# 335             RasenBallsport Leipzig         3             RB Leipzig II
# 336             RasenBallsport Leipzig         4            RB Leipzig U19
# 337             RasenBallsport Leipzig        25               RB Salzburg
# 338             RasenBallsport Leipzig         7             FSV Frankfurt
# 340                      SK Sturm Graz        23                RB Leipzig
# 341          RasenBallsport Leipzig II         0                RB Leipzig
# 342          RasenBallsport Leipzig II        10                RB Leipzig
#
#                   *Wechsel von*  Alle Karten
# 0          FC FC Bayern München           72
# 1           Bayer 04 Leverkusen            6
# 2           Bayer 04 Leverkusen            8
# 3           Bayer 04 Leverkusen            5
# 5           Bayer 04 Leverkusen           17
# 6           Bayer 04 Leverkusen           14
# 9                    Hertha BSC            6
# 11                  Real Madrid            6
# 12                VfL Wolfsburg            3
# 13                VfL Wolfsburg           12
# 15                 Hamburger SV           12
# 16                 Hamburger SV            6
# 19                 Hamburger SV            1
# 20             FC Ingolstadt 04           12
# 21             FC Ingolstadt 04           31
# 23                  FC Augsburg            6
# 24             SV Werder Bremen           11
# 25          TSG 1899 Hoffenheim           17
# 26          TSG 1899 Hoffenheim           21
# 27          TSG 1899 Hoffenheim            1
# 28          TSG 1899 Hoffenheim            6
# 30          TSG 1899 Hoffenheim            2
# 33          TSG 1899 Hoffenheim           24
# 36     Barra Futebol Clube (SC)            5
# 37                   AC Florenz           31
# 38            Manchester United           14
# 39                  Real Madrid            8
# 40                  SC Freiburg           26
# 41                  SC Freiburg            8
# 42                  SC Freiburg            9
# ..                          ...          ...
# 301               FSV Frankfurt            4
# 302         Eintracht Frankfurt           66
# 304         Eintracht Frankfurt           34
# 306         Eintracht Frankfurt            3
# 307         Eintracht Frankfurt           27
# 308         Eintracht Frankfurt           30
# 309         Eintracht Frankfurt            2
# 311                   Altinordu           14
# 313                  VfL Bochum           21
# 314               Karlsruher SC           22
# 317                 SC Freiburg            1
# 318             Preußen Münster           11
# 319                 SC Freiburg           26
# 320              BSC Young Boys           22
# 321               1.FC Nürnberg           13
# 322                 SC Freiburg           38
# 326                 SC Freiburg            2
# 327                 SC Freiburg           17
# 328                 SC Freiburg           16
# 331                 RB Salzburg           15
# 332               VfB Stuttgart            8
# 333              1.FC K'lautern           11
# 334                 RB Salzburg           27
# 335   RasenBallsport Leipzig II            7
# 336  RasenBallsport Leipzig U19            1
# 337                 RB Salzburg           23
# 338               FSV Frankfurt           18
# 340      RasenBallsport Leipzig           34
# 341      RasenBallsport Leipzig           14
# 342      RasenBallsport Leipzig            8
#
# [264 rows x 20 columns]

# %%
df_SL_transfers[df_SL_transfers['Agent'] == 'arena11 sports group']
# Out:
#                     Agent  Alter  \
# 71   arena11 sports group     23
# 105  arena11 sports group     33
# 110  arena11 sports group     18
# 118  arena11 sports group     20
# 126  arena11 sports group     21
# 143  arena11 sports group     31
# 175  arena11 sports group     24
# 188  arena11 sports group     23
# 201  arena11 sports group     22
# 215  arena11 sports group     25
# 216  arena11 sports group     31
# 241  arena11 sports group     25
# 252  arena11 sports group     23
# 284  arena11 sports group     28
# 321  arena11 sports group     22
# 331  arena11 sports group     21
#
#                                             Ausrüster  Gelb-Rote Karten  \
# 71    Nike Mercurial Superfly V FG - Spark Brilliance                 1
# 105                      adidas ACE 16.1 Primeknit FG                 0
# 110                                              None                 1
# 118                      adidas ACE 16.1 Primeknit FG                 0
# 126     Nike Mercurial Vapor XI FG - Spark Brilliance                 0
# 143                                              None                 0
# 175     Nike Mercurial Vapor XI FG - Spark Brilliance                 1
# 188                                              None                 2
# 201                                              None                 0
# 215   Nike Mercurial Superfly V FG - Spark Brilliance                 1
# 216  Nike Hypervenom Phinish II FG - Spark Brilliance                 0
# 241                      adidas ACE 16.1 Primeknit FG                 0
# 252                                              None                 0
# 284  Nike Hypervenom Phinish II FG - Spark Brilliance                 1
# 321     Nike Mercurial Vapor XI FG - Spark Brilliance                 0
# 331  Nike Hypervenom Phantom II FG - Spark Brilliance                 1
#
#      Gelbe Karten  Grösse Im Team seit Marktwert  \
# 71             12   185.0   01.07.2016
# 105            65   198.0   01.07.2016
# 110            18   178.0   01.07.2016
# 118            16   190.0   01.07.2016
# 126             3   183.0   01.07.2016
# 143            60   188.0   01.07.2016
# 175            42   194.0   01.07.2016
# 188            37   185.0   13.07.2016
# 201            13   189.0   01.07.2016
# 215            15   183.0   01.07.2016
# 216            23   187.0   01.07.2016
# 241            17   179.0   07.07.2016
# 252             5   188.0   01.07.2016
# 284            22   193.0   04.07.2014
# 321            13   184.0   01.07.2013
# 331            14   172.0   01.07.2016
#
#                                Minuten                       Name  \
# 71   <function Minuten at 0x10d8660d0>             Danny da Costa
# 105  <function Minuten at 0x10d8660d0>                      Naldo
# 110  <function Minuten at 0x10d8660d0>  Christian Rubio Sivodedov
# 118  <function Minuten at 0x10d8660d0>           Marvin Friedrich
# 126  <function Minuten at 0x10d8660d0>            Gerrit Holtmann
# 143  <function Minuten at 0x10d8660d0>             Vedad Ibisevic
# 175  <function Minuten at 0x10d8660d0>                 Kevin Vogt
# 188  <function Minuten at 0x10d8660d0>             Kerem Demirbay
# 201  <function Minuten at 0x10d8660d0>                 Hauke Wahl
# 215  <function Minuten at 0x10d8660d0>                Georg Teigl
# 216  <function Minuten at 0x10d8660d0>             Sascha Mölders
# 241  <function Minuten at 0x10d8660d0>               Anthony Ujah
# 252  <function Minuten at 0x10d8660d0>     Daniel Heuer Fernandes
# 284  <function Minuten at 0x10d8660d0>                Ádám Szalai
# 321  <function Minuten at 0x10d8660d0>             Sebastian Kerk
# 331  <function Minuten at 0x10d8660d0>                 Naby Keïta
#
#                                Position  Rote Karten  Tore  Total Spiele  \
# 71         Abwehr - Rechter Verteidiger            0     4           183
# 105           Abwehr - Innenverteidiger            2    56           423
# 110   Mittelfeld - Zentrales Mittelfeld            0    18            99
