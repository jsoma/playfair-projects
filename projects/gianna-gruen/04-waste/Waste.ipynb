# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import dateutil.parser
import datetime

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
df = pd.read_csv('OECD_waste_municipal.csv')

# %%
df.head(10)
# Out:
#   ﻿"LOCATION" INDICATOR SUBJECT     MEASURE FREQUENCY  TIME      Value  \
# 0         AUS  WASTEMUN     TOT  THND_TONNE         A  1980  10000.000
# 1         AUS  WASTEMUN     TOT  THND_TONNE         A  1992  12000.000
# 2         AUS  WASTEMUN     TOT  THND_TONNE         A  2000  13200.000
# 3         AUS  WASTEMUN     TOT  THND_TONNE         A  2009  14035.000
# 4         AUS  WASTEMUN     TOT  THND_TONNE         A  2011  14037.000
# 5         AUS  WASTEMUN     TOT      KG_CAP         A  1980    680.487
# 6         AUS  WASTEMUN     TOT      KG_CAP         A  1992    686.538
# 7         AUS  WASTEMUN     TOT      KG_CAP         A  2000    693.715
# 8         AUS  WASTEMUN     TOT      KG_CAP         A  2009    647.072
# 9         AUS  WASTEMUN     TOT      KG_CAP         A  2011    628.335
#
#   Flag Codes
# 0          E
# 1          E
# 2          E
# 3        NaN
# 4        NaN
# 5          E
# 6          E
# 7          E
# 8        NaN
# 9        NaN

# %%
df_capita = df[df['MEASURE']=="KG_CAP"]

# %%
df_capita.columns = ('Country', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
       'Amount', 'Flag Codes')

# %%
selection = df_capita[["Country", "TIME", "Amount"]]
selection
# Out:
#      Country  TIME   Amount
# 5        AUS  1980  680.487
# 6        AUS  1992  686.538
# 7        AUS  2000  693.715
# 8        AUS  2009  647.072
# 9        AUS  2011  628.335
# 36       AUT  1989  413.410
# 37       AUT  1990  417.305
# 38       AUT  1991  403.101
# 39       AUT  1992  405.066
# 40       AUT  1993  422.610
# 41       AUT  1994  428.421
# 42       AUT  1995  437.328
# 43       AUT  1996  483.100
# 44       AUT  1997  499.119
# 45       AUT  1998  499.324
# 46       AUT  1999  521.876
# 47       AUT  2000  539.346
# 48       AUT  2001  535.793
# 49       AUT  2002  567.796
# 50       AUT  2003  567.487
# 51       AUT  2004  573.687
# 52       AUT  2005  575.263
# 53       AUT  2006  596.581
# 54       AUT  2007  596.864
# 55       AUT  2008  600.478
# 56       AUT  2009  589.943
# 57       AUT  2010  562.225
# 58       AUT  2011  573.032
# 59       AUT  2012  579.530
# 60       AUT  2013  579.224
# ...      ...   ...      ...
# 1577    OECD  2010  532.297
# 1578    OECD  2011  530.160
# 1579    OECD  2012  524.511
# 1580    OECD  2013  519.767
# 1581    OECD  2014  516.336
# 1619   OECDE  1990  448.762
# 1620   OECDE  1991  453.832
# 1621   OECDE  1992  457.273
# 1622   OECDE  1993  463.472
# 1623   OECDE  1994  465.706
# 1624   OECDE  1995  474.489
# 1625   OECDE  1996  489.970
# 1626   OECDE  1997  507.465
# 1627   OECDE  1998  510.121
# 1628   OECDE  1999  515.573
# 1629   OECDE  2000  523.843
# 1630   OECDE  2001  520.572
# 1631   OECDE  2002  526.825
# 1632   OECDE  2003  516.296
# 1633   OECDE  2004  512.458
# 1634   OECDE  2005  515.906
# 1635   OECDE  2006  518.317
# 1636   OECDE  2007  520.068
# 1637   OECDE  2008  511.750
# 1638   OECDE  2009  506.201
# 1639   OECDE  2010  500.135
# 1640   OECDE  2011  497.964
# 1641   OECDE  2012  487.139
# 1642   OECDE  2013  481.498
# 1643   OECDE  2014  477.768
#
# [792 rows x 3 columns]

# %%
selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 792 entries, 5 to 1643
# Data columns (total 3 columns):
# Country    792 non-null object
# TIME       792 non-null int64
# Amount     792 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 24.8+ KB

# %%
dateutil.parser.parse("1980")
# Out:
# datetime.datetime(1980, 8, 18, 0, 0)

# %%
def convert_year(year_int):
    year_str = str(year_int)
    parsed_year = dateutil.parser.parse(year_str+'-01-01')
    return parsed_year

# %%
parsed_year = [convert_year(year) for year in selection["TIME"]]
selection['parsed_year'] = parsed_year
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
selection
# Out:
#      Country  TIME   Amount parsed_year
# 5        AUS  1980  680.487  1980-01-01
# 6        AUS  1992  686.538  1992-01-01
# 7        AUS  2000  693.715  2000-01-01
# 8        AUS  2009  647.072  2009-01-01
# 9        AUS  2011  628.335  2011-01-01
# 36       AUT  1989  413.410  1989-01-01
# 37       AUT  1990  417.305  1990-01-01
# 38       AUT  1991  403.101  1991-01-01
# 39       AUT  1992  405.066  1992-01-01
# 40       AUT  1993  422.610  1993-01-01
# 41       AUT  1994  428.421  1994-01-01
# 42       AUT  1995  437.328  1995-01-01
# 43       AUT  1996  483.100  1996-01-01
# 44       AUT  1997  499.119  1997-01-01
# 45       AUT  1998  499.324  1998-01-01
# 46       AUT  1999  521.876  1999-01-01
# 47       AUT  2000  539.346  2000-01-01
# 48       AUT  2001  535.793  2001-01-01
# 49       AUT  2002  567.796  2002-01-01
# 50       AUT  2003  567.487  2003-01-01
# 51       AUT  2004  573.687  2004-01-01
# 52       AUT  2005  575.263  2005-01-01
# 53       AUT  2006  596.581  2006-01-01
# 54       AUT  2007  596.864  2007-01-01
# 55       AUT  2008  600.478  2008-01-01
# 56       AUT  2009  589.943  2009-01-01
# 57       AUT  2010  562.225  2010-01-01
# 58       AUT  2011  573.032  2011-01-01
# 59       AUT  2012  579.530  2012-01-01
# 60       AUT  2013  579.224  2013-01-01
# ...      ...   ...      ...         ...
# 1577    OECD  2010  532.297  2010-01-01
# 1578    OECD  2011  530.160  2011-01-01
# 1579    OECD  2012  524.511  2012-01-01
# 1580    OECD  2013  519.767  2013-01-01
# 1581    OECD  2014  516.336  2014-01-01
# 1619   OECDE  1990  448.762  1990-01-01
# 1620   OECDE  1991  453.832  1991-01-01
# 1621   OECDE  1992  457.273  1992-01-01
# 1622   OECDE  1993  463.472  1993-01-01
# 1623   OECDE  1994  465.706  1994-01-01
# 1624   OECDE  1995  474.489  1995-01-01
# 1625   OECDE  1996  489.970  1996-01-01
# 1626   OECDE  1997  507.465  1997-01-01
# 1627   OECDE  1998  510.121  1998-01-01
# 1628   OECDE  1999  515.573  1999-01-01
# 1629   OECDE  2000  523.843  2000-01-01
# 1630   OECDE  2001  520.572  2001-01-01
# 1631   OECDE  2002  526.825  2002-01-01
# 1632   OECDE  2003  516.296  2003-01-01
# 1633   OECDE  2004  512.458  2004-01-01
# 1634   OECDE  2005  515.906  2005-01-01
# 1635   OECDE  2006  518.317  2006-01-01
# 1636   OECDE  2007  520.068  2007-01-01
# 1637   OECDE  2008  511.750  2008-01-01
# 1638   OECDE  2009  506.201  2009-01-01
# 1639   OECDE  2010  500.135  2010-01-01
# 1640   OECDE  2011  497.964  2011-01-01
# 1641   OECDE  2012  487.139  2012-01-01
# 1642   OECDE  2013  481.498  2013-01-01
# 1643   OECDE  2014  477.768  2014-01-01
#
# [792 rows x 4 columns]

# %%
selection.index = selection['parsed_year']

# %%
selection = selection.drop(['TIME', 'parsed_year'], axis=1)

# %%
selection[selection["Country"] == "AUS"].plot()

# %%
fig, ax = plt.subplots()

selection.groupby(by="Country").plot(ax = ax, legend = False, figsize = (10,7), xlim=("1990","2014"))

ax.set_title("Municipal waste by country")
# ax.set_xlabel("Year")
# ax.set_ylabel("kilogram per capita")


# y=selection["Amount"]
# z=selection.index
# n=selection["Country"]

# for i, txt in enumerate(n):
#     ax.annotate(txt, (z[i+5], y[i+5]))

# plt.savefig("municipalwaste-02.pdf", transparent = True)

# %% [markdown]
# # Packaging waste

# %%
pacwas = pd.read_csv('EU-packagingwaste.csv')

# %%
pacwas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22320 entries, 0 to 22319
# Data columns (total 8 columns):
# TIME                  22320 non-null int64
# GEO                   22320 non-null object
# WASTE                 22320 non-null object
# STK_FLOW              22320 non-null object
# WST_OPER              22320 non-null object
# UNIT                  22320 non-null object
# Value                 22320 non-null object
# Flag and Footnotes    414 non-null object
# dtypes: int64(1), object(7)
# memory usage: 1.4+ MB

# %%
pacwas.head(10)
# Out:
#    TIME      GEO      WASTE  STK_FLOW         WST_OPER                   UNIT  \
# 0  2002  Austria  Packaging   Imports  Waste generated                  Tonne
# 1  2002  Austria  Packaging   Imports  Waste generated  Kilograms per capita
# 2  2002  Austria  Packaging   Imports        Recycling                  Tonne
# 3  2002  Austria  Packaging   Imports        Recycling  Kilograms per capita
# 4  2002  Austria  Packaging   Exports  Waste generated                  Tonne
# 5  2002  Austria  Packaging   Exports  Waste generated  Kilograms per capita
# 6  2002  Austria  Packaging   Exports        Recycling                  Tonne
# 7  2002  Austria  Packaging   Exports        Recycling  Kilograms per capita
# 8  2002  Austria  Packaging  Domestic  Waste generated                  Tonne
# 9  2002  Austria  Packaging  Domestic  Waste generated  Kilograms per capita
#
#        Value Flag and Footnotes
# 0          :                NaN
# 1          :                NaN
# 2          :                NaN
# 3          :                NaN
# 4          :                NaN
# 5          :                NaN
# 6          :                NaN
# 7          :                NaN
# 8  1,059,000                NaN
# 9     131.03                NaN

# %%
# 22151  Domestic        Recycling  Kilograms per capita        67.09
# 22208  Domestic  Waste generated                  Tonne     442,659
# 22209  Domestic  Waste generated  Kilograms per capita        81.77
# 22210  Domestic        Recycling                  Tonne     291,790
# 22211  Domestic        Recycling  Kilograms per capita         53.9
# 22268  Domestic  Waste generated                  Tonne  10,384,147
# 22269  Domestic  Waste generated  Kilograms per capita       161.93
# 22270  Domestic        Recycling                  Tonne   6,710,149
# 22271  Domestic        Recycling  Kilograms per capita       104.64
#
#       Flag and Footnotes
# 20468                NaN
# 20469                NaN
# 20470                NaN
# 20471                NaN
# 20528                NaN
# 20529                NaN
# 20530                NaN
# 20531                NaN
# 20588                NaN
# 20589                NaN
# 20590                NaN
# 20591                NaN
# 20648                NaN
# 20649                NaN
# 20650                NaN
# 20651                NaN
# 20708                NaN
# 20709                NaN
# 20710                NaN
# 20711                NaN
# 20768                NaN
# 20769                NaN
# 20770                NaN
# 20771                NaN
# 20828                NaN
# 20829                NaN
# 20830                NaN
# 20831                NaN
# 20888                NaN
# 20889                NaN
# ...                  ...
# 21850                NaN
# 21851                NaN
# 21908                NaN
# 21909                NaN
# 21910                NaN
# 21911                NaN
# 21968                NaN
# 21969                NaN
# 21970                NaN
# 21971                NaN
# 22028                NaN
# 22029                NaN
# 22030                NaN
# 22031                NaN
# 22088                NaN
# 22089                NaN
# 22090                NaN
# 22091                NaN
# 22148                NaN
# 22149                NaN
# 22150                NaN
# 22151                NaN
# 22208                NaN
# 22209                NaN
# 22210                NaN
# 22211                NaN
# 22268                NaN
# 22269                NaN
# 22270                NaN
# 22271                NaN
#
# [124 rows x 8 columns]

# %%
pacwas_pc = pacwas_recent[pacwas_recent["UNIT"].str.contains(pat="Kilogram")]
pacwas_pc
# Out:
#        TIME                                               GEO      WASTE  \
# 20469  2013                                           Austria  Packaging
# 20471  2013                                           Austria  Packaging
# 20529  2013                                           Belgium  Packaging
# 20531  2013                                           Belgium  Packaging
# 20589  2013                                          Bulgaria  Packaging
# 20591  2013                                          Bulgaria  Packaging
# 20649  2013                                            Cyprus  Packaging
# 20651  2013                                            Cyprus  Packaging
# 20709  2013                                    Czech Republic  Packaging
# 20711  2013                                    Czech Republic  Packaging
# 20769  2013  Germany (until 1990 former territory of the FRG)  Packaging
# 20771  2013  Germany (until 1990 former territory of the FRG)  Packaging
# 20829  2013                                           Denmark  Packaging
# 20831  2013                                           Denmark  Packaging
# 20889  2013                                           Estonia  Packaging
# 20891  2013                                           Estonia  Packaging
# 20949  2013                                            Greece  Packaging
# 20951  2013                                            Greece  Packaging
# 21009  2013                                             Spain  Packaging
# 21011  2013                                             Spain  Packaging
# 21069  2013                     European Union (15 countries)  Packaging
# 21071  2013                     European Union (15 countries)  Packaging
# 21129  2013                     European Union (27 countries)  Packaging
# 21131  2013                     European Union (27 countries)  Packaging
# 21189  2013                                           Finland  Packaging
# 21191  2013                                           Finland  Packaging
# 21249  2013                                            France  Packaging
# 21251  Domestic        Recycling  Kilograms per capita   122.68
# 21309  Domestic  Waste generated  Kilograms per capita   103.34
# 21311  Domestic        Recycling  Kilograms per capita    50.82
# ...         ...              ...                    ...     ...
# 21429  Domestic  Waste generated  Kilograms per capita   190.31
# 21431  Domestic        Recycling  Kilograms per capita   126.88
# 21489  Domestic  Waste generated  Kilograms per capita   152.28
# 21491  Domestic        Recycling  Kilograms per capita     76.6
# 21549  Domestic  Waste generated  Kilograms per capita   108.11
# 21551  Domestic        Recycling  Kilograms per capita    57.86
# 21609  Domestic  Waste generated  Kilograms per capita   206.14
# 21611  Domestic        Recycling  Kilograms per capita   129.36
# 21669  Domestic  Waste generated  Kilograms per capita   113.94
# 21671  Domestic        Recycling  Kilograms per capita    58.08
# 21729  Domestic  Waste generated  Kilograms per capita   134.71
# 21731  Domestic        Recycling  Kilograms per capita    51.28
# 21789  Domestic  Waste generated  Kilograms per capita   166.98
# 21791  Domestic        Recycling  Kilograms per capita   117.65
# 21849  Domestic  Waste generated  Kilograms per capita   145.68
# 21851  Domestic        Recycling  Kilograms per capita    79.41
# 21909  Domestic  Waste generated  Kilograms per capita   126.88
# 21911  Domestic        Recycling  Kilograms per capita    45.75
# 21969  Domestic  Waste generated  Kilograms per capita    149.1
# 21971  Domestic        Recycling  Kilograms per capita     91.7
# 22029  Domestic  Waste generated  Kilograms per capita        :
# 22031  Domestic        Recycling  Kilograms per capita        :
# 22089  Domestic  Waste generated  Kilograms per capita   109.17
# 22091  Domestic        Recycling  Kilograms per capita    78.53
# 22149  Domestic  Waste generated  Kilograms per capita    97.28
# 22151  Domestic        Recycling  Kilograms per capita    67.09
# 22209  Domestic  Waste generated  Kilograms per capita    81.77
# 22211  Domestic        Recycling  Kilograms per capita     53.9
# 22269  Domestic  Waste generated  Kilograms per capita   161.93
# 22271  Domestic        Recycling  Kilograms per capita   104.64
#
#       Flag and Footnotes
# 20469                NaN
# 20471                NaN
# 20529                NaN
# 20531                NaN
# 20589                NaN
# 20591                NaN
# 20649                NaN
# 20651                NaN
# 20709                NaN
# 20711                NaN
# 20769                NaN
# 20771                NaN
# 20829                NaN
# 20831                NaN
# 20889                NaN
# 20891                NaN
# 20949                NaN
# 20951                NaN
# 21009                NaN
# 21011                NaN
# 21069                NaN
# 21071                NaN
# 21129                  s
# 21131                  s
# 21189                NaN
# 21191                NaN
# 21249                NaN
# 21251                NaN
# 21309                NaN
# 21311                NaN
# ...                  ...
# 21429                NaN
# 21431                NaN
# 21489                NaN
# 21491                NaN
# 21549                NaN
# 21551                NaN
# 21609                NaN
# 21611                NaN
# 21669                NaN
# 21671                NaN
# 21729                NaN
# 21731                NaN
# 21789                NaN
# 21791                NaN
# 21849                NaN
# 21851                NaN
# 21909                NaN
# 21911                NaN
# 21969                NaN
# 21971                NaN
# 22029                NaN
# 22031                NaN
# 22089                NaN
# 22091                NaN
# 22149                NaN
# 22151                NaN
# 22209                NaN
# 22211                NaN
# 22269                NaN
# 22271                NaN
#
# [62 rows x 8 columns]

# %%
pacwas_pc = pacwas_pc.drop("TIME",1)

# %%
pacwas_pc.columns
# Out:
# Index(['GEO', 'WASTE', 'STK_FLOW', 'WST_OPER', 'UNIT', 'Value',
#        'Flag and Footnotes'],
#       dtype='object')

# %%
pacwas_pc = pacwas_pc.drop('WASTE',1)

# %%
pacwas_pc = pacwas_pc.drop('STK_FLOW',1)
pacwas_pc = pacwas_pc.drop('UNIT',1)
pacwas_pc = pacwas_pc.drop('Flag and Footnotes',1)

# %%
pacwas_pc_generation = pacwas_pc[pacwas_pc["WST_OPER"]=="Waste generated"]

# %%
pacwas_pc_generation
# Out:
#                                                     GEO         WST_OPER  \
# 20469                                           Austria  Waste generated
# 20529                                           Belgium  Waste generated
# 20589                                          Bulgaria  Waste generated
# 20649                                            Cyprus  Waste generated
# 20709                                    Czech Republic  Waste generated
# 20769  Germany (until 1990 former territory of the FRG)  Waste generated
# 20829                                           Denmark  Waste generated
# 20889                                           Estonia  Waste generated
# 20949                                            Greece  Waste generated
# 21009                                             Spain  Waste generated
# 21069                     European Union (15 countries)  Waste generated
# 21129                     European Union (27 countries)  Waste generated
# 21189                                           Finland  Waste generated
# 21249                                            France  Waste generated
# 21309                                           Hungary  Waste generated
# 21369                                           Ireland  Waste generated
# 21429                                             Italy  Waste generated
# 21489                                     Liechtenstein  Waste generated
# 21549                                         Lithuania  Waste generated
# 21609                                        Luxembourg  Waste generated
# 21669                                            Latvia  Waste generated
# 21729                                             Malta  Waste generated
# 21789                                       Netherlands  Waste generated
# 21849                                            Norway  Waste generated
# 21909                                            Poland  Waste generated
# 21969                                          Portugal  Waste generated
# 22029                                           Romania  Waste generated
# 22089                                            Sweden  Waste generated
# 22149                                          Slovenia  Waste generated
# 22209                                          Slovakia  Waste generated
# 22269                                    United Kingdom  Waste generated
#
#         Value
# 20469  149.98
# 20529  155.44
# 20589   48.18
# 20649   91.31
# 20709   95.66
# 20769  210.42
# 20829  169.62
# 20889   169.9
# 20949   68.33
# 21009  143.63
# 21069       :
# 21129  157.86
# 21189  131.77
# 21249  184.63
# 21309  103.34
# 21369  189.22
# 21429  190.31
# 21489  152.28
# 21549  108.11
# 21609  206.14
# 21669  113.94
# 21729  134.71
# 21789  166.98
# 21849  145.68
# 21909  126.88
# 21969   149.1
# 22029       :
# 22089  109.17
# 22149   97.28
# 22209   81.77
# 22269  161.93

# %%
pacwas_pc_generation = pacwas_pc_generation.drop("WST_OPER", 1)

# %%
pacwas_pc_generation.columns = ("GEO", "Generation")

# %%
pacwas_pc_generation
# Out:
#                                                     GEO Generation
# 20469                                           Austria     149.98
# 20529                                           Belgium     155.44
# 20589                                          Bulgaria      48.18
# 20649                                            Cyprus      91.31
# 20709                                    Czech Republic      95.66
# 20769  Germany (until 1990 former territory of the FRG)     210.42
# 20829                                           Denmark     169.62
# 20889                                           Estonia      169.9
# 20949                                            Greece      68.33
# 21009                                             Spain     143.63
# 21069                     European Union (15 countries)          :
# 21129                     European Union (27 countries)     157.86
# 21189                                           Finland     131.77
# 21249                                            France     184.63
# 21309                                           Hungary     103.34
# 21369                                           Ireland     189.22
# 21429                                             Italy     190.31
# 21489                                     Liechtenstein     152.28
# 21549                                         Lithuania     108.11
# 21609                                        Luxembourg     206.14
# 21669                                            Latvia     113.94
# 21729                                             Malta     134.71
# 21789                                       Netherlands     166.98
# 21849                                            Norway     145.68
# 21909                                            Poland     126.88
# 21969                                          Portugal      149.1
# 22029                                           Romania          :
# 22089                                            Sweden     109.17
# 22149                                          Slovenia      97.28
# 22209                                          Slovakia      81.77
# 22269                                    United Kingdom     161.93

# %%
pacwas_pc_recycling = pacwas_pc[pacwas_pc["WST_OPER"]=="Recycling"]

# %%
pacwas_pc_recycling = pacwas_pc_recycling.drop("WST_OPER", 1)

# %%
pacwas_pc_recycling.columns = ("GEO", "Recycling")

# %%
# pacwas_pc_recycling
# pacwas_pc_recycling = pacwas_pc_recycling.drop(pacwas_pc_recycling.iloc[11],1)
pacwas_pc_recycling.index[11]
# Out:
# 21131

# %%
pacwas_merge = pacwas_pc_generation.merge(pacwas_pc_recycling, left_on="GEO", right_on = "GEO")

# %%
pacwas_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 3 columns):
# GEO           31 non-null object
# Generation    31 non-null object
# Recycling     31 non-null object
# dtypes: object(3)
# memory usage: 992.0+ bytes

# %%
def float_conversion(value_str):
    try:
        value = float(value_str)
        return value
    except:
        pass

# %%
pacwas_merge["Generation"] = pacwas_merge["Generation"].apply(float_conversion)

# %%
pacwas_merge["Recycling"] = pacwas_merge["Recycling"].apply(float_conversion)

# %%
pacwas_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 3 columns):
# GEO           31 non-null object
# Generation    29 non-null float64
# Recycling     29 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 992.0+ bytes

# %%
fig, ax = plt.subplots(figsize=(10,10))
pacwas_merge.plot(ax = ax, kind='scatter', x="Generation", y="Recycling", xlim=(0,220), ylim=(0,220))

y=pacwas_merge["Recycling"]
z=pacwas_merge["Generation"]
n=pacwas_merge["GEO"]

#i+2, because index number starts at 2 
for i, txt in enumerate(n):
    try:
        ax.annotate(txt, (z[i+1], y[i+1]))
    except:
        pass

# %%
# iqr = pacwas_merge.quantile(q=0.75) - pacwas_merge.quantile(q=0.25)

# %% [markdown]
# # Plastic waste packaing recycling

# %%
pacwas["WASTE"].value_counts()
# Out:
# Glass packaging                  4464
# Metallic packaging               4464
# Paper and cardboard packaging    4464
# Packaging                        4464
# Plastic packaging                4464
# Name: WASTE, dtype: int64

# %%
plastic = pacwas[(pacwas["WASTE"]=="Plastic packaging")&(pacwas["TIME"]==2013)&(pacwas["STK_FLOW"]=="Domestic")]

# %%
plastic_pc = plastic[plastic["UNIT"].str.contains(pat="Kilogram")]

# %%
plastic_pc
# Out:
Plastic packaging  Domestic  Waste generated  Kilograms per capita
# 22235  Plastic packaging  Domestic        Recycling  Kilograms per capita
# 22293  Plastic packaging  Domestic  Waste generated  Kilograms per capita
# 22295  Plastic packaging  Domestic        Recycling  Kilograms per capita
#
#        Value Flag and Footnotes
# 20493  34.05                NaN
# 20495  11.71                NaN
# 20553  29.45                NaN
# 20555  11.47                NaN
# 20613  13.29                NaN
# 20615   5.49                NaN
# 20673  18.25                NaN
# 20675   8.27                NaN
# 20733  20.46                NaN
# 20735   12.2                NaN
# 20793   35.3                NaN
# 20795  17.42                NaN
# 20853  33.85                NaN
# 20855  12.17                NaN
# 20913  49.06                NaN
# 20915   13.8                NaN
# 20973  16.55                NaN
# 20975   5.34                NaN
# 21033     28                NaN
# 21035   11.4                NaN
# 21093      :                NaN
# 21095      :                NaN
# 21153  29.72                  s
# 21155  11.07                  s
# 21213  21.65                NaN
# 21215   4.92                NaN
# 21273  30.13                NaN
# 21275   7.71                NaN
# 21333  27.85                NaN
# 21335   8.59                NaN
# ...      ...                ...
# 21453  33.91                NaN
# 21455  12.47                NaN
# 21513  19.28                NaN
# 21515   1.27                NaN
# 21573  21.37                NaN
# 21575   9.16                NaN
# 21633   50.1                NaN
# 21635  16.11                NaN
# 21693  20.14                NaN
# 21695   4.94                NaN
# 21753  27.12                NaN
# 21755   6.12                NaN
# 21813  27.55                NaN
# 21815  12.73                NaN
# 21873  33.79                NaN
# 21875  13.11                NaN
# 21933  23.53                NaN
# 21935    4.7                NaN
# 21993  34.16                NaN
# 21995  12.06                NaN
# 22053      :                NaN
# 22055      :                NaN
# 22113  23.18                NaN
# 22115  10.57                NaN
# 22173  20.41                NaN
# 22175  16.68                NaN
# 22233  18.06                NaN
# 22235   9.95                NaN
# 22293  35.24                NaN
# 22295  11.14                NaN
#
# [62 rows x 8 columns]

# %%
plastic_pc_recycling = plastic_pc[plastic_pc["WST_OPER"]=="Recycling"]
plastic_pc_generation = plastic_pc[plastic_pc["WST_OPER"]=="Waste generated"]

# %%
plastic_pc_recy = plastic_pc_recycling[["GEO", "Value"]]
plastic_pc_gen = plastic_pc_generation[["GEO", "Value"]]

# %%
plastic_pc_recy.columns = ("GEO", "plastic_recycling")
plastic_pc_gen.columns = ("GEO", "plastic_generation")

# %%
plastic_merge = plastic_pc_recy.merge(plastic_pc_gen, left_on="GEO", right_on="GEO")

# %%
plastic_merge['plastic_generation'] = plastic_merge['plastic_generation'].apply(float_conversion)
plastic_merge['plastic_recycling'] = plastic_merge['plastic_recycling'].apply(float_conversion)

# %%
plastic_merge.plot(kind="scatter", x="plastic_generation", y="plastic_recycling", xlim=(0,55), ylim=(0,55))

# %% [markdown]
# # Writing a function for this mess

# %%
def waste_type_analysis(waste_type, descriptor):
    waste_type = pacwas[(pacwas["WASTE"]==descriptor)&(pacwas["TIME"]==2013)&(pacwas["STK_FLOW"]=="Domestic")]
    pc = waste_type[waste_type["UNIT"].str.contains(pat="Kilogram")]
    recycling = pc[pc["WST_OPER"]=="Recycling"]
    generation = pc[pc["WST_OPER"]=="Waste generated"]
    pc_recy = recycling[["GEO", "Value"]]
    pc_gen = generation[["GEO", "Value"]]
    pc_recy.columns = ("GEO", "_recycling")
    pc_gen.columns = ("GEO", "_generation")
    merge = pc_recy.merge(pc_gen, left_on="GEO", right_on="GEO")
    merge['_generation'] = merge['_generation'].apply(float_conversion)
    merge['_recycling'] = merge['_recycling'].apply(float_conversion)
#     merge.plot(kind="scatter", figsize=(7,7), x="_generation", y="_recycling", xlim=(0, int(merge["_generation"].max() + 5)), ylim=(0, int(merge["_generation"].max() + 5)))
    merge.plot(kind="scatter", figsize=(7,7), x="_generation", y="_recycling", xlim=(0, 100), ylim=(0, 100))

# %%
waste_type_analysis("plastic", "Plastic packaging")
plt.savefig('plastic.pdf', transparent = True)

# %%
waste_type_analysis("glass", "Glass packaging")
plt.savefig('glass.pdf', transparent = True)

# %%
waste_type_analysis("Metal", "Metallic packaging")
plt.savefig('metal.pdf', transparent = True)

# %%
waste_type_analysis("Paper", "Paper and cardboard packaging")
plt.savefig('paper.pdf', transparent = True)

# %% [markdown]
# # Hazardous waste

# %%
df_haz = pd.read_csv('EU-hazardous-waste.csv')

# %%
df_haz.head(6)
# Out:
#          WASTE             GEO                   UNIT     HAZARD  \
# 0  Total Waste         Belgium                  Tonne  Hazardous
# 1  Total Waste         Belgium  Kilograms per capita   Hazardous
# 2  Total Waste        Bulgaria                  Tonne  Hazardous
# 3  Total Waste        Bulgaria  Kilograms per capita   Hazardous
# 4  Total Waste  Czech Republic                  Tonne  Hazardous
# 5  Total Waste  Czech Republic  Kilograms per capita   Hazardous
#
#                                NACE_R2  TIME       Value  Flag and Footnotes
# 0  All NACE activities plus households  2012   4,257,755                 NaN
# 1  All NACE activities plus households  2012         383                 NaN
# 2  All NACE activities plus households  2012  13,407,042                 NaN
# 3  All NACE activities plus households  2012       1,835                 NaN
# 4  All NACE activities plus households  2012   1,481,281                 NaN
# 5  All NACE activities plus households  2012         141                 NaN

# %%
haz = df_haz[(df_haz["UNIT"]=="Tonne")&(df_haz["WASTE"]=="Total Waste")]
selection_haz = haz[["GEO", "Value"]]
selection_haz
# Out:
#                                                   GEO       Value
# 0                                             Belgium   4,257,755
# 2                                            Bulgaria  13,407,042
# 4                                      Czech Republic   1,481,281
# 6                                             Denmark   1,192,750
# 8    Germany (until 1990 former territory of the FRG)  21,983,895
# 10                                            Estonia   9,159,139
# 12                                            Ireland   1,385,065
# 14                                             Greece     297,370
# 16                                              Spain   3,113,947
# 18                                             France  11,303,137
# 20                                            Croatia     122,541
# 22                                              Italy   9,474,446
# 24                                             Cyprus      31,288
# 26                                             Latvia      95,114
# 28                                          Lithuania     136,786
# 30                                         Luxembourg     315,082
# 32                                            Hungary     700,246
# 34                                              Malta      29,326
# 36                                        Netherlands   4,859,942
# 38                                            Austria   1,065,888
# 40                                             Poland   1,737,024
# 42                                           Portugal     544,963
# 44                                            Romania     670,590
# 46                                           Slovenia     133,334
# 48                                           Slovakia     370,223
# 50                                            Finland   1,653,942
# 52                                             Sweden   2,696,749
# 54                                     United Kingdom   7,630,711
# 56                                            Iceland      16,263
# 58                                      Liechtenstein       3,642
# 60                                             Norway   1,357,124
# 62                                         Montenegro       2,840
# 64         Former Yugoslav Republic of Macedonia, the     678,568
# 66                                             Serbia  14,457,180
# 68                                             Turkey   3,988,200
# 70                             Bosnia and Herzegovina     945,923
# 72  Kosovo (under United Nations Security Council ...       1,348

# %%
selection_haz['Values'] = [value.replace(',', '') for value in selection_haz['Value']]
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
selection_haz['amount_tonnes'] = selection_haz['Values'].apply(float_conversion)
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
selection_haz = selection_haz.drop('Value', 1)
selection_haz = selection_haz.drop('Values', 1)

# %%
selection_haz.to_csv('hazardous_waste_selection.csv')

# %%
selection_haz.sort_values(by='amount_tonnes', ascending=False)
# Out:
#                                                   GEO  amount_tonnes
# 8    Germany (until 1990 former territory of the FRG)     21983895.0
# 66                                             Serbia     14457180.0
# 2                                            Bulgaria     13407042.0
# 18                                             France     11303137.0
# 22                                              Italy      9474446.0
# 10                                            Estonia      9159139.0
# 54                                     United Kingdom      7630711.0
# 36                                        Netherlands      4859942.0
# 0                                             Belgium      4257755.0
# 68                                             Turkey      3988200.0
# 16                                              Spain      3113947.0
# 52                                             Sweden      2696749.0
# 40                                             Poland      1737024.0
# 50                                            Finland      1653942.0
# 4                                      Czech Republic      1481281.0
# 12                                            Ireland      1385065.0
# 60                                             Norway      1357124.0
# 6                                             Denmark      1192750.0
# 38                                            Austria      1065888.0
# 70                             Bosnia and Herzegovina       945923.0
# 32                                            Hungary       700246.0
# 64         Former Yugoslav Republic of Macedonia, the       678568.0
# 44                                            Romania       670590.0
# 42                                           Portugal       544963.0
# 48                                           Slovakia       370223.0
# 30                                         Luxembourg       315082.0
# 14                                             Greece       297370.0
# 28                                          Lithuania       136786.0
# 46                                           Slovenia       133334.0
# 20                                            Croatia       122541.0
# 26                                             Latvia        95114.0
# 24                                             Cyprus        31288.0
# 34                                              Malta        29326.0
# 56                                            Iceland        16263.0
# 58                                      Liechtenstein         3642.0
# 62                                         Montenegro         2840.0
# 72  Kosovo (under United Nations Security Council ...         1348.0

# %%
df_haz["WASTE"].value_counts()
# Out:
# Total Waste                                 74
# Chemical and medical wastes (subtotal)      74
# Mineral and solidified wastes (subtotal)    74
# Name: WASTE, dtype: int64

# %%
haz_chem = df_haz[(df_haz["UNIT"]=="Tonne")&(df_haz["WASTE"]=="Chemical and medical wastes (subtotal)")]
selection_haz_chem = haz_chem[["GEO", "Value"]]
selection_haz_chem
# Out:
#                                                    GEO      Value
# 74                                             Belgium  2,351,545
# 76                                            Bulgaria     52,150
# 78                                      Czech Republic    631,647
# 80                                             Denmark    205,232
# 82    Germany (until 1990 former territory of the FRG)  6,386,831
# 84                                             Estonia  1,560,521
# 86                                             Ireland  1,241,262
# 88                                              Greece    122,464
# 90                                               Spain  1,823,898
# 92                                              France  3,610,656
# 94                                             Croatia     35,849
# 96                                               Italy  4,402,127
# 98                                              Cyprus      5,908
# 100                                             Latvia     31,225
# 102                                          Lithuania     45,654
# 104                                         Luxembourg     36,798
# 106                                            Hungary    331,197
# 108                                              Malta     11,800
# 110                                        Netherlands  1,527,646
# 112                                            Austria    347,675
# 114                                             Poland    814,583
# 116                                           Portugal    290,304
# 118                                            Romania    315,151
# 120                                           Slovenia     75,066
# 122                                           Slovakia    234,451
# 124                                            Finland    425,230
# 126                                             Sweden    696,866
# 128                                     United Kingdom  3,006,156
# 130                                            Iceland      8,556
# 132                                      Liechtenstein        899
# 134                                             Norway    913,075
# 136                                         Montenegro      2,034
# 138         Former Yugoslav Republic of Macedonia, the      6,997
# 140                                             Serbia     54,887
# 142                                             Turkey    616,810
# 144                             Bosnia and Herzegovina      4,455
# 146  Kosovo (under United Nations Security Council ...      1,002

# %%
haz_min = df_haz[(df_haz["UNIT"]=="Tonne")&(df_haz["WASTE"]=="Mineral and solidified wastes (subtotal)")]
selection_haz_min = haz_min[["GEO", "Value"]]
selection_haz_min
# Out:
#                                                    GEO       Value
# 148                                            Belgium   1,331,214
# 150                                           Bulgaria  13,343,813
# 152                                     Czech Republic     793,459
# 154                                            Denmark     789,854
# 156   Germany (until 1990 former territory of the FRG)  10,973,308
# 158                                            Estonia   7,569,320
# 160                                            Ireland      35,359
# 162                                             Greece      46,937
# 164                                              Spain     688,495
# 166                                             France   4,947,028
# 168                                            Croatia      27,642
# 170                                              Italy   2,878,256
# 172                                             Cyprus       6,305
# 174                                             Latvia      40,531
# 176                                          Lithuania      25,259
# 178                                         Luxembourg     229,150
# 180                                            Hungary     272,099
# 182                                              Malta       2,722
# 184                                        Netherlands   2,827,060
# 186                                            Austria     545,201
# 188                                             Poland     719,003
# 190                                           Portugal      88,095
# 192                                            Romania     198,807
# 194                                           Slovenia      24,065
# 196                                           Slovakia     116,605
# 198                                            Finland   1,062,721
# 200                                             Sweden   1,367,406
# 202                                     United Kingdom   1,763,785
# 204                                            Iceland       6,477
# 206                                      Liechtenstein         130
# 208                                             Norway     195,915
# 210                                         Montenegro         753
# 212         Former Yugoslav Republic of Macedonia, the     671,475
# 214                                             Serbia  14,397,438
# 216                                             Turkey   3,346,183
# 218                             Bosnia and Herzegovina     940,244
# 220  Kosovo (under United Nations Security Council ...         221

# %%
selection_haz_chem['Value'] = [value.replace(',', '') for value in selection_haz_chem['Value']]
selection_haz_min['Value'] = [value.replace(',', '') for value in selection_haz_min['Value']]
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
selection_haz_chem['amount_tonnes'] = selection_haz_chem['Value'].apply(float_conversion)
selection_haz_min['amount_tonnes'] = selection_haz_min['Value'].apply(float_conversion)
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
selection_haz_chem = selection_haz_chem.drop('Value', 1)
selection_haz_min = selection_haz_min.drop('Value', 1)

# %%
selection_haz_chem.to_csv('hazardous_waste_chem_selection.csv')
selection_haz_min.to_csv('hazardous_waste_min_selection.csv')
