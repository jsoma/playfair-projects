# %%
import pandas as pd
import matplotlib.pyplot as plt
import dateutil.parser
import datetime
# %matplotlib inline

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
# DATASET COMPRISES:
# Indicator: Primary production // Gross inland consumption
# Unit: Thousand TOE vs Terajoule
# Time: 2014 back to 2004/2005
# Energy products: All products, Renewables, Nuclear, Gas, Solid fuels, Petroleum
df = pd.read_csv('EU-energy-data-COMPLETE.csv')
df.head(50)
# Out:
#     TIME                            GEO  \
# 0   2005  European Union (28 countries)
# 1   2005  European Union (28 countries)
# 2   2005  European Union (28 countries)
# 3   2005  European Union (28 countries)
# 4   2005  European Union (28 countries)
# 5   2005  European Union (28 countries)
# 6   2005  European Union (28 countries)
# 7   2005  European Union (28 countries)
# 8   2005  European Union (28 countries)
# 9   2005  European Union (28 countries)
# 10  2005  European Union (28 countries)
# 11  2005  European Union (28 countries)
# 12  2005  European Union (28 countries)
# 13  2005  European Union (28 countries)
# 14  2005  European Union (28 countries)
# 15  2005  European Union (28 countries)
# 16  2005  European Union (28 countries)
# 17  2005  European Union (28 countries)
# 18  2005  European Union (28 countries)
# 19  2005  European Union (28 countries)
# 20  2005  European Union (28 countries)
# 21  2005  European Union (28 countries)
# ...

# %% [markdown]
# # RENEWABLE ENERGY

# %%
renewable_df = df[df['PRODUCT']== 'Renewable energies']
renewable_df.head()
# Out:
#     TIME                            GEO  \
# 10  2005  European Union (28 countries)
# 11  2005  European Union (28 countries)
# 22  2005  European Union (28 countries)
# 23  2005  European Union (28 countries)
# 34  2005       Euro area (19 countries)
#
#                                        UNIT             PRODUCT  \
# 10  Thousand TOE (tonnes of oil equivalent)  Renewable energies
# 11  Thousand TOE (tonnes of oil equivalent)  Renewable energies
# 22                                Terajoule  Renewable energies
# 23                                Terajoule  Renewable energies
# 34  Thousand TOE (tonnes of oil equivalent)  Renewable energies
#
#                    INDIC_NRG      Value  Flag and Footnotes
# 10        Primary production  119,605.7                 NaN
# 11  Gross inland consumption  121,014.1                 NaN
# 22        Primary production  5,007,652                 NaN
# 23  Gross inland consumption  5,066,617                 NaN
# ...

# %% [markdown]
# ## Selecting 2014

# %%
recent_r_df = renewable_df[renewable_df['TIME'] == 2014]

# %% [markdown]
# # RENEWABLE: PRIMARY PRODUCTION, THOUSAND TOE

# %%
selection_r_p = recent_r_df[(recent_r_df['INDIC_NRG'] == "Primary production") & (recent_r_df['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]

# %%
selection_r_p
# Out:
#                                                     GEO      Value
# 8866                      European Union (28 countries)  195,814.0
# 8890                           Euro area (19 countries)  142,329.0
# 8914                                            Belgium    2,857.1
# 8938                                           Bulgaria    1,842.3
# 8962                                     Czech Republic    3,656.1
# 8986                                            Denmark    3,144.0
# 9010   Germany (until 1990 former territory of the FRG)   36,017.9
# 9034                                            Estonia    1,186.0
# 9058                                            Ireland      853.6
# 9082                                             Greece    2,329.3
# 9106                                              Spain   18,002.8
# 9130                                             France   21,002.1
# 9154                                            Croatia    2,292.1
# ...

# %%
selection_r_p['formatted_values'] = [float(value.replace(',', '')) for value in selection_r_p['Value']]

# %%
selection_r_p = selection_r_p.drop('Value',1)
selection_r_p.columns=(('GEO', 'production_renewables'))
selection_r_p
# Out:
#                                                     GEO  production_renewables
# 8866                      European Union (28 countries)               195814.0
# 8890                           Euro area (19 countries)               142329.0
# 8914                                            Belgium                 2857.1
# 8938                                           Bulgaria                 1842.3
# 8962                                     Czech Republic                 3656.1
# 8986                                            Denmark                 3144.0
# 9010   Germany (until 1990 former territory of the FRG)                36017.9
# 9034                                            Estonia                 1186.0
# 9058                                            Ireland                  853.6
# 9082                                             Greece                 2329.3
# 9106                                              Spain                18002.8
# ...

# %%
#cutting out EU total values
cut_selection = cut_selection = selection_r_p.drop(selection_r_p.index[[0,1]])
cut_selection
# Out:
#                                                     GEO  production_renewables
# 8914                                            Belgium                 2857.1
# 8938                                           Bulgaria                 1842.3
# 8962                                     Czech Republic                 3656.1
# 8986                                            Denmark                 3144.0
# 9010   Germany (until 1990 former territory of the FRG)                36017.9
# 9034                                            Estonia                 1186.0
# 9058                                            Ireland                  853.6
# 9082                                             Greece                 2329.3
# 9106                                              Spain                18002.8
# 9130                                             France                21002.1
# 9154                                            Croatia                 2292.1
# ...

# %%
cut_selection.sort_values(by='production_renewables', ascending = False)
# Out:
#                                                     GEO  production_renewables
# 9010   Germany (until 1990 former territory of the FRG)                36017.9
# 9178                                              Italy                23644.1
# 9130                                             France                21002.1
# 9106                                              Spain                18002.8
# 9538                                             Sweden                16659.8
# 9610                                             Norway                12964.5
# 9730                                             Turkey                12010.2
# 9514                                            Finland                10068.0
# 9562                                     United Kingdom                 9695.7
# 9370                                            Austria                 9370.4
# 9394                                             Poland                 8054.4
# ...

# %%
ax = cut_selection.sort_values(by='production_renewables', ascending = False).plot(kind='barh', x="GEO", figsize=(10,10))

#draw an additional line
EU_average = 6993
ax.plot([EU_average, EU_average], [-1,100], c='red', linestyle="-", linewidth=0.5)


#givin the line a label
ax.annotate(s="European average: 6993 TOE", xy=(6994,0), color='darkred')
ax.set_title('Total production of renewable energy [in thousand tons of oil equivalent(TOE))]')

# plt.savefig('Renewable_consumption by country.pdf', transparent = True)

# %% [markdown]
# # ALL RENEWABLE CONSUMPTION

# %%
selection_r_c = recent_r_df[(recent_r_df['INDIC_NRG'] == "Gross inland consumption") & (recent_r_df['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]

# %%
#re-formatting value column
selection_r_c['consumption_renewables'] = [float(value.replace(',', '')) for value in selection_r_c['Value']]

# %%
#deleting old value column
selection_r_c = selection_r_c.drop('Value', 1)

# %%
selection_r_c
# Out:
#                                                     GEO  \
# 8867                      European Union (28 countries)
# 8891                           Euro area (19 countries)
# 8915                                            Belgium
# 8939                                           Bulgaria
# 8963                                     Czech Republic
# 8987                                            Denmark
# 9011   Germany (until 1990 former territory of the FRG)
# 9035                                            Estonia
# 9059                                            Ireland
# 9083                                             Greece
# 9107                                              Spain
# 9131                                             France
# 9155                                            Croatia
# 9179                                              Italy
# 9203                                             Cyprus
# 9227                                             Latvia
# ...

# %% [markdown]
# # ALL ENERGY PRODUCTION

# %%
all_energy_df = df[df['PRODUCT']== 'All products']

# %%
recent_df_t = all_energy_df[all_energy_df['TIME']==2014]

# %%
selection_t_p = recent_df_t[(recent_df_t['INDIC_NRG'] == "Primary production") & (recent_df_t['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]

# %%
selection_t_p['production_allenergy'] = [float(value.replace(',', '')) for value in selection_t_p['Value']]

# %%
selection_t_p = selection_t_p.drop('Value', 1)
selection_t_p
# Out:
#                                                     GEO  production_allenergy
# 8856                      European Union (28 countries)              770721.8
# 8880                           Euro area (19 countries)              465071.8
# 8904                                            Belgium               12214.7
# 8928                                           Bulgaria               11263.1
# 8952                                     Czech Republic               29069.3
# 8976                                            Denmark               15791.8
# 9000   Germany (until 1990 former territory of the FRG)              119865.8
# 9024                                            Estonia                5832.3
# 9048                                            Ireland                2010.6
# 9072                                             Greece                8804.8
# 9096                                              Spain               34941.8
# ...

# %%
merged_t_r_p = selection_t_p.merge(selection_r_p, left_on= "GEO", right_on = "GEO")

# %%
merged_t_r_p
# Out:
#                                                   GEO  production_allenergy  \
# 0                       European Union (28 countries)              770721.8
# 1                            Euro area (19 countries)              465071.8
# 2                                             Belgium               12214.7
# 3                                            Bulgaria               11263.1
# 4                                      Czech Republic               29069.3
# 5                                             Denmark               15791.8
# 6    Germany (until 1990 former territory of the FRG)              119865.8
# 7                                             Estonia                5832.3
# 8                                             Ireland                2010.6
# 9                                              Greece                8804.8
# 10                                              Spain               34941.8
# ...

# %%
merged_t_r_p['Share of renewable in total production [in %]'] = round((merged_t_r_p['production_renewables']/merged_t_r_p['production_allenergy'])*100)

# %%
merged_t_r_p
# Out:
#                                                   GEO  production_allenergy  \
# 0                       European Union (28 countries)              770721.8
# 1                            Euro area (19 countries)              465071.8
# 2                                             Belgium               12214.7
# 3                                            Bulgaria               11263.1
# 4                                      Czech Republic               29069.3
# 5                                             Denmark               15791.8
# 6    Germany (until 1990 former territory of the FRG)              119865.8
# 7                                             Estonia                5832.3
# 8                                             Ireland                2010.6
# 9                                              Greece                8804.8
# 10                                              Spain               34941.8
# ...

# %%
merged_t_r_p['Share of renewable in total production [in %]'].sort_values().plot(kind='barh', x='GEO', figsize=(10,10))

# %%
#weil manche Laender mehr Energie produzieren, als sie verbrauchen, macht es vermutlich mehr Sinn, auf den Verbrauch zu schauen, als auf die Production, also nochmal alles von vorn....

# %% [markdown]
# # TOTAL ENERGY CONSUMPTION

# %%
selection_t_c = recent_df_t[(recent_df_t['INDIC_NRG'] == "Gross inland consumption") & (recent_df_t['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]

# %%
selection_t_c['consumption_allenergy'] = [float(value.replace(',', '')) for value in selection_t_c['Value']]

# %%
selection_t_c = selection_t_c.drop('Value', 1)

# %%
merged_t_r_consumption = selection_t_c.merge(selection_r_c, left_on="GEO", right_on="GEO")

# %%
merged_t_r_consumption
# Out:
#                                                   GEO  consumption_allenergy  \
# 0                       European Union (28 countries)              1605930.7
# 1                            Euro area (19 countries)              1134762.6
# 2                                             Belgium                53366.8
# 3                                            Bulgaria                17732.3
# 4                                      Czech Republic                41455.9
# 5                                             Denmark                16905.2
# 6    Germany (until 1990 former territory of the FRG)               312969.3
# 7                                             Estonia                 6726.5
# 8                                             Ireland                13562.5
# 9                                              Greece                24429.6
# 10                                              Spain               116680.6
# ...

# %%
merged_t_r_consumption['Share of renewables in total consumption[%]'] = round((merged_t_r_consumption['consumption_renewables']/merged_t_r_consumption['consumption_allenergy'])*100)

# %%
merged_t_r_consumption
# Out:
#                                                   GEO  consumption_allenergy  \
# 0                       European Union (28 countries)              1605930.7
# 1                            Euro area (19 countries)              1134762.6
# 2                                             Belgium                53366.8
# 3                                            Bulgaria                17732.3
# 4                                      Czech Republic                41455.9
# 5                                             Denmark                16905.2
# 6    Germany (until 1990 former territory of the FRG)               312969.3
# 7                                             Estonia                 6726.5
# 8                                             Ireland                13562.5
# 9                                              Greece                24429.6
# 10                                              Spain               116680.6
# ...

# %%
merged_t_r_consumption.plot(kind='barh', x="GEO", figsize=(10,10))

# %%
merged_t_r_consumption['Share of renewables in total consumption[%]'].sort_values().plot(kind='barh', x="GEO", figsize=(10,10))
plt.savefig('share_renewables.pdf', transparent = True)

# %% [markdown]
# # Nuclear energy

# %%
nuclear_df = df[df['PRODUCT']=='Nuclear heat']

# %%
nuclear_df.head()
# Out:
#     TIME                            GEO  \
# 8   2005  European Union (28 countries)
# 9   2005  European Union (28 countries)
# 20  2005  European Union (28 countries)
# 21  2005  European Union (28 countries)
# 32  2005       Euro area (19 countries)
#
#                                        UNIT       PRODUCT  \
# 8   Thousand TOE (tonnes of oil equivalent)  Nuclear heat
# 9   Thousand TOE (tonnes of oil equivalent)  Nuclear heat
# 20                                Terajoule  Nuclear heat
# 21                                Terajoule  Nuclear heat
# 32  Thousand TOE (tonnes of oil equivalent)  Nuclear heat
#
#                    INDIC_NRG       Value  Flag and Footnotes
# 8         Primary production   257,516.0                 NaN
# 9   Gross inland consumption   257,516.0                 NaN
# 20        Primary production  10,781,679                 NaN
# 21  Gross inland consumption  10,781,679                 NaN
# 32        Primary production   201,544.1                 NaN

# %%
recent_df_n = nuclear_df[nuclear_df['TIME']==2014]

# %% [markdown]
# # Nuclear production

# %%
selection_n_p = recent_df_n[(recent_df_n['INDIC_NRG'] == "Primary production") & (recent_df_n['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]
selection_n_p
# Out:
#                                                     GEO      Value
# 8864                      European Union (28 countries)  226,131.9
# 8888                           Euro area (19 countries)  173,942.5
# 8912                                            Belgium    8,693.8
# 8936                                           Bulgaria    4,107.4
# 8960                                     Czech Republic    7,843.3
# 8984                                            Denmark        0.0
# 9008   Germany (until 1990 former territory of the FRG)   25,054.8
# 9032                                            Estonia        0.0
# 9056                                            Ireland        0.0
# 9080                                             Greece        0.0
# 9104                                              Spain   14,782.0
# 9128                                             France  112,590.0
# 9152                                            Croatia        0.0
# ...

# %%
selection_n_p['production_nuclear'] = [float(value.replace(',', '')) for value in selection_n_p['Value']]
selection_n_p = selection_n_p.drop('Value', 1)
selection_n_p.head()
# Out:
#                                 GEO  production_nuclear
# 8864  European Union (28 countries)            226131.9
# 8888       Euro area (19 countries)            173942.5
# 8912                        Belgium              8693.8
# 8936                       Bulgaria              4107.4
# 8960                 Czech Republic              7843.3

# %%
merged_t_r_n_p = merged_t_r_p.merge(selection_n_p, left_on='GEO', right_on = 'GEO')

# %%
merged_t_r_n_p['Share of nuclear in total production[%]'] = round((merged_t_r_n_p['production_nuclear']/merged_t_r_n_p['production_allenergy'])*100)
merged_t_r_n_p
# Out:
#                                                   GEO  production_allenergy  \
# 0                       European Union (28 countries)              770721.8
# 1                            Euro area (19 countries)              465071.8
# 2                                             Belgium               12214.7
# 3                                            Bulgaria               11263.1
# 4                                      Czech Republic               29069.3
# 5                                             Denmark               15791.8
# 6    Germany (until 1990 former territory of the FRG)              119865.8
# 7                                             Estonia                5832.3
# 8                                             Ireland                2010.6
# 9                                              Greece                8804.8
# 10                                              Spain               34941.8
# ...

# %% [markdown]
# # Nuclear consumption

# %%
selection_n_c = recent_df_n[(recent_df_n['INDIC_NRG'] == "Gross inland consumption") & (recent_df_n['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]

# %%
selection_n_c['consumption_nuclear'] = [float(value.replace(',', '')) for value in selection_n_c['Value']]
selection_n_c = selection_n_c.drop('Value', 1)

# %%
merged_t_r_n_c = merged_t_r_consumption.merge(selection_n_c, left_on='GEO', right_on = 'GEO')

# %%
merged_t_r_n_c['Share of nuclear in total consumption[%]'] = round((merged_t_r_n_c['consumption_nuclear']/merged_t_r_n_c['consumption_allenergy'])*100)
merged_t_r_n_c
# Out:
#                                                   GEO  consumption_allenergy  \
# 0                       European Union (28 countries)              1605930.7
# 1                            Euro area (19 countries)              1134762.6
# 2                                             Belgium                53366.8
# 3                                            Bulgaria                17732.3
# 4                                      Czech Republic                41455.9
# 5                                             Denmark                16905.2
# 6    Germany (until 1990 former territory of the FRG)               312969.3
# 7                                             Estonia                 6726.5
# 8                                             Ireland                13562.5
# 9                                              Greece                24429.6
# 10                                              Spain               116680.6
# ...

# %% [markdown]
# # GAS

# %%
gas_df = df[df['PRODUCT']=='Gas']
recent_df_g = gas_df[gas_df['TIME']==2014]

# %% [markdown]
# ## GAS CONSUMPTION

# %%
selection_g_c = recent_df_g[(recent_df_g['INDIC_NRG'] == "Gross inland consumption") & (recent_df_g['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]
selection_g_c['consumption_gas'] = [float(value.replace(',', '')) for value in selection_g_c['Value']]
selection_g_c = selection_g_c.drop('Value', 1)
selection_g_c.head()
# Out:
#                                 GEO  consumption_gas
# 8863  European Union (28 countries)         342916.5
# 8887       Euro area (19 countries)         239185.9
# 8911                        Belgium          12599.3
# 8935                       Bulgaria           2362.6
# 8959                 Czech Republic           6182.1

# %%
merged_t_r_n_g_c = merged_t_r_n_c.merge(selection_g_c, left_on='GEO', right_on = 'GEO')
merged_t_r_n_g_c['Share of gas in total consumption[%]'] = round((merged_t_r_n_g_c['consumption_gas']/merged_t_r_n_g_c['consumption_allenergy'])*100)
merged_t_r_n_g_c
# Out:
#                                                   GEO  consumption_allenergy  \
# 0                       European Union (28 countries)              1605930.7
# 1                            Euro area (19 countries)              1134762.6
# 2                                             Belgium                53366.8
# 3                                            Bulgaria                17732.3
# 4                                      Czech Republic                41455.9
# 5                                             Denmark                16905.2
# 6    Germany (until 1990 former territory of the FRG)               312969.3
# 7                                             Estonia                 6726.5
# 8                                             Ireland                13562.5
# 9                                              Greece                24429.6
# 10                                              Spain               116680.6
# ...

# %% [markdown]
# # Petroleum = Oil

# %%
oil_df = df[df['PRODUCT']=='Total petroleum products']
recent_df_o = oil_df[oil_df['TIME']==2014]

# %% [markdown]
# ## Oil consumption

# %%
selection_o_c = recent_df_o[(recent_df_o['INDIC_NRG'] == "Gross inland consumption") & (recent_df_o['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]
selection_o_c['consumption_oil'] = [float(value.replace(',', '')) for value in selection_o_c['Value']]
selection_o_c = selection_o_c.drop('Value', 1)

# %%
merged_t_r_n_g_o_c = merged_t_r_n_g_c.merge(selection_o_c, left_on='GEO', right_on = 'GEO')
merged_t_r_n_g_o_c['Share of oil in total consumption[%]'] = round((merged_t_r_n_g_o_c['consumption_oil']/merged_t_r_n_g_o_c['consumption_allenergy'])*100)
merged_t_r_n_g_o_c
# Out:
#                                                   GEO  consumption_allenergy  \
# 0                       European Union (28 countries)              1605930.7
# 1                            Euro area (19 countries)              1134762.6
# 2                                             Belgium                53366.8
# 3                                            Bulgaria                17732.3
# 4                                      Czech Republic                41455.9
# 5                                             Denmark                16905.2
# 6    Germany (until 1990 former territory of the FRG)               312969.3
# 7                                             Estonia                 6726.5
# 8                                             Ireland                13562.5
# 9                                              Greece                24429.6
# 10                                              Spain               116680.6
# ...

# %% [markdown]
# # Solid fuels = Coal (and peat)

# %%
solid_df = df[df['PRODUCT']=='Solid fuels']
recent_df_s = solid_df[solid_df['TIME']==2014]

# %% [markdown]
# ## Solid consumption

# %%
selection_s_c = recent_df_s[(recent_df_s['INDIC_NRG'] == "Gross inland consumption") & (recent_df_s['UNIT']=="Thousand TOE (tonnes of oil equivalent)")][['GEO', 'Value']]
selection_s_c
selection_s_c['consumption_solid'] = [value.replace(',', '') for value in selection_s_c['Value']]
selection_s_c = selection_s_c.drop('Value', 1)

# %%
def float_conversion(value_str):
    try:
        value = float(value_str)
        return value
    except:
        pass

# %%
selection_s_c['consumption_solid'] = selection_s_c['consumption_solid'].apply(float_conversion)

# %%
selection_s_c
# Out:
#                                                     GEO  consumption_solid
# 8859                      European Union (28 countries)           268517.4
# 8883                           Euro area (19 countries)           153975.0
# 8907                                            Belgium             3289.8
# 8931                                           Bulgaria             6396.2
# 8955                                     Czech Republic            15876.2
# 8979                                            Denmark             2386.5
# 9003   Germany (until 1990 former territory of the FRG)            79617.2
# 9027                                            Estonia             4500.1
# 9051                                            Ireland             2005.0
# 9075                                             Greece             6687.1
# 9099                                              Spain            11486.5
# ...

# %%
merged_t_r_n_g_o_s_c = merged_t_r_n_g_o_c.merge(selection_s_c, left_on='GEO', right_on = 'GEO')
merged_t_r_n_g_o_s_c['Share of solid fuels in total consumption[%]'] = round((merged_t_r_n_g_o_s_c['consumption_solid']/merged_t_r_n_g_o_s_c['consumption_allenergy'])*100)
merged_t_r_n_g_o_s_c
# Out:
#                                                   GEO  consumption_allenergy  \
# 0                       European Union (28 countries)              1605930.7
# 1                            Euro area (19 countries)              1134762.6
# 2                                             Belgium                53366.8
# 3                                            Bulgaria                17732.3
# 4                                      Czech Republic                41455.9
# 5                                             Denmark                16905.2
# 6    Germany (until 1990 former territory of the FRG)               312969.3
# 7                                             Estonia                 6726.5
# 8                                             Ireland                13562.5
# 9                                              Greece                24429.6
# 10                                              Spain               116680.6
# ...

# %% [markdown]
# # CONSUMPTION DF

# %%
consumption_df = merged_t_r_n_g_o_s_c.copy()
consumption_df.columns
# Out:
# Index(['GEO', 'consumption_allenergy', 'consumption_renewables',
#        'Share of renewables in total consumption[%]', 'consumption_nuclear',
#        'Share of nuclear in total consumption[%]', 'consumption_gas',
#        'Share of gas in total consumption[%]', 'consumption_oil',
#        'Share of oil in total consumption[%]', 'consumption_solid',
#        'Share of solid fuels in total consumption[%]'],
#       dtype='object')

# %%
consumption_shares = consumption_df[['GEO','Share of renewables in total consumption[%]', 'Share of nuclear in total consumption[%]','Share of gas in total consumption[%]', 'Share of oil in total consumption[%]', 'Share of solid fuels in total consumption[%]']]

# %%
consumption_shares
# Out:
#                                                   GEO  \
# 0                       European Union (28 countries)
# 1                            Euro area (19 countries)
# 2                                             Belgium
# 3                                            Bulgaria
# 4                                      Czech Republic
# 5                                             Denmark
# 6    Germany (until 1990 former territory of the FRG)
# 7                                             Estonia
# 8                                             Ireland
# 9                                              Greece
# 10                                              Spain
# 11                                             France
# 12                                            Croatia
# 13                                              Italy
# 14                                             Cyprus
# 15                                             Latvia
# ...

# %%
cut_consumption_shares = consumption_shares.drop(consumption_shares.index[[0,1]])
cut_consumption_shares
# Out:
#                                                   GEO  \
# 2                                             Belgium
# 3                                            Bulgaria
# 4                                      Czech Republic
# 5                                             Denmark
# 6    Germany (until 1990 former territory of the FRG)
# 7                                             Estonia
# 8                                             Ireland
# 9                                              Greece
# 10                                              Spain
# 11                                             France
# 12                                            Croatia
# 13                                              Italy
# 14                                             Cyprus
# 15                                             Latvia
# 16                                          Lithuania
# 17                                         Luxembourg
# ...

# %%
cut_consumption_shares.plot.barh(stacked=True, figsize=(15,15), x='GEO')

# %%
consumption_shares_manipulated = consumption_shares.copy()

# %%
consumption_shares_manipulated['Renewables_negative'] = [(value*-1 )for value in consumption_shares_manipulated['Share of renewables in total consumption[%]']]

# %%
consumption_shares_manipulated['Share of fossil energy'] = consumption_shares_manipulated["Share of gas in total consumption[%]"]+ consumption_shares_manipulated["Share of oil in total consumption[%]"]+consumption_shares_manipulated["Share of solid fuels in total consumption[%]"]

# %%
consumption_shares_manipulated = consumption_shares_manipulated.drop(consumption_shares_manipulated.index[[0,1]])

# %%
consumption_shares_manipulated.columns
# Out:
# Index(['GEO', 'Share of renewables in total consumption[%]',
#        'Share of nuclear in total consumption[%]',
#        'Share of gas in total consumption[%]',
#        'Share of oil in total consumption[%]',
#        'Share of solid fuels in total consumption[%]', 'Renewables_negative',
#        'Share of fossil energy'],
#       dtype='object')

# %%
selection_consumption_shares_manipulated = consumption_shares_manipulated[['GEO','Renewables_negative','Share of fossil energy','Share of nuclear in total consumption[%]']]

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax = selection_consumption_shares_manipulated.sort_values(by="Renewables_negative", ascending=False).plot.barh(ax = ax, stacked=True, x='GEO')
ax.grid()
ax.set_xticks([-100,-75,-50,-25,0,25,50,75,100])
# ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# plt.savefig("energy_plt_renewablevsother_grid.pdf", transparent=True)

# %% [markdown]
# # CONSUMPTION SELECTION

# %%
consumption_germany = consumption_df[consumption_df["GEO"] == "Germany (until 1990 former territory of the FRG)"]

# %%
consumption_germany
# Out:
#                                                 GEO  consumption_allenergy  \
# 6  Germany (until 1990 former territory of the FRG)               312969.3
#
#    consumption_renewables  Share of renewables in total consumption[%]  \
# 6                 35406.3                                         11.0
#
#    consumption_nuclear  Share of nuclear in total consumption[%]  \
# 6              25054.8                                       8.0
#
#    consumption_gas  Share of gas in total consumption[%]  consumption_oil  \
# 6          63090.8                                  20.0         108415.1
#
#    Share of oil in total consumption[%]  consumption_solid  \
# 6                                  35.0            79617.2
#
#    Share of solid fuels in total consumption[%]
# 6                                          25.0

# %%
consumption_norway = consumption_df[consumption_df["GEO"] == "Norway"]

# %%
consumption_norway
# Out:
#        GEO  consumption_allenergy  consumption_renewables  \
# 31  Norway                29236.7                 13096.2
#
#     Share of renewables in total consumption[%]  consumption_nuclear  \
# 31                                         45.0                  0.0
#
#     Share of nuclear in total consumption[%]  consumption_gas  \
# 31                                       0.0           4939.4
#
#     Share of gas in total consumption[%]  consumption_oil  \
# 31                                  17.0          11466.8
#
#     Share of oil in total consumption[%]  consumption_solid  \
# 31                                  39.0              850.0
#
#     Share of solid fuels in total consumption[%]
# 31                                           3.0

# %%
consumption_sweden = consumption_df[consumption_df["GEO"] == "Sweden"]

# %%
consumption_sweden
# Out:
#        GEO  consumption_allenergy  consumption_renewables  \
# 28  Sweden                48168.8                 17265.8
#
#     Share of renewables in total consumption[%]  consumption_nuclear  \
# 28                                         36.0              16735.3
#
#     Share of nuclear in total consumption[%]  consumption_gas  \
# 28                                      35.0            801.4
#
#     Share of gas in total consumption[%]  consumption_oil  \
# 28                                   2.0          12002.6
#
#     Share of oil in total consumption[%]  consumption_solid  \
# 28                                  25.0             2102.7
#
#     Share of solid fuels in total consumption[%]
# 28                                           4.0

# %%
consumption_france = consumption_df[consumption_df["GEO"]=="France"]
consumption_france
# Out:
#        GEO  consumption_allenergy  consumption_renewables  \
# 11  France               248498.2                 21317.4
#
#     Share of renewables in total consumption[%]  consumption_nuclear  \
# 11                                          9.0             112590.0
#
#     Share of nuclear in total consumption[%]  consumption_gas  \
# 11                                      45.0          32597.1
#
#     Share of gas in total consumption[%]  consumption_oil  \
# 11                                  13.0          77240.3
#
#     Share of oil in total consumption[%]  consumption_solid  \
# 11                                  31.0             9289.6
#
#     Share of solid fuels in total consumption[%]
# 11                                           4.0

# %%
consumption_selection = consumption_germany.copy()
table_list=[consumption_norway, consumption_sweden, consumption_france]
for table in table_list:
    consumption_selection = consumption_selection.append(table)

# %%
consumption_selection
# Out:
#                                                  GEO  consumption_allenergy  \
# 6   Germany (until 1990 former territory of the FRG)               312969.3
# 31                                            Norway                29236.7
# 28                                            Sweden                48168.8
# 11                                            France               248498.2
#
#     consumption_renewables  Share of renewables in total consumption[%]  \
# 6                  35406.3                                         11.0
# 31                 13096.2                                         45.0
# 28                 17265.8                                         36.0
# 11                 21317.4                                          9.0
#
#     consumption_nuclear  Share of nuclear in total consumption[%]  \
# 6               25054.8                                       8.0
# 31                  0.0                                       0.0
# ...

# %% [markdown]
# # GDP PER CAPITA vs ENERGY CONSUMPTION vs SHARE RENEWABLES

# %%
gdp_df = pd.read_excel('real-gpd-percap.xls')

# %%
gdp_df = gdp_df.drop(gdp_df.index[[0,1,41,42,43,44,45,46,47,48]])

# %%
gdp_df.columns=((gdp_df.loc[2]))

# %%
gdp_df.columns=(('GEO', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015'))

# %%
gdp_df = gdp_df.drop(gdp_df.index[[0]])
gdp_df.head()
# Out:
#                         GEO   1995   1996   1997   1998   1999   2000   2001  \
# 3         EU (28 countries)  20000  20400  20900  21500  22100  22900  23400
# 4         EU (27 countries)      :      :      :      :      :      :      :
# 5  Euro area (19 countries)  23400  23700  24300  24900  25600  26500  27000
# 6  Euro area (18 countries)  23600  23900  24500  25200  25800  26700  27200
# 7                   Belgium  26600  27000  28000  28400  29400  30400  30500
#
#     2002   2003  ...     2006   2007   2008   2009   2010   2011   2012  \
# 3  23600  23800  ...    25500  26200  26200  25000  25400  25800  25600
# 4      :      :  ...        :      :      :      :      :      :      :
# 5  27100  27100  ...    28700  29400  29400  28000  28500  28900  28600
# 6  27300  27400  ...    28900  29600  29600  28200  28700  29100  28700
# 7  30900  31000  ...    33100  34000  34000  32900  33500  33900  33700
#
#     2013   2014   2015
# 3  25600  25900  26300
# ...

# %%
gdp_2014 = gdp_df[['GEO','2014']]

# %%
gdp_2014
# Out:
#                                            GEO   2014
# 3                            EU (28 countries)  25900
# 4                            EU (27 countries)      :
# 5                     Euro area (19 countries)  28600
# 6                     Euro area (18 countries)  28800
# 7                                      Belgium  33800
# 8                                     Bulgaria   5500
# 9                               Czech Republic  15400
# 10                                     Denmark  43700
# 11                                     Germany  33800
# 12                                     Estonia  13200
# 13                                     Ireland  39300
# 14                                      Greece  17000
# 15                                       Spain  22400
# 16                                      France  31200
# 17                                     Croatia  10200
# 18                                       Italy  25300
# ...

# %%
#WRONG ROW NAMES IN PREVIOUS DATASET --> FINDING NEW ONE
new_gdp = pd.read_csv('new-gdp.csv')

# %%
new_gdp_pc = new_gdp[(new_gdp["UNIT"]=="Chain linked volumes (2010), euro per capita")&(new_gdp["NA_ITEM"]=="Gross domestic product at market prices")]
gdp_pc = new_gdp_pc[["GEO", "Value"]]
gdp_pc["gdp_per_capita"] = [value.replace(',', '') for value in gdp_pc['Value']]
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
gdp_pc["gdp_per_capita"]= gdp_pc["gdp_per_capita"].apply(float_conversion)
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
gdp_pc = gdp_pc.drop("Value", 1)

# %%
gdp_pc
# Out:
#                                                    GEO  gdp_per_capita
# 15                       European Union (28 countries)         25900.0
# 40                       European Union (15 countries)         30000.0
# 65   Euro area (EA11-2000, EA12-2006, EA13-2007, EA...         28800.0
# 90                            Euro area (19 countries)         28600.0
# 115                           Euro area (18 countries)         28800.0
# 140                           Euro area (12 countries)         29300.0
# 165                                            Belgium         33800.0
# 190                                           Bulgaria          5500.0
# 215                                     Czech Republic         15400.0
# 240                                            Denmark         43700.0
# 265   Germany (until 1990 former territory of the FRG)         33800.0
# 290                                            Estonia         13200.0
# ...

# %%
merge_gdp_consumption = merged_t_r_consumption.merge(gdp_pc, left_on="GEO", right_on="GEO")
merge_gdp_consumption.columns = (('GEO', 'consumption_allenergy', 'consumption_renewables','share_renewables', 'GDP_per_capita'))
merge_gdp_consumption= merge_gdp_consumption.drop(merge_gdp_consumption.index[[0,1]])
merge_gdp_consumption
# Out:
#                                                  GEO  consumption_allenergy  \
# 2                                            Belgium                53366.8
# 3                                           Bulgaria                17732.3
# 4                                     Czech Republic                41455.9
# 5                                            Denmark                16905.2
# 6   Germany (until 1990 former territory of the FRG)               312969.3
# 7                                            Estonia                 6726.5
# 8                                            Ireland                13562.5
# 9                                             Greece                24429.6
# 10                                             Spain               116680.6
# 11                                            France               248498.2
# 12                                           Croatia                 8195.3
# ...

# %%
merge_gdp_consumption['GDP_per_capita'].mean()
# Out:
# 25419.354838709678

# %%
merge_gdp_consumption['GDP_per_capita'].median()
# Out:
# 20100.0

# %%
merge_gdp_consumption['consumption_allenergy'].mean()
# Out:
# 50287.060606060608

# %%
merge_gdp_consumption['consumption_allenergy'].median()
# Out:
# 22097.0

# %%
# merge_gdp_consumption["GDP_per_capita"]
# merge_gdp_consumption.info()
# merge_gdp_consumption['GDP_per_capita'] = merge_gdp_consumption['GDP_per_capita'].apply(float_conversion)

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", alpha = 0.5)
ax.set_ylim(0,350000)
# Out:
# (0, 350000)

# %% [markdown]
# ### Bubble size = renewable engery absolute

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", s=merge_gdp_consumption["consumption_renewables"], alpha = 0.5)
# plt.savefig("energy_plt_scatter.pdf", transparent = True)

# %% [markdown]
# ### Bubble size = renewable energy share

# %%
#UNALTERED SIZE
fig, ax = plt.subplots(figsize=(15,10))
ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", s=merge_gdp_consumption["share_renewables"], alpha = 0.5)
# plt.savefig("energy_plt_scatter.pdf", transparent = True)

# %%
#INCREASED SHARE
fig, ax = plt.subplots(figsize=(15,10))
ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", s=merge_gdp_consumption["share_renewables"]*30, alpha = 0.5)
# plt.savefig("energy_plt_scatter.pdf", transparent = True)

# %%
y=merge_gdp_consumption["consumption_allenergy"]
z=merge_gdp_consumption["GDP_per_capita"]
n=merge_gdp_consumption["GEO"]

fig, ax = plt.subplots(figsize=(15,10))
ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", s=merge_gdp_consumption["share_renewables"]*30, alpha=0.5)

#i+2, because index number starts at 2 
for i, txt in enumerate(n):
    ax.annotate(txt, (z[i+2], y[i+2]))

# plt.savefig("energy_plt_scatter_annotated2.pdf", transparent = True)

# %%
# def label_point(x, y, val, ax):
#     a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
#     for i, point in a.iterrows():
#         ax.text(point['x'], point['y'], str(point['val']))

# %%
# fig, ax = plt.subplots(figsize=(15,10))
# ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", s=merge_gdp_consumption["share_renewables"]*5, alpha = 0.5)
# label_point("GDP_per_capita", "consumption_allenergy", "GEO", ax)
# label_point(merge_gdp_consumption["GDP_per_capita"], merge_gdp_consumption["consumption_allenergy"], merge_gdp_consumption["GEO"], ax)

# %%
# fig, ax = plt.subplots(figsize=(15,10))
# ax = merge_gdp_consumption.plot(ax = ax, kind="scatter", x ="GDP_per_capita", y="consumption_allenergy", s=merge_gdp_consumption["share_renewables"]*50, alpha = 0.5)
# for i, row in merge_gdp_consumption.iterrows():
#     ax.annotate(row['GEO']
#     x = (row['GPD_per_capita'])
#     y = (row['consumption_allenergy'])
#     xytext=(row['GPD_per_capita'] + 1, row['consumption_allenergy'] + 1)
#     fontproperties=annotation_font
#     bbox=dict(boxstyle='round', color='k', fc='w', alpha=0.8)
#     xycoords='data'
#     arrowprops=dict(arrowstyle='->', connectionstyle='-')

# %% [markdown]
# # Energy prices -- DOMESTIC

# %%
prices_domestic = pd.read_csv('energy-prices-domestic.csv')

# %%
prices_domestic.head(20)
# Out:
#       TIME                                                GEO  \
# 0   2011S1                      European Union (28 countries)
# 1   2011S1                      European Union (28 countries)
# 2   2011S1                      European Union (28 countries)
# 3   2011S1                      European Union (27 countries)
# 4   2011S1                      European Union (27 countries)
# 5   2011S1                      European Union (27 countries)
# 6   2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 7   2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 8   2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 9   2011S1                                            Belgium
# 10  2011S1                                            Belgium
# 11  2011S1                                            Belgium
# 12  2011S1                                           Bulgaria
# 13  2011S1                                           Bulgaria
# ...

# %%
filtered_d_prices = prices_domestic[prices_df["CURRENCY"]=="Euro"]
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
electricity_prices_domestic = filtered_d_prices[['TIME', 'GEO', 'Value']]

# %%
electricity_prices_domestic.head()
# Out:
#       TIME                                                GEO   Value
# 0   2011S1                      European Union (28 countries)  0.1798
# 3   2011S1                      European Union (27 countries)  0.1803
# 6   2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...  0.1902
# 9   2011S1                                            Belgium  0.2136
# 12  2011S1                                           Bulgaria  0.0826

# %%
electricity_prices_domestic["elec_d_price"] = electricity_prices_domestic['Value'].apply(float_conversion)
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
electricity_prices_domestic = electricity_prices_domestic.drop('Value', 1)

# %%
electricity_prices_domestic
# Out:
#         TIME                                                GEO  elec_d_price
# 0     2011S1                      European Union (28 countries)        0.1798
# 3     2011S1                      European Union (27 countries)        0.1803
# 6     2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...        0.1902
# 9     2011S1                                            Belgium        0.2136
# 12    2011S1                                           Bulgaria        0.0826
# 15    2011S1                                     Czech Republic        0.1495
# 18    2011S1                                            Denmark        0.2908
# 21    2011S1   Germany (until 1990 former territory of the FRG)        0.2528
# 24    2011S1                                            Estonia        0.0973
# 27    2011S1                                            Ireland        0.1901
# 30    2011S1                                             Greece        0.1250
# ...

# %%
electricity_prices_domestic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420 entries, 0 to 1257
# Data columns (total 3 columns):
# TIME            420 non-null object
# GEO             420 non-null object
# elec_d_price    393 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 13.1+ KB

# %%
electricity_prices_domestic['temporary_time'] = [value.replace('S1', '-01-01').replace('S2', '-07-01') for value in electricity_prices_domestic["TIME"]]

# %%
electricity_prices_domestic['parsed_time']=[dateutil.parser.parse(value) for value in electricity_prices_domestic['temporary_time']]

# %%
# electricity_prices_domestic.index = electricity_prices_domestic['parsed_time']

# %%
electricity_prices_domestic= electricity_prices_domestic.drop('temporary_time', 1)
# electricity_prices_domestic= electricity_prices_domestic.drop('parsed_time', 1)
# electricity_prices_domestic= electricity_prices_domestic.drop('TIME', 1)

# %%
electricity_prices_domestic["Unique_Key"]=(electricity_prices_domestic['GEO']+electricity_prices_domestic['TIME'])

# %%
electricity_prices_domestic["Country_name"]=electricity_prices_domestic['GEO'].str.replace(r'\s\(\D.*\)','')

# %%
electricity_prices_domestic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420 entries, 0 to 1257
# Data columns (total 6 columns):
# TIME            420 non-null object
# GEO             420 non-null object
# elec_d_price    393 non-null float64
# parsed_time     420 non-null datetime64[ns]
# Unique_Key      420 non-null object
# Country_name    420 non-null object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 23.0+ KB

# %%
countries_list = []
for country in electricity_prices_domestic["GEO"]:
    countries_list.append(country)

# %%
countries = set(countries_list)

# %%
df=electricity_prices_domestic.copy()
fig, axes = plt.subplots(nrows=7, ncols=6, sharex=True, sharey=True, figsize=(15,15))
axes_list = [item for sublist in axes for item in sublist]

countries = ['Albania',
 'Austria',
 'Belgium',
 'Bosnia and Herzegovina',
 'Bulgaria',
 'Croatia',
 'Cyprus',
 'Czech Republic',
 'Denmark',
 'Estonia',
 'Euro area (EA11-2000, EA12-2006, EA13-2007, EA15-2008, EA16-2010, EA17-2013, EA18-2014, EA19)',
 'European Union (27 countries)',
 'European Union (28 countries)',
 'Finland',
 'Former Yugoslav Republic of Macedonia, the',
 'France',
 'Germany (until 1990 former territory of the FRG)',
 'Greece',
 'Hungary',
 'Iceland',
 'Ireland',
 'Italy',
 'Kosovo (under United Nations Security Council Resolution 1244/99)',
 'Latvia',
 'Liechtenstein',
 'Lithuania',
 'Luxembourg',
 'Malta',
 'Moldova',
 'Montenegro',
 'Netherlands',
 'Norway',
 'Poland',
 'Portugal',
 'Romania',
 'Serbia',
 'Slovakia',
 'Slovenia',
 'Spain',
 'Sweden',
 'Turkey',
 'United Kingdom']

subset_df = df[df['GEO'].isin(countries)]

for countryname, selection in subset_df.groupby('Country_name'):
    ax = axes_list.pop(0)
    selection.plot(x='parsed_time', y='elec_d_price', label=countryname, ax=ax, legend=False)
    ax.set_title(countryname)
    ax.tick_params(
        which='minor',
        bottom='off',
        left='off',
        right='off',
        top='off'
    )
    ax.tick_params(
        which='major',
        bottom='on',
        left='off',
        right='off',
        top='off'
    )
    #ax.grid(linewidth=0.25)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xlabel("")

for ax in axes_list:
    ax.remove()
    
plt.subplots_adjust(hspace=0.55)

# plt.savefig("energy-multiples-prices-domestic.pdf", transparent = True)

# %% [markdown]
# # Energy prices -- industry

# %%
energy_industry= pd.read_csv('energy-prices-industry.csv')
energy_industry.head()
# Out:
#      TIME                            GEO            PRODUCT  \
# 0  2011S1  European Union (28 countries)  Electrical energy
# 1  2011S1  European Union (28 countries)  Electrical energy
# 2  2011S1  European Union (28 countries)  Electrical energy
# 3  2011S1  European Union (27 countries)  Electrical energy
# 4  2011S1  European Union (27 countries)  Electrical energy
#
#                                         CONSOM           UNIT  \
# 0  Band IC : 500 MWh < Consumption < 2 000 MWh  Kilowatt-hour
# 1  Band IC : 500 MWh < Consumption < 2 000 MWh  Kilowatt-hour
# 2  Band IC : 500 MWh < Consumption < 2 000 MWh  Kilowatt-hour
# 3  Band IC : 500 MWh < Consumption < 2 000 MWh  Kilowatt-hour
# 4  Band IC : 500 MWh < Consumption < 2 000 MWh  Kilowatt-hour
#
#                              TAX  \
# 0  All taxes and levies included
# 1  All taxes and levies included
# 2  All taxes and levies included
# 3  All taxes and levies included
# 4  All taxes and levies included
#
# ...

# %%
filtered_i_prices = energy_industry[energy_industry["CURRENCY"]=="Euro"]

# %%
electricity_prices_industry = filtered_i_prices[['TIME', 'GEO', 'Value']]
electricity_prices_industry.head()
# Out:
#       TIME                                                GEO   Value
# 0   2011S1                      European Union (28 countries)  0.1360
# 3   2011S1                      European Union (27 countries)  0.1360
# 6   2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...  0.1416
# 9   2011S1                                            Belgium  0.1328
# 12  2011S1                                           Bulgaria  0.0778

# %%
electricity_prices_industry["elec_i_price"] = electricity_prices_industry['Value'].apply(float_conversion)
electricity_prices_industry = electricity_prices_industry.drop('Value', 1)
electricity_prices_industry
# Out:
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#         TIME                                                GEO  elec_i_price
# 0     2011S1                      European Union (28 countries)        0.1360
# 3     2011S1                      European Union (27 countries)        0.1360
# 6     2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...        0.1416
# 9     2011S1                                            Belgium        0.1328
# 12    2011S1                                           Bulgaria        0.0778
# 15    2011S1                                     Czech Republic        0.1330
# ...

# %%
electricity_prices_industry["Country_name"]=electricity_prices_industry['GEO'].str.replace(r'\s\(\D.*\)','')

# %%
electricity_prices_industry["Unique_Key"]=(electricity_prices_industry['GEO']+electricity_prices_industry['TIME'])
electricity_prices_industry
# Out:
#         TIME                                                GEO  elec_i_price  \
# 0     2011S1                      European Union (28 countries)        0.1360
# 3     2011S1                      European Union (27 countries)        0.1360
# 6     2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...        0.1416
# 9     2011S1                                            Belgium        0.1328
# 12    2011S1                                           Bulgaria        0.0778
# 15    2011S1                                     Czech Republic        0.1330
# 18    2011S1                                            Denmark        0.2423
# 21    2011S1   Germany (until 1990 former territory of the FRG)        0.1668
# 24    2011S1                                            Estonia        0.0862
# 27    2011S1                                            Ireland        0.1281
# 30    2011S1                                             Greece        0.1182
# ...

# %%
fig, axes = plt.subplots(nrows=7, ncols=6, sharex=True, sharey=True, figsize=(15,15))
axes_list = [item for sublist in axes for item in sublist]

countries = ['Albania',
 'Austria',
 'Belgium',
 'Bosnia and Herzegovina',
 'Bulgaria',
 'Croatia',
 'Cyprus',
 'Czech Republic',
 'Denmark',
 'Estonia',
 'Euro area (EA11-2000, EA12-2006, EA13-2007, EA15-2008, EA16-2010, EA17-2013, EA18-2014, EA19)',
 'European Union (27 countries)',
 'European Union (28 countries)',
 'Finland',
 'Former Yugoslav Republic of Macedonia, the',
 'France',
 'Germany (until 1990 former territory of the FRG)',
 'Greece',
 'Hungary',
 'Iceland',
 'Ireland',
 'Italy',
 'Kosovo (under United Nations Security Council Resolution 1244/99)',
 'Latvia',
 'Liechtenstein',
 'Lithuania',
 'Luxembourg',
 'Malta',
 'Moldova',
 'Montenegro',
 'Netherlands',
 'Norway',
 'Poland',
 'Portugal',
 'Romania',
 'Serbia',
 'Slovakia',
 'Slovenia',
 'Spain',
 'Sweden',
 'Turkey',
 'United Kingdom']

subset_industry = electricity_prices_industry[electricity_prices_industry['GEO'].isin(countries)]

for countryname, selection in subset_industry.groupby('Country_name'):
#     print(selection)
    ax = axes_list.pop(0)
    selection.plot(x='TIME', y='elec_i_price', label=countryname, ax=ax, legend=False, c='red')
    ax.set_title(countryname)
    ax.tick_params(
        which='minor',
        bottom='off',
        left='off',
        right='off',
        top='off'
    )
    ax.tick_params(
        which='major',
        bottom='on',
        left='off',
        right='off',
        top='off'
    )
    #ax.grid(linewidth=0.25)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xlabel("")

for ax in axes_list:
    ax.remove()
    
plt.subplots_adjust(hspace=0.55)
# plt.savefig("energy-multiples-prices-industry.pdf", transparent = True)

# %%
#No data for Albania and Iceland available!

# %%
merged_prices = electricity_prices_domestic.merge(electricity_prices_industry, left_on="Unique_Key", right_on="Unique_Key")

# %%
merged_prices.head()
# Out:
#    TIME_x                                              GEO_x  elec_d_price  \
# 0  2011S1                      European Union (28 countries)        0.1798
# 1  2011S1                      European Union (27 countries)        0.1803
# 2  2011S1  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...        0.1902
# 3  2011S1                                            Belgium        0.2136
# 4  2011S1                                           Bulgaria        0.0826
#
#   parsed_time                                         Unique_Key  \
# 0  2011-01-01                European Union (28 countries)2011S1
# 1  2011-01-01                European Union (27 countries)2011S1
# 2  2011-01-01  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 3  2011-01-01                                      Belgium2011S1
# 4  2011-01-01                                     Bulgaria2011S1
#
#                   Country_name_x  TIME_y  \
# 0  European Union (28 countries)  2011S1
# ...

# %%
fig, axes = plt.subplots(nrows=7, ncols=6, sharey=True, figsize=(15,15))
axes_list = [item for sublist in axes for item in sublist]

countries = ['Albania',
 'Austria',
 'Belgium',
 'Bosnia and Herzegovina',
 'Bulgaria',
 'Croatia',
 'Cyprus',
 'Czech Republic',
 'Denmark',
 'Estonia',
 'Euro area (EA11-2000, EA12-2006, EA13-2007, EA15-2008, EA16-2010, EA17-2013, EA18-2014, EA19)',
 'European Union (27 countries)',
 'European Union (28 countries)',
 'Finland',
 'Former Yugoslav Republic of Macedonia, the',
 'France',
 'Germany (until 1990 former territory of the FRG)',
 'Greece',
 'Hungary',
 'Iceland',
 'Ireland',
 'Italy',
 'Kosovo (under United Nations Security Council Resolution 1244/99)',
 'Latvia',
 'Liechtenstein',
 'Lithuania',
 'Luxembourg',
 'Malta',
 'Moldova',
 'Montenegro',
 'Netherlands',
 'Norway',
 'Poland',
 'Portugal',
 'Romania',
 'Serbia',
 'Slovakia',
 'Slovenia',
 'Spain',
 'Sweden',
 'Turkey',
 'United Kingdom']

subset_both = merged_prices[merged_prices['GEO_x'].isin(countries)]

for countryname, selection in subset_both.groupby('Country_name_x'):
#     print(selection)
    ax = axes_list.pop(0)
    selection.plot(x='parsed_time', y='elec_d_price', label=countryname, ax=ax, legend=False, c='blue')
    selection.plot(x='parsed_time', y='elec_i_price', label=countryname, ax=ax, legend=False, c='red')
    ax.set_title(countryname)
    ax.tick_params(
        which='minor',
        bottom='off',
        left='off',
        right='off',
        top='off'
    )
    ax.tick_params(
        which='major',
        bottom='on',
        left='off',
        right='off',
        top='off'
    )
    #ax.grid(linewidth=0.25)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xlabel("")

for ax in axes_list:
    ax.remove()
    
plt.subplots_adjust(hspace=0.55)
# plt.savefig("energy-multiples-prices-merged-x.pdf", transparent = True)
