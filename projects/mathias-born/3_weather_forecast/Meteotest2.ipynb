# %%
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import csv
import json
import requests

# %%
# Get the data
response = requests.get('https://meteotest.ch/wetter/messwerte-bern')
soup_meteotest = BeautifulSoup(response.text, 'html.parser')

# %%
soup_meteotest
# Out:
# <!DOCTYPE html>
# ...
